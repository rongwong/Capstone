# %% [markdown]
# # 4.5 EAE Dataset Modeling

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Results:</b> This dataset did not out-perform the AE dataset.
#
# Go straight to [Results](#Results) for EAE Dataset
# </div>

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import classification_report, confusion_matrix


# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## Creating the Network of Best Model

# %%
#shaping X_train and X_test
train_data_dir = "../datasets/train_cropped_eae/train"
validation_data_dir = "../datasets/train_cropped_eae/val"
filepath = "../models/best_model_eae_cp.hdf5"

img_rows, img_cols = 48, 48
num_classes = 4
epochs = 100
batch_size = 64

# %%
#callbacks

checkpoint = ModelCheckpoint(filepath,
                             monitor='val_categorical_accuracy',
                             mode='max',
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_categorical_accuracy',
                          min_delta=0,
                          mode='auto',
                          patience=15,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = ReduceLROnPlateau(monitor='val_categorical_accuracy',
                              factor=0.2,
                              mode='auto',
                              patience=5,
                              verbose=1,
                              min_delta=0.001)

# callbacks = [checkpoint]
callbacks = [earlystop,checkpoint,reduce_lr]

# %%
#data augmentation for train dataset, normalize all 

val_datagen = ImageDataGenerator(rescale=1./255)

train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')


train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 19601 images belonging to 4 classes.
# Found 4198 images belonging to 4 classes.

# %%
global train_samples, validation_samples
train_samples = 19601
validation_samples = 4198


print(validation_generator.class_indices)
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
#Model
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation="relu", input_shape= (48,48,1)))
model.add(Conv2D(16, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Flatten())
model.add(Dense(4, activation="softmax"))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 16)        2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 128)         73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 2052
# =================================================================
# Total params: 286,036
# Trainable params: 286,036
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile model
model.compile(optimizer= Adam(lr=0.001, decay=1e-6),
              loss="categorical_crossentropy",
              metrics=["categorical_accuracy"])

# %%
# %%time

#fit model
history = model.fit_generator(
            train_generator,
            steps_per_epoch=train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From <timed exec>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2739 - categorical_accuracy: 0.3941
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.43005, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 98s 321ms/step - loss: 1.2739 - categorical_accuracy: 0.3941 - val_loss: 1.2830 - val_categorical_accuracy: 0.4300 - lr: 0.0010
# Epoch 2/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1214 - categorical_accuracy: 0.5269
# Epoch 00002: val_categorical_accuracy improved from 0.43005 to 0.61346, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 97s 318ms/step - loss: 1.1214 - categorical_accuracy: 0.5269 - val_loss: 0.9571 - val_categorical_accuracy: 0.6135 - lr: 0.0010
# Epoch 3/100
# 306/306 [==============================] - ETA: 0s - loss: 0.9955 - categorical_accuracy: 0.5953
# Epoch 00003: val_categorical_accuracy improved from 0.61346 to 0.63486, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 97s 317ms/step - loss: 0.9955 - categorical_accuracy: 0.5953 - val_loss: 0.8904 - val_categorical_accuracy: 0.6349 - lr: 0.0010
# Epoch 4/100
# 306/306 [==============================] - ETA: 0s - loss: 0.9265 - categorical_accuracy: 0.6203
# Epoch 00004: val_categorical_accuracy improved from 0.63486 to 0.64880, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 110s 360ms/step - loss: 0.9265 - categorical_accuracy: 0.6203 - val_loss: 0.8358 - val_categorical_accuracy: 0.6488 - lr: 0.0010
# Epoch 5/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8585 - categorical_accuracy: 0.6507
# Epoch 00005: val_categorical_accuracy improved from 0.64880 to 0.68750, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 113s 371ms/step - loss: 0.8585 - categorical_accuracy: 0.6507 - val_loss: 0.7856 - val_categorical_accuracy: 0.6875 - lr: 0.0010
# Epoch 6/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8288 - categorical_accuracy: 0.6655
# Epoch 00006: val_categorical_accuracy improved from 0.68750 to 0.70433, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 114s 372ms/step - loss: 0.8288 - categorical_accuracy: 0.6655 - val_loss: 0.7238 - val_categorical_accuracy: 0.7043 - lr: 0.0010
# Epoch 7/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7916 - categorical_accuracy: 0.6836
# Epoch 00007: val_categorical_accuracy improved from 0.70433 to 0.70817, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 114s 372ms/step - loss: 0.7916 - categorical_accuracy: 0.6836 - val_loss: 0.7258 - val_categorical_accuracy: 0.7082 - lr: 0.0010
# Epoch 8/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7713 - categorical_accuracy: 0.6935
# Epoch 00008: val_categorical_accuracy improved from 0.70817 to 0.71490, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 115s 375ms/step - loss: 0.7713 - categorical_accuracy: 0.6935 - val_loss: 0.7126 - val_categorical_accuracy: 0.7149 - lr: 0.0010
# Epoch 9/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7480 - categorical_accuracy: 0.7037
# Epoch 00009: val_categorical_accuracy did not improve from 0.71490
# 306/306 [==============================] - 115s 375ms/step - loss: 0.7480 - categorical_accuracy: 0.7037 - val_loss: 0.7250 - val_categorical_accuracy: 0.7050 - lr: 0.0010
# Epoch 10/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7379 - categorical_accuracy: 0.7108
# Epoch 00010: val_categorical_accuracy improved from 0.71490 to 0.72933, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 114s 374ms/step - loss: 0.7379 - categorical_accuracy: 0.7108 - val_loss: 0.6648 - val_categorical_accuracy: 0.7293 - lr: 0.0010
# Epoch 11/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7160 - categorical_accuracy: 0.7214
# Epoch 00011: val_categorical_accuracy improved from 0.72933 to 0.74014, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 114s 372ms/step - loss: 0.7160 - categorical_accuracy: 0.7214 - val_loss: 0.6482 - val_categorical_accuracy: 0.7401 - lr: 0.0010
# Epoch 12/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7067 - categorical_accuracy: 0.7242
# Epoch 00012: val_categorical_accuracy did not improve from 0.74014
# 306/306 [==============================] - 115s 375ms/step - loss: 0.7067 - categorical_accuracy: 0.7242 - val_loss: 0.6498 - val_categorical_accuracy: 0.7399 - lr: 0.0010
# Epoch 13/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6914 - categorical_accuracy: 0.7278
# Epoch 00013: val_categorical_accuracy did not improve from 0.74014
# 306/306 [==============================] - 114s 374ms/step - loss: 0.6914 - categorical_accuracy: 0.7278 - val_loss: 0.7619 - val_categorical_accuracy: 0.6935 - lr: 0.0010
# Epoch 14/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6921 - categorical_accuracy: 0.7266
# Epoch 00014: val_categorical_accuracy did not improve from 0.74014
# 306/306 [==============================] - 115s 377ms/step - loss: 0.6921 - categorical_accuracy: 0.7266 - val_loss: 0.6675 - val_categorical_accuracy: 0.7317 - lr: 0.0010
# Epoch 15/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6790 - categorical_accuracy: 0.7385
# Epoch 00015: val_categorical_accuracy improved from 0.74014 to 0.74135, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 114s 374ms/step - loss: 0.6790 - categorical_accuracy: 0.7385 - val_loss: 0.6444 - val_categorical_accuracy: 0.7413 - lr: 0.0010
# Epoch 16/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6644 - categorical_accuracy: 0.7382
# Epoch 00016: val_categorical_accuracy improved from 0.74135 to 0.75625, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 116s 380ms/step - loss: 0.6644 - categorical_accuracy: 0.7382 - val_loss: 0.6196 - val_categorical_accuracy: 0.7563 - lr: 0.0010
# Epoch 17/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6632 - categorical_accuracy: 0.7430
# Epoch 00017: val_categorical_accuracy improved from 0.75625 to 0.76106, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 115s 376ms/step - loss: 0.6632 - categorical_accuracy: 0.7430 - val_loss: 0.6205 - val_categorical_accuracy: 0.7611 - lr: 0.0010
# Epoch 18/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6584 - categorical_accuracy: 0.7427
# Epoch 00018: val_categorical_accuracy did not improve from 0.76106
# 306/306 [==============================] - 115s 376ms/step - loss: 0.6584 - categorical_accuracy: 0.7427 - val_loss: 0.6313 - val_categorical_accuracy: 0.7490 - lr: 0.0010
# Epoch 19/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6519 - categorical_accuracy: 0.7481
# Epoch 00019: val_categorical_accuracy did not improve from 0.76106
# 306/306 [==============================] - 115s 376ms/step - loss: 0.6519 - categorical_accuracy: 0.7481 - val_loss: 0.6221 - val_categorical_accuracy: 0.7567 - lr: 0.0010
# Epoch 20/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6404 - categorical_accuracy: 0.7498
# Epoch 00020: val_categorical_accuracy did not improve from 0.76106
# 306/306 [==============================] - 115s 376ms/step - loss: 0.6404 - categorical_accuracy: 0.7498 - val_loss: 0.6159 - val_categorical_accuracy: 0.7502 - lr: 0.0010
# Epoch 21/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6318 - categorical_accuracy: 0.7561
# Epoch 00021: val_categorical_accuracy did not improve from 0.76106
# 306/306 [==============================] - 115s 377ms/step - loss: 0.6318 - categorical_accuracy: 0.7561 - val_loss: 0.6004 - val_categorical_accuracy: 0.7589 - lr: 0.0010
# Epoch 22/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6335 - categorical_accuracy: 0.7530
# Epoch 00022: val_categorical_accuracy did not improve from 0.76106
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 306/306 [==============================] - 115s 376ms/step - loss: 0.6335 - categorical_accuracy: 0.7530 - val_loss: 0.6125 - val_categorical_accuracy: 0.7534 - lr: 0.0010
# Epoch 23/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5945 - categorical_accuracy: 0.7704
# Epoch 00023: val_categorical_accuracy improved from 0.76106 to 0.77380, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 115s 375ms/step - loss: 0.5945 - categorical_accuracy: 0.7704 - val_loss: 0.5820 - val_categorical_accuracy: 0.7738 - lr: 2.0000e-04
# Epoch 24/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5829 - categorical_accuracy: 0.7736
# Epoch 00024: val_categorical_accuracy did not improve from 0.77380
# 306/306 [==============================] - 116s 378ms/step - loss: 0.5829 - categorical_accuracy: 0.7736 - val_loss: 0.5731 - val_categorical_accuracy: 0.7678 - lr: 2.0000e-04
# Epoch 25/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5812 - categorical_accuracy: 0.7808
# Epoch 00025: val_categorical_accuracy did not improve from 0.77380
# 306/306 [==============================] - 115s 374ms/step - loss: 0.5812 - categorical_accuracy: 0.7808 - val_loss: 0.5987 - val_categorical_accuracy: 0.7606 - lr: 2.0000e-04
# Epoch 26/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5755 - categorical_accuracy: 0.7789
# Epoch 00026: val_categorical_accuracy did not improve from 0.77380
# 306/306 [==============================] - 115s 377ms/step - loss: 0.5755 - categorical_accuracy: 0.7789 - val_loss: 0.5892 - val_categorical_accuracy: 0.7659 - lr: 2.0000e-04
# Epoch 27/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5706 - categorical_accuracy: 0.7831
# Epoch 00027: val_categorical_accuracy did not improve from 0.77380
# 306/306 [==============================] - 116s 378ms/step - loss: 0.5706 - categorical_accuracy: 0.7831 - val_loss: 0.5823 - val_categorical_accuracy: 0.7719 - lr: 2.0000e-04
# Epoch 28/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5695 - categorical_accuracy: 0.7828
# Epoch 00028: val_categorical_accuracy improved from 0.77380 to 0.77788, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 116s 380ms/step - loss: 0.5695 - categorical_accuracy: 0.7828 - val_loss: 0.5682 - val_categorical_accuracy: 0.7779 - lr: 2.0000e-04
# Epoch 29/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5698 - categorical_accuracy: 0.7801
# Epoch 00029: val_categorical_accuracy did not improve from 0.77788
# 306/306 [==============================] - 116s 378ms/step - loss: 0.5698 - categorical_accuracy: 0.7801 - val_loss: 0.5792 - val_categorical_accuracy: 0.7683 - lr: 2.0000e-04
# Epoch 30/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5632 - categorical_accuracy: 0.7860
# Epoch 00030: val_categorical_accuracy did not improve from 0.77788
# 306/306 [==============================] - 115s 376ms/step - loss: 0.5632 - categorical_accuracy: 0.7860 - val_loss: 0.5811 - val_categorical_accuracy: 0.7721 - lr: 2.0000e-04
# Epoch 31/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5680 - categorical_accuracy: 0.7837
# Epoch 00031: val_categorical_accuracy did not improve from 0.77788
# 306/306 [==============================] - 115s 377ms/step - loss: 0.5680 - categorical_accuracy: 0.7837 - val_loss: 0.5672 - val_categorical_accuracy: 0.7774 - lr: 2.0000e-04
# Epoch 32/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5611 - categorical_accuracy: 0.7865
# Epoch 00032: val_categorical_accuracy did not improve from 0.77788
# 306/306 [==============================] - 116s 378ms/step - loss: 0.5611 - categorical_accuracy: 0.7865 - val_loss: 0.5731 - val_categorical_accuracy: 0.7767 - lr: 2.0000e-04
# Epoch 33/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5626 - categorical_accuracy: 0.7853
# Epoch 00033: val_categorical_accuracy did not improve from 0.77788
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 306/306 [==============================] - 115s 375ms/step - loss: 0.5626 - categorical_accuracy: 0.7853 - val_loss: 0.5918 - val_categorical_accuracy: 0.7714 - lr: 2.0000e-04
# Epoch 34/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5442 - categorical_accuracy: 0.7941
# Epoch 00034: val_categorical_accuracy did not improve from 0.77788
# 306/306 [==============================] - 115s 375ms/step - loss: 0.5442 - categorical_accuracy: 0.7941 - val_loss: 0.5825 - val_categorical_accuracy: 0.7721 - lr: 4.0000e-05
# Epoch 35/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5482 - categorical_accuracy: 0.7897
# Epoch 00035: val_categorical_accuracy improved from 0.77788 to 0.77861, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 116s 379ms/step - loss: 0.5482 - categorical_accuracy: 0.7897 - val_loss: 0.5726 - val_categorical_accuracy: 0.7786 - lr: 4.0000e-05
# Epoch 36/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5551 - categorical_accuracy: 0.7875
# Epoch 00036: val_categorical_accuracy did not improve from 0.77861
# 306/306 [==============================] - 115s 377ms/step - loss: 0.5551 - categorical_accuracy: 0.7875 - val_loss: 0.5722 - val_categorical_accuracy: 0.7769 - lr: 4.0000e-05
# Epoch 37/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5499 - categorical_accuracy: 0.7925
# Epoch 00037: val_categorical_accuracy did not improve from 0.77861
# 306/306 [==============================] - 116s 378ms/step - loss: 0.5499 - categorical_accuracy: 0.7925 - val_loss: 0.5682 - val_categorical_accuracy: 0.7786 - lr: 4.0000e-05
# Epoch 38/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5525 - categorical_accuracy: 0.7890
# Epoch 00038: val_categorical_accuracy did not improve from 0.77861
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 306/306 [==============================] - 116s 378ms/step - loss: 0.5525 - categorical_accuracy: 0.7890 - val_loss: 0.5764 - val_categorical_accuracy: 0.7757 - lr: 4.0000e-05
# Epoch 39/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5460 - categorical_accuracy: 0.7888
# Epoch 00039: val_categorical_accuracy did not improve from 0.77861
# 306/306 [==============================] - 115s 374ms/step - loss: 0.5460 - categorical_accuracy: 0.7888 - val_loss: 0.5754 - val_categorical_accuracy: 0.7762 - lr: 8.0000e-06
# Epoch 40/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5541 - categorical_accuracy: 0.7875
# Epoch 00040: val_categorical_accuracy did not improve from 0.77861
# 306/306 [==============================] - 115s 376ms/step - loss: 0.5541 - categorical_accuracy: 0.7875 - val_loss: 0.5751 - val_categorical_accuracy: 0.7745 - lr: 8.0000e-06
# Epoch 41/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5443 - categorical_accuracy: 0.7952
# Epoch 00041: val_categorical_accuracy did not improve from 0.77861
# 306/306 [==============================] - 116s 380ms/step - loss: 0.5443 - categorical_accuracy: 0.7952 - val_loss: 0.5734 - val_categorical_accuracy: 0.7752 - lr: 8.0000e-06
# Epoch 42/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5502 - categorical_accuracy: 0.7909
# Epoch 00042: val_categorical_accuracy did not improve from 0.77861
# 306/306 [==============================] - 116s 380ms/step - loss: 0.5502 - categorical_accuracy: 0.7909 - val_loss: 0.5719 - val_categorical_accuracy: 0.7786 - lr: 8.0000e-06
# Epoch 43/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5524 - categorical_accuracy: 0.7873
# Epoch 00043: val_categorical_accuracy did not improve from 0.77861
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 306/306 [==============================] - 116s 379ms/step - loss: 0.5524 - categorical_accuracy: 0.7873 - val_loss: 0.5718 - val_categorical_accuracy: 0.7786 - lr: 8.0000e-06
# Epoch 44/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5452 - categorical_accuracy: 0.7909
# Epoch 00044: val_categorical_accuracy improved from 0.77861 to 0.78005, saving model to ../models/best_model_eae_cp.hdf5
# 306/306 [==============================] - 101s 330ms/step - loss: 0.5452 - categorical_accuracy: 0.7909 - val_loss: 0.5712 - val_categorical_accuracy: 0.7800 - lr: 1.6000e-06
# Epoch 45/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5431 - categorical_accuracy: 0.7919
# Epoch 00045: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 93s 304ms/step - loss: 0.5431 - categorical_accuracy: 0.7919 - val_loss: 0.5746 - val_categorical_accuracy: 0.7774 - lr: 1.6000e-06
# Epoch 46/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5467 - categorical_accuracy: 0.7898
# Epoch 00046: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 92s 300ms/step - loss: 0.5467 - categorical_accuracy: 0.7898 - val_loss: 0.5691 - val_categorical_accuracy: 0.7798 - lr: 1.6000e-06
# Epoch 47/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5420 - categorical_accuracy: 0.7924
# Epoch 00047: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 92s 301ms/step - loss: 0.5420 - categorical_accuracy: 0.7924 - val_loss: 0.5724 - val_categorical_accuracy: 0.7779 - lr: 1.6000e-06
# Epoch 48/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5430 - categorical_accuracy: 0.7932
# Epoch 00048: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 93s 303ms/step - loss: 0.5430 - categorical_accuracy: 0.7932 - val_loss: 0.5742 - val_categorical_accuracy: 0.7776 - lr: 1.6000e-06
# Epoch 49/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5461 - categorical_accuracy: 0.7889
# Epoch 00049: val_categorical_accuracy did not improve from 0.78005
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 306/306 [==============================] - 92s 301ms/step - loss: 0.5461 - categorical_accuracy: 0.7889 - val_loss: 0.5733 - val_categorical_accuracy: 0.7774 - lr: 1.6000e-06
# Epoch 50/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5474 - categorical_accuracy: 0.7913
# Epoch 00050: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 92s 301ms/step - loss: 0.5474 - categorical_accuracy: 0.7913 - val_loss: 0.5740 - val_categorical_accuracy: 0.7764 - lr: 3.2000e-07
# Epoch 51/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5498 - categorical_accuracy: 0.7919
# Epoch 00051: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 92s 302ms/step - loss: 0.5498 - categorical_accuracy: 0.7919 - val_loss: 0.5730 - val_categorical_accuracy: 0.7767 - lr: 3.2000e-07
# Epoch 52/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5441 - categorical_accuracy: 0.7923
# Epoch 00052: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 92s 302ms/step - loss: 0.5441 - categorical_accuracy: 0.7923 - val_loss: 0.5737 - val_categorical_accuracy: 0.7764 - lr: 3.2000e-07
# Epoch 53/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5465 - categorical_accuracy: 0.7933
# Epoch 00053: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 93s 303ms/step - loss: 0.5465 - categorical_accuracy: 0.7933 - val_loss: 0.5712 - val_categorical_accuracy: 0.7772 - lr: 3.2000e-07
# Epoch 54/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5435 - categorical_accuracy: 0.7920
# Epoch 00054: val_categorical_accuracy did not improve from 0.78005
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 306/306 [==============================] - 92s 302ms/step - loss: 0.5435 - categorical_accuracy: 0.7920 - val_loss: 0.5739 - val_categorical_accuracy: 0.7774 - lr: 3.2000e-07
# Epoch 55/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5472 - categorical_accuracy: 0.7919
# Epoch 00055: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 92s 302ms/step - loss: 0.5472 - categorical_accuracy: 0.7919 - val_loss: 0.5730 - val_categorical_accuracy: 0.7772 - lr: 6.4000e-08
# Epoch 56/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5424 - categorical_accuracy: 0.7938
# Epoch 00056: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 93s 303ms/step - loss: 0.5424 - categorical_accuracy: 0.7938 - val_loss: 0.5728 - val_categorical_accuracy: 0.7774 - lr: 6.4000e-08
# Epoch 57/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5469 - categorical_accuracy: 0.7910
# Epoch 00057: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 72s 234ms/step - loss: 0.5469 - categorical_accuracy: 0.7910 - val_loss: 0.5689 - val_categorical_accuracy: 0.7791 - lr: 6.4000e-08
# Epoch 58/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5448 - categorical_accuracy: 0.7941
# Epoch 00058: val_categorical_accuracy did not improve from 0.78005
# 306/306 [==============================] - 70s 229ms/step - loss: 0.5448 - categorical_accuracy: 0.7941 - val_loss: 0.5721 - val_categorical_accuracy: 0.7781 - lr: 6.4000e-08
# Epoch 59/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5467 - categorical_accuracy: 0.7941Restoring model weights from the end of the best epoch.
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.78005
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 306/306 [==============================] - 70s 227ms/step - loss: 0.5467 - categorical_accuracy: 0.7941 - val_loss: 0.5731 - val_categorical_accuracy: 0.7772 - lr: 6.4000e-08
# Epoch 00059: early stopping
# CPU times: user 2h 34min 21s, sys: 24min 23s, total: 2h 58min 44s
# Wall time: 1h 45min 42s

# %% [markdown]
# ## Results

# %%
#plotting Accuracy and Loss curves
plt.figure(figsize=(15,5))

plt.subplot(121)
plt.plot(history.history["categorical_accuracy"], label = 'Train Accuracy', color='gold')
plt.plot(history.history["val_categorical_accuracy"], label = 'Validation Accuracy', color='slategray')
plt.title("Training and Validation Accuracy by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend();

plt.subplot(122)
plt.plot(history.history["loss"], label = 'Train Loss', color='gold')
plt.plot(history.history["val_loss"], label = 'Validation Loss', color='slategray')
plt.title("Training and Validation Loss by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend();

# %%
#Code snippet credit: APEKSHA PRIYA, Priya Dwivedi
#confusion matrix and classification report

#validation generator with shuffle = false
validation_generator1 = val_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

class_labels = validation_generator1.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())

#Confusion Matrix and Classification Report
Y_pred = model.predict_generator(validation_generator1, validation_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
y_test = validation_generator1.classes

#Generate Confusion Matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
cnf_matrix.ravel

print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(y_test, y_pred, target_names=target_names))


#plot confusion matrix
plt.figure(figsize=(8,8))
ax= plt.subplot()
sns.heatmap(cnf_matrix, annot=True, ax = ax, cmap='bone_r', fmt='g', cbar=False)
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad'])
ax.yaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad']);
# Out:
# Found 4198 images belonging to 4 classes.
# WARNING:tensorflow:From <ipython-input-10-6561d12b4ec9>:18: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.66      0.72      0.69       544
#        happy       0.91      0.88      0.89      1665
#      neutral       0.75      0.80      0.77      1401
#          sad       0.59      0.52      0.55       588
#
#     accuracy                           0.78      4198
#    macro avg       0.73      0.73      0.73      4198
# weighted avg       0.78      0.78      0.78      4198
