# %% [markdown]
# # 4.6 Baseline Model Score - Original Dataset

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Results: F1 weighted average 0.47</b>
#
# This is the Baseline score calculated on the simplest CNN model.
#
# Go straight to [Results](#Results) for Baseline Results
# </div>

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.utils.vis_utils import plot_model

from sklearn.metrics import classification_report, confusion_matrix


# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## Creating the Network of Best Model

# %%
#shaping X_train and X_test
train_data_dir = "../datasets/train_cropped_original/train"
validation_data_dir = "../datasets/train_cropped_original/val"
filepath = "../models/best_model_baseline_cp.hdf5"

img_rows, img_cols = 48, 48
num_classes = 4
epochs = 100
batch_size = 64

# %%
#callbacks

checkpoint = ModelCheckpoint(filepath,
                             monitor='val_categorical_accuracy',
                             mode='max',
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_categorical_accuracy',
                          min_delta=0,
                          mode='auto',
                          patience=15,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = ReduceLROnPlateau(monitor='val_categorical_accuracy',
                              factor=0.2,
                              mode='auto',
                              patience=5,
                              verbose=1,
                              min_delta=0.001)

# callbacks = [checkpoint]
callbacks = [earlystop,checkpoint,reduce_lr]

# %%
#data augmentation for train dataset, normalize all 

val_datagen = ImageDataGenerator(rescale=1./255)

train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')


train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 19601 images belonging to 4 classes.
# Found 4198 images belonging to 4 classes.

# %%
global train_samples, validation_samples
train_samples = 19601
validation_samples = 4198


print(validation_generator.class_indices)
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
#baseline model
model = Sequential()

model.add(Flatten(input_shape= (48,48,1)))

model.add(Dense(4, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 9220
# =================================================================
# Total params: 9,220
# Trainable params: 9,220
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file = "../images/model_plot_baseline.png", show_shapes=True, show_layer_names=True)

# %%
#compile model
model.compile(optimizer= Adam(lr=0.001, decay=1e-6),
              loss="categorical_crossentropy",
              metrics=["categorical_accuracy"])

# %%
# %%time

#fit model
history = model.fit_generator(
            train_generator,
            steps_per_epoch=train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From <timed exec>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2813 - categorical_accuracy: 0.4186
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.46034, saving model to ../models/best_model_baseline_cp.hdf5
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2811 - categorical_accuracy: 0.4187 - val_loss: 1.2061 - val_categorical_accuracy: 0.4603 - lr: 0.0010
# Epoch 2/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2508 - categorical_accuracy: 0.4437
# Epoch 00002: val_categorical_accuracy improved from 0.46034 to 0.46394, saving model to ../models/best_model_baseline_cp.hdf5
# 306/306 [==============================] - 8s 27ms/step - loss: 1.2508 - categorical_accuracy: 0.4437 - val_loss: 1.2091 - val_categorical_accuracy: 0.4639 - lr: 0.0010
# Epoch 3/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2564 - categorical_accuracy: 0.4391
# Epoch 00003: val_categorical_accuracy improved from 0.46394 to 0.51611, saving model to ../models/best_model_baseline_cp.hdf5
# 306/306 [==============================] - 8s 27ms/step - loss: 1.2561 - categorical_accuracy: 0.4393 - val_loss: 1.2021 - val_categorical_accuracy: 0.5161 - lr: 0.0010
# Epoch 4/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2498 - categorical_accuracy: 0.4547
# Epoch 00004: val_categorical_accuracy did not improve from 0.51611
# 306/306 [==============================] - 8s 28ms/step - loss: 1.2497 - categorical_accuracy: 0.4549 - val_loss: 1.1807 - val_categorical_accuracy: 0.4894 - lr: 0.0010
# Epoch 5/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2414 - categorical_accuracy: 0.4608
# Epoch 00005: val_categorical_accuracy did not improve from 0.51611
# 306/306 [==============================] - 8s 28ms/step - loss: 1.2414 - categorical_accuracy: 0.4608 - val_loss: 1.1933 - val_categorical_accuracy: 0.5019 - lr: 0.0010
# Epoch 6/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2398 - categorical_accuracy: 0.4577
# Epoch 00006: val_categorical_accuracy did not improve from 0.51611
# 306/306 [==============================] - 9s 29ms/step - loss: 1.2404 - categorical_accuracy: 0.4571 - val_loss: 1.2199 - val_categorical_accuracy: 0.4486 - lr: 0.0010
# Epoch 7/100
# 304/306 [============================>.] - ETA: 0s - loss: 1.2452 - categorical_accuracy: 0.4555
# Epoch 00007: val_categorical_accuracy improved from 0.51611 to 0.52596, saving model to ../models/best_model_baseline_cp.hdf5
# 306/306 [==============================] - 8s 28ms/step - loss: 1.2453 - categorical_accuracy: 0.4549 - val_loss: 1.1691 - val_categorical_accuracy: 0.5260 - lr: 0.0010
# Epoch 8/100
# 304/306 [============================>.] - ETA: 0s - loss: 1.2469 - categorical_accuracy: 0.4536
# Epoch 00008: val_categorical_accuracy did not improve from 0.52596
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2466 - categorical_accuracy: 0.4535 - val_loss: 1.1678 - val_categorical_accuracy: 0.5214 - lr: 0.0010
# Epoch 9/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2381 - categorical_accuracy: 0.4572
# Epoch 00009: val_categorical_accuracy did not improve from 0.52596
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2381 - categorical_accuracy: 0.4572 - val_loss: 1.1738 - val_categorical_accuracy: 0.5238 - lr: 0.0010
# Epoch 10/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2390 - categorical_accuracy: 0.4605
# Epoch 00010: val_categorical_accuracy improved from 0.52596 to 0.53173, saving model to ../models/best_model_baseline_cp.hdf5
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2390 - categorical_accuracy: 0.4605 - val_loss: 1.1797 - val_categorical_accuracy: 0.5317 - lr: 0.0010
# Epoch 11/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2393 - categorical_accuracy: 0.4590
# Epoch 00011: val_categorical_accuracy did not improve from 0.53173
# 306/306 [==============================] - 9s 29ms/step - loss: 1.2393 - categorical_accuracy: 0.4592 - val_loss: 1.2069 - val_categorical_accuracy: 0.4889 - lr: 0.0010
# Epoch 12/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2417 - categorical_accuracy: 0.4615
# Epoch 00012: val_categorical_accuracy did not improve from 0.53173
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2418 - categorical_accuracy: 0.4613 - val_loss: 1.2272 - val_categorical_accuracy: 0.4519 - lr: 0.0010
# Epoch 13/100
# 304/306 [============================>.] - ETA: 0s - loss: 1.2378 - categorical_accuracy: 0.4528
# Epoch 00013: val_categorical_accuracy did not improve from 0.53173
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2376 - categorical_accuracy: 0.4528 - val_loss: 1.2810 - val_categorical_accuracy: 0.4269 - lr: 0.0010
# Epoch 14/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2493 - categorical_accuracy: 0.4525
# Epoch 00014: val_categorical_accuracy did not improve from 0.53173
# 306/306 [==============================] - 8s 28ms/step - loss: 1.2498 - categorical_accuracy: 0.4527 - val_loss: 1.1981 - val_categorical_accuracy: 0.5142 - lr: 0.0010
# Epoch 15/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2408 - categorical_accuracy: 0.4602
# Epoch 00015: val_categorical_accuracy did not improve from 0.53173
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 306/306 [==============================] - 8s 28ms/step - loss: 1.2408 - categorical_accuracy: 0.4602 - val_loss: 1.1791 - val_categorical_accuracy: 0.5257 - lr: 0.0010
# Epoch 16/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2086 - categorical_accuracy: 0.4743
# Epoch 00016: val_categorical_accuracy did not improve from 0.53173
# 306/306 [==============================] - 8s 27ms/step - loss: 1.2086 - categorical_accuracy: 0.4740 - val_loss: 1.1593 - val_categorical_accuracy: 0.5185 - lr: 2.0000e-04
# Epoch 17/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2086 - categorical_accuracy: 0.4810
# Epoch 00017: val_categorical_accuracy did not improve from 0.53173
# 306/306 [==============================] - 9s 29ms/step - loss: 1.2085 - categorical_accuracy: 0.4811 - val_loss: 1.1565 - val_categorical_accuracy: 0.5276 - lr: 2.0000e-04
# Epoch 18/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2071 - categorical_accuracy: 0.4825
# Epoch 00018: val_categorical_accuracy did not improve from 0.53173
# 306/306 [==============================] - 9s 29ms/step - loss: 1.2071 - categorical_accuracy: 0.4825 - val_loss: 1.1615 - val_categorical_accuracy: 0.5262 - lr: 2.0000e-04
# Epoch 19/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2105 - categorical_accuracy: 0.4762
# Epoch 00019: val_categorical_accuracy improved from 0.53173 to 0.53317, saving model to ../models/best_model_baseline_cp.hdf5
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2103 - categorical_accuracy: 0.4762 - val_loss: 1.1600 - val_categorical_accuracy: 0.5332 - lr: 2.0000e-04
# Epoch 20/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2034 - categorical_accuracy: 0.4812
# Epoch 00020: val_categorical_accuracy did not improve from 0.53317
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2032 - categorical_accuracy: 0.4816 - val_loss: 1.1653 - val_categorical_accuracy: 0.5315 - lr: 2.0000e-04
# Epoch 21/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2101 - categorical_accuracy: 0.4778
# Epoch 00021: val_categorical_accuracy did not improve from 0.53317
# 306/306 [==============================] - 8s 27ms/step - loss: 1.2101 - categorical_accuracy: 0.4778 - val_loss: 1.1706 - val_categorical_accuracy: 0.4981 - lr: 2.0000e-04
# Epoch 22/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2117 - categorical_accuracy: 0.4745
# Epoch 00022: val_categorical_accuracy did not improve from 0.53317
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2117 - categorical_accuracy: 0.4745 - val_loss: 1.1629 - val_categorical_accuracy: 0.5250 - lr: 2.0000e-04
# Epoch 23/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2110 - categorical_accuracy: 0.4760
# Epoch 00023: val_categorical_accuracy did not improve from 0.53317
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2110 - categorical_accuracy: 0.4760 - val_loss: 1.1692 - val_categorical_accuracy: 0.5123 - lr: 2.0000e-04
# Epoch 24/100
# 304/306 [============================>.] - ETA: 0s - loss: 1.2105 - categorical_accuracy: 0.4765
# Epoch 00024: val_categorical_accuracy did not improve from 0.53317
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 306/306 [==============================] - 8s 28ms/step - loss: 1.2103 - categorical_accuracy: 0.4764 - val_loss: 1.1618 - val_categorical_accuracy: 0.5303 - lr: 2.0000e-04
# Epoch 25/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1980 - categorical_accuracy: 0.4823
# Epoch 00025: val_categorical_accuracy did not improve from 0.53317
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1984 - categorical_accuracy: 0.4821 - val_loss: 1.1601 - val_categorical_accuracy: 0.5317 - lr: 4.0000e-05
# Epoch 26/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1982 - categorical_accuracy: 0.4856
# Epoch 00026: val_categorical_accuracy improved from 0.53317 to 0.53438, saving model to ../models/best_model_baseline_cp.hdf5
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1982 - categorical_accuracy: 0.4856 - val_loss: 1.1599 - val_categorical_accuracy: 0.5344 - lr: 4.0000e-05
# Epoch 27/100
# 304/306 [============================>.] - ETA: 0s - loss: 1.1985 - categorical_accuracy: 0.4833
# Epoch 00027: val_categorical_accuracy did not improve from 0.53438
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1988 - categorical_accuracy: 0.4833 - val_loss: 1.1591 - val_categorical_accuracy: 0.5209 - lr: 4.0000e-05
# Epoch 28/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2007 - categorical_accuracy: 0.4839
# Epoch 00028: val_categorical_accuracy did not improve from 0.53438
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2007 - categorical_accuracy: 0.4839 - val_loss: 1.1591 - val_categorical_accuracy: 0.5288 - lr: 4.0000e-05
# Epoch 29/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1999 - categorical_accuracy: 0.4830
# Epoch 00029: val_categorical_accuracy did not improve from 0.53438
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1995 - categorical_accuracy: 0.4832 - val_loss: 1.1606 - val_categorical_accuracy: 0.5190 - lr: 4.0000e-05
# Epoch 30/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1970 - categorical_accuracy: 0.4867
# Epoch 00030: val_categorical_accuracy improved from 0.53438 to 0.53558, saving model to ../models/best_model_baseline_cp.hdf5
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1970 - categorical_accuracy: 0.4867 - val_loss: 1.1564 - val_categorical_accuracy: 0.5356 - lr: 4.0000e-05
# Epoch 31/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1993 - categorical_accuracy: 0.4822
# Epoch 00031: val_categorical_accuracy did not improve from 0.53558
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1993 - categorical_accuracy: 0.4822 - val_loss: 1.1590 - val_categorical_accuracy: 0.5334 - lr: 4.0000e-05
# Epoch 32/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1996 - categorical_accuracy: 0.4858
# Epoch 00032: val_categorical_accuracy did not improve from 0.53558
# 306/306 [==============================] - 8s 27ms/step - loss: 1.2000 - categorical_accuracy: 0.4857 - val_loss: 1.1566 - val_categorical_accuracy: 0.5272 - lr: 4.0000e-05
# Epoch 33/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2009 - categorical_accuracy: 0.4868
# Epoch 00033: val_categorical_accuracy did not improve from 0.53558
# 306/306 [==============================] - 8s 27ms/step - loss: 1.2009 - categorical_accuracy: 0.4868 - val_loss: 1.1608 - val_categorical_accuracy: 0.5341 - lr: 4.0000e-05
# Epoch 34/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2008 - categorical_accuracy: 0.4829
# Epoch 00034: val_categorical_accuracy did not improve from 0.53558
# 306/306 [==============================] - 9s 28ms/step - loss: 1.2009 - categorical_accuracy: 0.4828 - val_loss: 1.1567 - val_categorical_accuracy: 0.5257 - lr: 4.0000e-05
# Epoch 35/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1988 - categorical_accuracy: 0.4847
# Epoch 00035: val_categorical_accuracy did not improve from 0.53558
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 306/306 [==============================] - 9s 29ms/step - loss: 1.1987 - categorical_accuracy: 0.4848 - val_loss: 1.1568 - val_categorical_accuracy: 0.5305 - lr: 4.0000e-05
# Epoch 36/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1976 - categorical_accuracy: 0.4840
# Epoch 00036: val_categorical_accuracy did not improve from 0.53558
# 306/306 [==============================] - 9s 28ms/step - loss: 1.1976 - categorical_accuracy: 0.4840 - val_loss: 1.1580 - val_categorical_accuracy: 0.5349 - lr: 8.0000e-06
# Epoch 37/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.2008 - categorical_accuracy: 0.4849
# Epoch 00037: val_categorical_accuracy improved from 0.53558 to 0.53606, saving model to ../models/best_model_baseline_cp.hdf5
# 306/306 [==============================] - 8s 27ms/step - loss: 1.2007 - categorical_accuracy: 0.4848 - val_loss: 1.1572 - val_categorical_accuracy: 0.5361 - lr: 8.0000e-06
# Epoch 38/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1999 - categorical_accuracy: 0.4839
# Epoch 00038: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 8s 28ms/step - loss: 1.1997 - categorical_accuracy: 0.4839 - val_loss: 1.1571 - val_categorical_accuracy: 0.5349 - lr: 8.0000e-06
# Epoch 39/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1977 - categorical_accuracy: 0.4849
# Epoch 00039: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 8s 28ms/step - loss: 1.1977 - categorical_accuracy: 0.4849 - val_loss: 1.1573 - val_categorical_accuracy: 0.5349 - lr: 8.0000e-06
# Epoch 40/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1965 - categorical_accuracy: 0.4860
# Epoch 00040: val_categorical_accuracy did not improve from 0.53606
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1966 - categorical_accuracy: 0.4859 - val_loss: 1.1569 - val_categorical_accuracy: 0.5353 - lr: 8.0000e-06
# Epoch 41/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1989 - categorical_accuracy: 0.4842
# Epoch 00041: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1989 - categorical_accuracy: 0.4842 - val_loss: 1.1580 - val_categorical_accuracy: 0.5339 - lr: 1.6000e-06
# Epoch 42/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1979 - categorical_accuracy: 0.4882
# Epoch 00042: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 9s 28ms/step - loss: 1.1979 - categorical_accuracy: 0.4880 - val_loss: 1.1574 - val_categorical_accuracy: 0.5351 - lr: 1.6000e-06
# Epoch 43/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1978 - categorical_accuracy: 0.4834
# Epoch 00043: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 9s 29ms/step - loss: 1.1978 - categorical_accuracy: 0.4835 - val_loss: 1.1564 - val_categorical_accuracy: 0.5325 - lr: 1.6000e-06
# Epoch 44/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1984 - categorical_accuracy: 0.4867
# Epoch 00044: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 9s 30ms/step - loss: 1.1984 - categorical_accuracy: 0.4867 - val_loss: 1.1569 - val_categorical_accuracy: 0.5334 - lr: 1.6000e-06
# Epoch 45/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1979 - categorical_accuracy: 0.4848
# Epoch 00045: val_categorical_accuracy did not improve from 0.53606
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1979 - categorical_accuracy: 0.4848 - val_loss: 1.1587 - val_categorical_accuracy: 0.5325 - lr: 1.6000e-06
# Epoch 46/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1947 - categorical_accuracy: 0.4900
# Epoch 00046: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 9s 29ms/step - loss: 1.1947 - categorical_accuracy: 0.4900 - val_loss: 1.1584 - val_categorical_accuracy: 0.5322 - lr: 3.2000e-07
# Epoch 47/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1979 - categorical_accuracy: 0.4876
# Epoch 00047: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 9s 29ms/step - loss: 1.1979 - categorical_accuracy: 0.4876 - val_loss: 1.1567 - val_categorical_accuracy: 0.5337 - lr: 3.2000e-07
# Epoch 48/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1991 - categorical_accuracy: 0.4865
# Epoch 00048: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 9s 28ms/step - loss: 1.1993 - categorical_accuracy: 0.4864 - val_loss: 1.1569 - val_categorical_accuracy: 0.5337 - lr: 3.2000e-07
# Epoch 49/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1966 - categorical_accuracy: 0.4811
# Epoch 00049: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 9s 28ms/step - loss: 1.1966 - categorical_accuracy: 0.4811 - val_loss: 1.1579 - val_categorical_accuracy: 0.5325 - lr: 3.2000e-07
# Epoch 50/100
# 304/306 [============================>.] - ETA: 0s - loss: 1.1957 - categorical_accuracy: 0.4854
# Epoch 00050: val_categorical_accuracy did not improve from 0.53606
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 306/306 [==============================] - 8s 28ms/step - loss: 1.1961 - categorical_accuracy: 0.4855 - val_loss: 1.1583 - val_categorical_accuracy: 0.5329 - lr: 3.2000e-07
# Epoch 51/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1970 - categorical_accuracy: 0.4889
# Epoch 00051: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1971 - categorical_accuracy: 0.4890 - val_loss: 1.1566 - val_categorical_accuracy: 0.5349 - lr: 6.4000e-08
# Epoch 52/100
# 305/306 [============================>.] - ETA: 0s - loss: 1.1978 - categorical_accuracy: 0.4868Restoring model weights from the end of the best epoch.
#
# Epoch 00052: val_categorical_accuracy did not improve from 0.53606
# 306/306 [==============================] - 8s 27ms/step - loss: 1.1976 - categorical_accuracy: 0.4870 - val_loss: 1.1563 - val_categorical_accuracy: 0.5334 - lr: 6.4000e-08
# Epoch 00052: early stopping
# CPU times: user 6min 58s, sys: 48.4 s, total: 7min 47s
# Wall time: 7min 25s

# %% [markdown]
# ## Results

# %%
#plotting Accuracy and Loss curves
plt.figure(figsize=(15,5))

plt.subplot(121)
plt.plot(history.history["categorical_accuracy"], label = 'Train Accuracy', color='slategray')
plt.plot(history.history["val_categorical_accuracy"], label = 'Validation Accuracy')
plt.title("Training and Validation Accuracy by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend();

plt.subplot(122)
plt.plot(history.history["loss"], label = 'Train Loss', color='slategray')
plt.plot(history.history["val_loss"], label = 'Validation Loss')
plt.title("Training and Validation Loss by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend();

# %%
#Code snippet credit: APEKSHA PRIYA, Priya Dwivedi
#confusion matrix and classification report

#validation generator with shuffle = false
validation_generator1 = val_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

class_labels = validation_generator1.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())

#Confusion Matrix and Classification Report
Y_pred = model.predict_generator(validation_generator1, validation_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
y_test = validation_generator1.classes

#Generate Confusion Matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
cnf_matrix.ravel

print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(y_test, y_pred, target_names=target_names))


#plot confusion matrix
plt.figure(figsize=(8,8))
ax= plt.subplot()
sns.heatmap(cnf_matrix, annot=True, ax = ax, cmap='bone_r', fmt='g', cbar=False)
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad'])
ax.yaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad']);
# Out:
# Found 4198 images belonging to 4 classes.
# WARNING:tensorflow:From <ipython-input-11-abdf88deab40>:18: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.30      0.03      0.05       544
#        happy       0.57      0.80      0.67      1665
#      neutral       0.50      0.63      0.56      1401
#          sad       0.38      0.03      0.06       588
#
#     accuracy                           0.54      4198
#    macro avg       0.44      0.37      0.33      4198
# weighted avg       0.49      0.54      0.47      4198
