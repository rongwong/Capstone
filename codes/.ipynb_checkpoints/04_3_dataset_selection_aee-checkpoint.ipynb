# %% [markdown]
# # 4.4 AEE Dataset Modeling

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Results:</b> This dataset did not out-perform the AE dataset.
#
# Go straight to [Results](#Results) for AEE Dataset
# </div>

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import classification_report, confusion_matrix


# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## Creating the Network of Best Model

# %%
#shaping X_train and X_test
train_data_dir = "../datasets/train_cropped_aee/train"
validation_data_dir = "../datasets/train_cropped_aee/val"
filepath = "../models/best_model_aee_cp.hdf5"

img_rows, img_cols = 48, 48
num_classes = 4
epochs = 100
batch_size = 64

# %%
#callbacks

checkpoint = ModelCheckpoint(filepath,
                             monitor='val_categorical_accuracy',
                             mode='max',
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_categorical_accuracy',
                          min_delta=0,
                          mode='auto',
                          patience=15,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = ReduceLROnPlateau(monitor='val_categorical_accuracy',
                              factor=0.2,
                              mode='auto',
                              patience=5,
                              verbose=1,
                              min_delta=0.001)

# callbacks = [checkpoint]
callbacks = [earlystop,checkpoint,reduce_lr]

# %%
#data augmentation for train dataset, normalize all 

val_datagen = ImageDataGenerator(rescale=1./255)

train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')


train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 19601 images belonging to 4 classes.
# Found 4198 images belonging to 4 classes.

# %%
global train_samples, validation_samples
train_samples = 19601
validation_samples = 4198


print(validation_generator.class_indices)
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
#Model
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation="relu", input_shape= (48,48,1)))
model.add(Conv2D(16, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Flatten())
model.add(Dense(4, activation="softmax"))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 16)        2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 128)         73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 2052
# =================================================================
# Total params: 286,036
# Trainable params: 286,036
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile model
model.compile(optimizer= Adam(lr=0.001, decay=1e-6),
              loss="categorical_crossentropy",
              metrics=["categorical_accuracy"])

# %%
# %%time

#fit model
history = model.fit_generator(
            train_generator,
            steps_per_epoch=train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From <timed exec>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2741 - categorical_accuracy: 0.3946
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.42284, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 85s 276ms/step - loss: 1.2741 - categorical_accuracy: 0.3946 - val_loss: 1.2534 - val_categorical_accuracy: 0.4228 - lr: 0.0010
# Epoch 2/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1663 - categorical_accuracy: 0.4963
# Epoch 00002: val_categorical_accuracy improved from 0.42284 to 0.59976, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 97s 317ms/step - loss: 1.1663 - categorical_accuracy: 0.4963 - val_loss: 0.9724 - val_categorical_accuracy: 0.5998 - lr: 0.0010
# Epoch 3/100
# 306/306 [==============================] - ETA: 0s - loss: 0.9905 - categorical_accuracy: 0.5938
# Epoch 00003: val_categorical_accuracy improved from 0.59976 to 0.65312, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 99s 324ms/step - loss: 0.9905 - categorical_accuracy: 0.5938 - val_loss: 0.8489 - val_categorical_accuracy: 0.6531 - lr: 0.0010
# Epoch 4/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8941 - categorical_accuracy: 0.6377
# Epoch 00004: val_categorical_accuracy improved from 0.65312 to 0.69087, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 98s 319ms/step - loss: 0.8941 - categorical_accuracy: 0.6377 - val_loss: 0.7671 - val_categorical_accuracy: 0.6909 - lr: 0.0010
# Epoch 5/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8425 - categorical_accuracy: 0.6584
# Epoch 00005: val_categorical_accuracy improved from 0.69087 to 0.69639, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 115s 377ms/step - loss: 0.8425 - categorical_accuracy: 0.6584 - val_loss: 0.7567 - val_categorical_accuracy: 0.6964 - lr: 0.0010
# Epoch 6/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8044 - categorical_accuracy: 0.6754
# Epoch 00006: val_categorical_accuracy improved from 0.69639 to 0.71755, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 115s 375ms/step - loss: 0.8044 - categorical_accuracy: 0.6754 - val_loss: 0.7111 - val_categorical_accuracy: 0.7175 - lr: 0.0010
# Epoch 7/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7841 - categorical_accuracy: 0.6831
# Epoch 00007: val_categorical_accuracy did not improve from 0.71755
# 306/306 [==============================] - 115s 374ms/step - loss: 0.7841 - categorical_accuracy: 0.6831 - val_loss: 0.7128 - val_categorical_accuracy: 0.7139 - lr: 0.0010
# Epoch 8/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7527 - categorical_accuracy: 0.6983
# Epoch 00008: val_categorical_accuracy improved from 0.71755 to 0.72788, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 115s 376ms/step - loss: 0.7527 - categorical_accuracy: 0.6983 - val_loss: 0.6923 - val_categorical_accuracy: 0.7279 - lr: 0.0010
# Epoch 9/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7416 - categorical_accuracy: 0.7054
# Epoch 00009: val_categorical_accuracy improved from 0.72788 to 0.73077, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 114s 373ms/step - loss: 0.7416 - categorical_accuracy: 0.7054 - val_loss: 0.7135 - val_categorical_accuracy: 0.7308 - lr: 0.0010
# Epoch 10/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7239 - categorical_accuracy: 0.7112
# Epoch 00010: val_categorical_accuracy improved from 0.73077 to 0.73702, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 116s 378ms/step - loss: 0.7239 - categorical_accuracy: 0.7112 - val_loss: 0.6672 - val_categorical_accuracy: 0.7370 - lr: 0.0010
# Epoch 11/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7127 - categorical_accuracy: 0.7147
# Epoch 00011: val_categorical_accuracy improved from 0.73702 to 0.74615, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 115s 376ms/step - loss: 0.7127 - categorical_accuracy: 0.7147 - val_loss: 0.6395 - val_categorical_accuracy: 0.7462 - lr: 0.0010
# Epoch 12/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6939 - categorical_accuracy: 0.7257
# Epoch 00012: val_categorical_accuracy improved from 0.74615 to 0.74712, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 116s 378ms/step - loss: 0.6939 - categorical_accuracy: 0.7257 - val_loss: 0.6377 - val_categorical_accuracy: 0.7471 - lr: 0.0010
# Epoch 13/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6816 - categorical_accuracy: 0.7342
# Epoch 00013: val_categorical_accuracy improved from 0.74712 to 0.75000, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 116s 379ms/step - loss: 0.6816 - categorical_accuracy: 0.7342 - val_loss: 0.6295 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 14/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6744 - categorical_accuracy: 0.7368
# Epoch 00014: val_categorical_accuracy improved from 0.75000 to 0.75577, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 116s 380ms/step - loss: 0.6744 - categorical_accuracy: 0.7368 - val_loss: 0.6246 - val_categorical_accuracy: 0.7558 - lr: 0.0010
# Epoch 15/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6680 - categorical_accuracy: 0.7386
# Epoch 00015: val_categorical_accuracy did not improve from 0.75577
# 306/306 [==============================] - 116s 380ms/step - loss: 0.6680 - categorical_accuracy: 0.7386 - val_loss: 0.6484 - val_categorical_accuracy: 0.7493 - lr: 0.0010
# Epoch 16/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6561 - categorical_accuracy: 0.7426
# Epoch 00016: val_categorical_accuracy did not improve from 0.75577
# 306/306 [==============================] - 116s 379ms/step - loss: 0.6561 - categorical_accuracy: 0.7426 - val_loss: 0.6286 - val_categorical_accuracy: 0.7555 - lr: 0.0010
# Epoch 17/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6502 - categorical_accuracy: 0.7486
# Epoch 00017: val_categorical_accuracy improved from 0.75577 to 0.75697, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 116s 378ms/step - loss: 0.6502 - categorical_accuracy: 0.7486 - val_loss: 0.6278 - val_categorical_accuracy: 0.7570 - lr: 0.0010
# Epoch 18/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6398 - categorical_accuracy: 0.7507
# Epoch 00018: val_categorical_accuracy did not improve from 0.75697
# 306/306 [==============================] - 115s 376ms/step - loss: 0.6398 - categorical_accuracy: 0.7507 - val_loss: 0.6288 - val_categorical_accuracy: 0.7524 - lr: 0.0010
# Epoch 19/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6415 - categorical_accuracy: 0.7498
# Epoch 00019: val_categorical_accuracy did not improve from 0.75697
# 306/306 [==============================] - 116s 380ms/step - loss: 0.6415 - categorical_accuracy: 0.7498 - val_loss: 0.6214 - val_categorical_accuracy: 0.7534 - lr: 0.0010
# Epoch 20/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6393 - categorical_accuracy: 0.7552
# Epoch 00020: val_categorical_accuracy improved from 0.75697 to 0.76082, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 116s 378ms/step - loss: 0.6393 - categorical_accuracy: 0.7552 - val_loss: 0.5947 - val_categorical_accuracy: 0.7608 - lr: 0.0010
# Epoch 21/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6310 - categorical_accuracy: 0.7584
# Epoch 00021: val_categorical_accuracy did not improve from 0.76082
# 306/306 [==============================] - 116s 379ms/step - loss: 0.6310 - categorical_accuracy: 0.7584 - val_loss: 0.6182 - val_categorical_accuracy: 0.7548 - lr: 0.0010
# Epoch 22/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6226 - categorical_accuracy: 0.7588
# Epoch 00022: val_categorical_accuracy improved from 0.76082 to 0.76635, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 116s 381ms/step - loss: 0.6226 - categorical_accuracy: 0.7588 - val_loss: 0.6022 - val_categorical_accuracy: 0.7663 - lr: 0.0010
# Epoch 23/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6275 - categorical_accuracy: 0.7569
# Epoch 00023: val_categorical_accuracy did not improve from 0.76635
# 306/306 [==============================] - 117s 381ms/step - loss: 0.6275 - categorical_accuracy: 0.7569 - val_loss: 0.6094 - val_categorical_accuracy: 0.7608 - lr: 0.0010
# Epoch 24/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6197 - categorical_accuracy: 0.7623
# Epoch 00024: val_categorical_accuracy did not improve from 0.76635
# 306/306 [==============================] - 116s 378ms/step - loss: 0.6197 - categorical_accuracy: 0.7623 - val_loss: 0.5968 - val_categorical_accuracy: 0.7647 - lr: 0.0010
# Epoch 25/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6150 - categorical_accuracy: 0.7623
# Epoch 00025: val_categorical_accuracy did not improve from 0.76635
# 306/306 [==============================] - 117s 383ms/step - loss: 0.6150 - categorical_accuracy: 0.7623 - val_loss: 0.6037 - val_categorical_accuracy: 0.7608 - lr: 0.0010
# Epoch 26/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6073 - categorical_accuracy: 0.7676
# Epoch 00026: val_categorical_accuracy improved from 0.76635 to 0.77308, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 117s 382ms/step - loss: 0.6073 - categorical_accuracy: 0.7676 - val_loss: 0.5892 - val_categorical_accuracy: 0.7731 - lr: 0.0010
# Epoch 27/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6049 - categorical_accuracy: 0.7665
# Epoch 00027: val_categorical_accuracy did not improve from 0.77308
# 306/306 [==============================] - 116s 379ms/step - loss: 0.6049 - categorical_accuracy: 0.7665 - val_loss: 0.5976 - val_categorical_accuracy: 0.7668 - lr: 0.0010
# Epoch 28/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6078 - categorical_accuracy: 0.7647
# Epoch 00028: val_categorical_accuracy did not improve from 0.77308
# 306/306 [==============================] - 116s 380ms/step - loss: 0.6078 - categorical_accuracy: 0.7647 - val_loss: 0.6016 - val_categorical_accuracy: 0.7690 - lr: 0.0010
# Epoch 29/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5954 - categorical_accuracy: 0.7719
# Epoch 00029: val_categorical_accuracy did not improve from 0.77308
# 306/306 [==============================] - 117s 383ms/step - loss: 0.5954 - categorical_accuracy: 0.7719 - val_loss: 0.6259 - val_categorical_accuracy: 0.7639 - lr: 0.0010
# Epoch 30/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5937 - categorical_accuracy: 0.7706
# Epoch 00030: val_categorical_accuracy improved from 0.77308 to 0.77404, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 115s 377ms/step - loss: 0.5937 - categorical_accuracy: 0.7706 - val_loss: 0.5880 - val_categorical_accuracy: 0.7740 - lr: 0.0010
# Epoch 31/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5957 - categorical_accuracy: 0.7723
# Epoch 00031: val_categorical_accuracy did not improve from 0.77404
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 306/306 [==============================] - 116s 379ms/step - loss: 0.5957 - categorical_accuracy: 0.7723 - val_loss: 0.6282 - val_categorical_accuracy: 0.7570 - lr: 0.0010
# Epoch 32/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5639 - categorical_accuracy: 0.7861
# Epoch 00032: val_categorical_accuracy improved from 0.77404 to 0.77740, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 117s 384ms/step - loss: 0.5639 - categorical_accuracy: 0.7861 - val_loss: 0.5718 - val_categorical_accuracy: 0.7774 - lr: 2.0000e-04
# Epoch 33/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5455 - categorical_accuracy: 0.7939
# Epoch 00033: val_categorical_accuracy improved from 0.77740 to 0.78125, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 116s 379ms/step - loss: 0.5455 - categorical_accuracy: 0.7939 - val_loss: 0.5629 - val_categorical_accuracy: 0.7812 - lr: 2.0000e-04
# Epoch 34/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5408 - categorical_accuracy: 0.7908
# Epoch 00034: val_categorical_accuracy improved from 0.78125 to 0.78486, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 117s 383ms/step - loss: 0.5408 - categorical_accuracy: 0.7908 - val_loss: 0.5634 - val_categorical_accuracy: 0.7849 - lr: 2.0000e-04
# Epoch 35/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5417 - categorical_accuracy: 0.7942
# Epoch 00035: val_categorical_accuracy did not improve from 0.78486
# 306/306 [==============================] - 115s 377ms/step - loss: 0.5417 - categorical_accuracy: 0.7942 - val_loss: 0.5779 - val_categorical_accuracy: 0.7745 - lr: 2.0000e-04
# Epoch 36/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5375 - categorical_accuracy: 0.7932
# Epoch 00036: val_categorical_accuracy did not improve from 0.78486
# 306/306 [==============================] - 116s 379ms/step - loss: 0.5375 - categorical_accuracy: 0.7932 - val_loss: 0.5670 - val_categorical_accuracy: 0.7829 - lr: 2.0000e-04
# Epoch 37/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5306 - categorical_accuracy: 0.7981
# Epoch 00037: val_categorical_accuracy improved from 0.78486 to 0.78822, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 116s 381ms/step - loss: 0.5306 - categorical_accuracy: 0.7981 - val_loss: 0.5542 - val_categorical_accuracy: 0.7882 - lr: 2.0000e-04
# Epoch 38/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5285 - categorical_accuracy: 0.8000
# Epoch 00038: val_categorical_accuracy did not improve from 0.78822
# 306/306 [==============================] - 117s 381ms/step - loss: 0.5285 - categorical_accuracy: 0.8000 - val_loss: 0.5664 - val_categorical_accuracy: 0.7827 - lr: 2.0000e-04
# Epoch 39/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5332 - categorical_accuracy: 0.7954
# Epoch 00039: val_categorical_accuracy did not improve from 0.78822
# 306/306 [==============================] - 117s 384ms/step - loss: 0.5332 - categorical_accuracy: 0.7954 - val_loss: 0.5779 - val_categorical_accuracy: 0.7757 - lr: 2.0000e-04
# Epoch 40/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5228 - categorical_accuracy: 0.8029
# Epoch 00040: val_categorical_accuracy improved from 0.78822 to 0.78918, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 118s 384ms/step - loss: 0.5228 - categorical_accuracy: 0.8029 - val_loss: 0.5563 - val_categorical_accuracy: 0.7892 - lr: 2.0000e-04
# Epoch 41/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5259 - categorical_accuracy: 0.8000
# Epoch 00041: val_categorical_accuracy did not improve from 0.78918
# 306/306 [==============================] - 117s 382ms/step - loss: 0.5259 - categorical_accuracy: 0.8000 - val_loss: 0.5633 - val_categorical_accuracy: 0.7841 - lr: 2.0000e-04
# Epoch 42/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5167 - categorical_accuracy: 0.8040
# Epoch 00042: val_categorical_accuracy did not improve from 0.78918
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 306/306 [==============================] - 116s 379ms/step - loss: 0.5167 - categorical_accuracy: 0.8040 - val_loss: 0.5583 - val_categorical_accuracy: 0.7880 - lr: 2.0000e-04
# Epoch 43/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5102 - categorical_accuracy: 0.8090
# Epoch 00043: val_categorical_accuracy did not improve from 0.78918
# 306/306 [==============================] - 117s 381ms/step - loss: 0.5102 - categorical_accuracy: 0.8090 - val_loss: 0.5578 - val_categorical_accuracy: 0.7875 - lr: 4.0000e-05
# Epoch 44/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5155 - categorical_accuracy: 0.8065
# Epoch 00044: val_categorical_accuracy did not improve from 0.78918
# 306/306 [==============================] - 110s 358ms/step - loss: 0.5155 - categorical_accuracy: 0.8065 - val_loss: 0.5569 - val_categorical_accuracy: 0.7880 - lr: 4.0000e-05
# Epoch 45/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5114 - categorical_accuracy: 0.8071
# Epoch 00045: val_categorical_accuracy did not improve from 0.78918
# 306/306 [==============================] - 93s 304ms/step - loss: 0.5114 - categorical_accuracy: 0.8071 - val_loss: 0.5561 - val_categorical_accuracy: 0.7887 - lr: 4.0000e-05
# Epoch 46/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5107 - categorical_accuracy: 0.8037
# Epoch 00046: val_categorical_accuracy improved from 0.78918 to 0.78990, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 93s 303ms/step - loss: 0.5107 - categorical_accuracy: 0.8037 - val_loss: 0.5571 - val_categorical_accuracy: 0.7899 - lr: 4.0000e-05
# Epoch 47/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5087 - categorical_accuracy: 0.8059
# Epoch 00047: val_categorical_accuracy did not improve from 0.78990
# 306/306 [==============================] - 93s 304ms/step - loss: 0.5087 - categorical_accuracy: 0.8059 - val_loss: 0.5586 - val_categorical_accuracy: 0.7851 - lr: 4.0000e-05
# Epoch 48/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5062 - categorical_accuracy: 0.8072
# Epoch 00048: val_categorical_accuracy improved from 0.78990 to 0.79207, saving model to ../models/best_model_aee_cp.hdf5
# 306/306 [==============================] - 93s 306ms/step - loss: 0.5062 - categorical_accuracy: 0.8072 - val_loss: 0.5539 - val_categorical_accuracy: 0.7921 - lr: 4.0000e-05
# Epoch 49/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5071 - categorical_accuracy: 0.8097
# Epoch 00049: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 93s 303ms/step - loss: 0.5071 - categorical_accuracy: 0.8097 - val_loss: 0.5564 - val_categorical_accuracy: 0.7858 - lr: 4.0000e-05
# Epoch 50/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5098 - categorical_accuracy: 0.8052
# Epoch 00050: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 93s 304ms/step - loss: 0.5098 - categorical_accuracy: 0.8052 - val_loss: 0.5515 - val_categorical_accuracy: 0.7887 - lr: 4.0000e-05
# Epoch 51/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5127 - categorical_accuracy: 0.8066
# Epoch 00051: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 94s 308ms/step - loss: 0.5127 - categorical_accuracy: 0.8066 - val_loss: 0.5528 - val_categorical_accuracy: 0.7906 - lr: 4.0000e-05
# Epoch 52/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5050 - categorical_accuracy: 0.8065
# Epoch 00052: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 92s 302ms/step - loss: 0.5050 - categorical_accuracy: 0.8065 - val_loss: 0.5540 - val_categorical_accuracy: 0.7904 - lr: 4.0000e-05
# Epoch 53/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5042 - categorical_accuracy: 0.8088
# Epoch 00053: val_categorical_accuracy did not improve from 0.79207
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 306/306 [==============================] - 93s 304ms/step - loss: 0.5042 - categorical_accuracy: 0.8088 - val_loss: 0.5559 - val_categorical_accuracy: 0.7885 - lr: 4.0000e-05
# Epoch 54/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5043 - categorical_accuracy: 0.8085
# Epoch 00054: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 93s 305ms/step - loss: 0.5043 - categorical_accuracy: 0.8085 - val_loss: 0.5564 - val_categorical_accuracy: 0.7899 - lr: 8.0000e-06
# Epoch 55/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5087 - categorical_accuracy: 0.8078
# Epoch 00055: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 93s 305ms/step - loss: 0.5087 - categorical_accuracy: 0.8078 - val_loss: 0.5546 - val_categorical_accuracy: 0.7906 - lr: 8.0000e-06
# Epoch 56/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5021 - categorical_accuracy: 0.8106
# Epoch 00056: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 93s 305ms/step - loss: 0.5021 - categorical_accuracy: 0.8106 - val_loss: 0.5563 - val_categorical_accuracy: 0.7885 - lr: 8.0000e-06
# Epoch 57/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5044 - categorical_accuracy: 0.8076
# Epoch 00057: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 77s 253ms/step - loss: 0.5044 - categorical_accuracy: 0.8076 - val_loss: 0.5564 - val_categorical_accuracy: 0.7897 - lr: 8.0000e-06
# Epoch 58/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5013 - categorical_accuracy: 0.8124
# Epoch 00058: val_categorical_accuracy did not improve from 0.79207
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 306/306 [==============================] - 70s 230ms/step - loss: 0.5013 - categorical_accuracy: 0.8124 - val_loss: 0.5529 - val_categorical_accuracy: 0.7901 - lr: 8.0000e-06
# Epoch 59/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5064 - categorical_accuracy: 0.8089
# Epoch 00059: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 70s 230ms/step - loss: 0.5064 - categorical_accuracy: 0.8089 - val_loss: 0.5538 - val_categorical_accuracy: 0.7909 - lr: 1.6000e-06
# Epoch 60/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5040 - categorical_accuracy: 0.8083
# Epoch 00060: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 54s 177ms/step - loss: 0.5040 - categorical_accuracy: 0.8083 - val_loss: 0.5533 - val_categorical_accuracy: 0.7904 - lr: 1.6000e-06
# Epoch 61/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5023 - categorical_accuracy: 0.8086
# Epoch 00061: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 49s 159ms/step - loss: 0.5023 - categorical_accuracy: 0.8086 - val_loss: 0.5545 - val_categorical_accuracy: 0.7911 - lr: 1.6000e-06
# Epoch 62/100
# 306/306 [==============================] - ETA: 0s - loss: 0.4994 - categorical_accuracy: 0.8121
# Epoch 00062: val_categorical_accuracy did not improve from 0.79207
# 306/306 [==============================] - 49s 159ms/step - loss: 0.4994 - categorical_accuracy: 0.8121 - val_loss: 0.5555 - val_categorical_accuracy: 0.7906 - lr: 1.6000e-06
# Epoch 63/100
# 306/306 [==============================] - ETA: 0s - loss: 0.4986 - categorical_accuracy: 0.8086Restoring model weights from the end of the best epoch.
#
# Epoch 00063: val_categorical_accuracy did not improve from 0.79207
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 306/306 [==============================] - 49s 160ms/step - loss: 0.4986 - categorical_accuracy: 0.8086 - val_loss: 0.5546 - val_categorical_accuracy: 0.7909 - lr: 1.6000e-06
# Epoch 00063: early stopping
# CPU times: user 2h 45min 37s, sys: 27min 10s, total: 3h 12min 47s
# Wall time: 1h 49min 38s

# %% [markdown]
# ## Results

# %%
#plotting Accuracy and Loss curves
plt.figure(figsize=(15,5))

plt.subplot(121)
plt.plot(history.history["categorical_accuracy"], label = 'Train Accuracy', color='gold')
plt.plot(history.history["val_categorical_accuracy"], label = 'Validation Accuracy', color='slategrey')
plt.title("Training and Validation Accuracy by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend();

plt.subplot(122)
plt.plot(history.history["loss"], label = 'Train Loss', color='gold')
plt.plot(history.history["val_loss"], label = 'Validation Loss', color='slategrey')
plt.title("Training and Validation Loss by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend();

# %%
#Code snippet credit: APEKSHA PRIYA, Priya Dwivedi
#confusion matrix and classification report

#validation generator with shuffle = false
validation_generator1 = val_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

class_labels = validation_generator1.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())

#Confusion Matrix and Classification Report
Y_pred = model.predict_generator(validation_generator1, validation_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
y_test = validation_generator1.classes

#Generate Confusion Matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
cnf_matrix.ravel

print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(y_test, y_pred, target_names=target_names))


#plot confusion matrix
plt.figure(figsize=(8,8))
ax= plt.subplot()
sns.heatmap(cnf_matrix, annot=True, ax = ax, cmap='bone_r', fmt='g', cbar=False)
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad'])
ax.yaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad']);
# Out:
# Found 4198 images belonging to 4 classes.
# WARNING:tensorflow:From <ipython-input-10-6561d12b4ec9>:18: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.74      0.65      0.69       544
#        happy       0.89      0.90      0.89      1665
#      neutral       0.75      0.82      0.79      1401
#          sad       0.64      0.55      0.59       588
#
#     accuracy                           0.79      4198
#    macro avg       0.76      0.73      0.74      4198
# weighted avg       0.79      0.79      0.79      4198
