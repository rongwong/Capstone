# %% [markdown]
# credits: APEKSHA PRIYA, Priya Dwivedi
#
# https://github.com/priya-dwivedi/face_and_emotion_detection/blob/master/src/EmotionDetector_v2.ipynb
# https://towardsdatascience.com/face-detection-recognition-and-emotion-detection-in-8-lines-of-code-b2ce32d4d5de

# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

# from keras.models import Sequential
# from keras.layers.normalization import BatchNormalization
# from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.advanced_activations import ELU
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras.optimizers import RMSprop, SGD, Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import regularizers
from keras.regularizers import l1

from keras.models import load_model

import cv2
import random
import numpy as np
# import os, os.path
# import glob
# from skimage.feature import Cascade
# import skimage 
# from skimage import data, color
# import matplotlib.pyplot as plt
# from PIL import Image

# %%
# initializing
num_classes = 4
img_rows, img_cols = 48, 48
batch_size = 200 #(change back for full load)

train_data_dir = '../test_full/train_cropped'
validation_data_dir = '../test_full/validation'

# %%
# Let's use some data augmentaiton 
# train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 27800 images belonging to 4 classes.
# Found 2590 images belonging to 4 classes.

# %%
print(validation_generator.class_indices)
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
# Create the model 2
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(48,48,1)))
# model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# # model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(2, 2), activation='relu'))
# model.add(BatchNormalization())

model.add(Flatten())

model.add(Dense(120, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))
#model.add(Activation("softmax"))

model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())
# model.add(Activation("softmax"))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 46, 46, 32)        320
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 1, 128)         131200
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               15480
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 484
# =================================================================
# Total params: 1,125,084
# Trainable params: 1,125,084
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # Create the model
# model = Sequential()

# model.add(Conv2D(32, kernel_size=(3, 3), activation='elu',input_shape=(48,48,1)))
# # model.add(BatchNormalization())

# model.add(Conv2D(64, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(128, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(256, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(64, kernel_size=(1, 1), activation='elu'))
# # # model.add(BatchNormalization())

# model.add(Conv2D(3, kernel_size=(4, 4), activation='elu'))
# # model.add(BatchNormalization())

# model.add(Flatten())

# model.add(Activation("softmax"))

# model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())

# %%
# %%time
# If you want to train the same model or try other models, go for this


# filepath = os.path.join("./emotion_detector_models/model_v6_{epoch}.hdf5")

checkpoint = keras.callbacks.ModelCheckpoint('rong_test_2_7.hdf5',
                                             monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                             mode='max')

callbacks = [checkpoint]

# checkpoint = ModelCheckpoint('rong_test_2.hdf5',
#                              monitor='val_loss',
#                              mode='min',
#                              save_best_only=True,
#                              verbose=1)

# earlystop = EarlyStopping(monitor='val_loss',
#                           min_delta=0,
#                           patience=9,
#                           verbose=1,
#                           restore_best_weights=True
#                           )

# reduce_lr = ReduceLROnPlateau(monitor='val_loss',
#                               factor=0.2,
#                               patience=3,
#                               verbose=1,
#                               min_delta=0.0001)

# callbacks = [checkpoint,reduce_lr]
# callbacks = [earlystop,checkpoint,reduce_lr]


# if mode == "train":
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001, decay=1e-6),metrics=['accuracy'])
nb_train_samples = 27800
nb_validation_samples = 2590
epochs = 200

model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)

# plot_model_history(model_info)
model.save_weights('rong_test_2_7_weights.h5')
model.save('rong_test_2_7model_file.h5')
# Out:
# Epoch 1/200
# 139/139 [==============================] - ETA: 0s - loss: 1.3309 - accuracy: 0.3655
# Epoch 00001: val_accuracy improved from -inf to 0.36000, saving model to rong_test_2_7.hdf5
# 139/139 [==============================] - 77s 557ms/step - loss: 1.3309 - accuracy: 0.3655 - val_loss: 1.3581 - val_accuracy: 0.3600
# Epoch 2/200
# 139/139 [==============================] - ETA: 0s - loss: 1.2544 - accuracy: 0.4296
# Epoch 00002: val_accuracy improved from 0.36000 to 0.40875, saving model to rong_test_2_7.hdf5
# 139/139 [==============================] - 78s 559ms/step - loss: 1.2544 - accuracy: 0.4296 - val_loss: 1.2846 - val_accuracy: 0.4087
# Epoch 3/200
# 139/139 [==============================] - ETA: 0s - loss: 1.1352 - accuracy: 0.5100
# Epoch 00003: val_accuracy improved from 0.40875 to 0.45167, saving model to rong_test_2_7.hdf5
# 139/139 [==============================] - 77s 552ms/step - loss: 1.1352 - accuracy: 0.5100 - val_loss: 1.2291 - val_accuracy: 0.4517
# Epoch 4/200
# 139/139 [==============================] - ETA: 0s - loss: 1.0553 - accuracy: 0.5425
# Epoch 00004: val_accuracy improved from 0.45167 to 0.48292, saving model to rong_test_2_7.hdf5
# 139/139 [==============================] - 93s 668ms/step - loss: 1.0553 - accuracy: 0.5425 - val_loss: 1.2333 - val_accuracy: 0.4829
# Epoch 5/200
# 139/139 [==============================] - ETA: 0s - loss: 0.9913 - accuracy: 0.5784
# Epoch 00005: val_accuracy improved from 0.48292 to 0.52167, saving model to rong_test_2_7.hdf5
# 139/139 [==============================] - 87s 626ms/step - loss: 0.9913 - accuracy: 0.5784 - val_loss: 1.2237 - val_accuracy: 0.5217
# Epoch 6/200
# 139/139 [==============================] - ETA: 0s - loss: 0.9438 - accuracy: 0.6037
# Epoch 00006: val_accuracy did not improve from 0.52167
# 139/139 [==============================] - 76s 549ms/step - loss: 0.9438 - accuracy: 0.6037 - val_loss: 1.2417 - val_accuracy: 0.5108
# Epoch 7/200
# 139/139 [==============================] - ETA: 0s - loss: 0.8969 - accuracy: 0.6255
# Epoch 00007: val_accuracy improved from 0.52167 to 0.53833, saving model to rong_test_2_7.hdf5
# 139/139 [==============================] - 78s 561ms/step - loss: 0.8969 - accuracy: 0.6255 - val_loss: 1.2387 - val_accuracy: 0.5383
# Epoch 8/200
# 139/139 [==============================] - ETA: 0s - loss: 0.8635 - accuracy: 0.6426
# Epoch 00008: val_accuracy did not improve from 0.53833
# 139/139 [==============================] - 79s 569ms/step - loss: 0.8635 - accuracy: 0.6426 - val_loss: 1.2130 - val_accuracy: 0.5375
# Epoch 9/200
# 139/139 [==============================] - ETA: 0s - loss: 0.8344 - accuracy: 0.6578
# Epoch 00009: val_accuracy improved from 0.53833 to 0.56833, saving model to rong_test_2_7.hdf5
# 139/139 [==============================] - 80s 574ms/step - loss: 0.8344 - accuracy: 0.6578 - val_loss: 1.2185 - val_accuracy: 0.5683
# Epoch 10/200
# 139/139 [==============================] - ETA: 0s - loss: 0.8163 - accuracy: 0.6681
# Epoch 00010: val_accuracy did not improve from 0.56833
# 139/139 [==============================] - 79s 566ms/step - loss: 0.8163 - accuracy: 0.6681 - val_loss: 1.1808 - val_accuracy: 0.5679
# Epoch 11/200
# 139/139 [==============================] - ETA: 0s - loss: 0.7925 - accuracy: 0.6795
# Epoch 00011: val_accuracy improved from 0.56833 to 0.56958, saving model to rong_test_2_7.hdf5
# 139/139 [==============================] - 81s 580ms/step - loss: 0.7925 - accuracy: 0.6795 - val_loss: 1.2164 - val_accuracy: 0.5696
# Epoch 12/200
# 139/139 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.62333
# 139/139 [==============================] - 75s 540ms/step - loss: 0.5713 - accuracy: 0.7741 - val_loss: 1.2774 - val_accuracy: 0.6125
# Epoch 58/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5749 - accuracy: 0.7783
# Epoch 00058: val_accuracy did not improve from 0.62333
# 139/139 [==============================] - 75s 541ms/step - loss: 0.5749 - accuracy: 0.7783 - val_loss: 1.4471 - val_accuracy: 0.6067
# Epoch 59/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5678 - accuracy: 0.7767
# Epoch 00059: val_accuracy did not improve from 0.62333
# 139/139 [==============================] - 75s 541ms/step - loss: 0.5678 - accuracy: 0.7767 - val_loss: 1.3589 - val_accuracy: 0.6129
# Epoch 60/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5658 - accuracy: 0.7801
# Epoch 00060: val_accuracy did not improve from 0.62333
# 139/139 [==============================] - 76s 543ms/step - loss: 0.5658 - accuracy: 0.7801 - val_loss: 1.3033 - val_accuracy: 0.6100
# Epoch 61/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5639 - accuracy: 0.7784
# Epoch 00061: val_accuracy did not improve from 0.62333
# 139/139 [==============================] - 75s 541ms/step - loss: 0.5639 - accuracy: 0.7784 - val_loss: 1.3360 - val_accuracy: 0.6075
# Epoch 62/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5650 - accuracy: 0.7829
# Epoch 00062: val_accuracy did not improve from 0.62333
# 139/139 [==============================] - 76s 548ms/step - loss: 0.5650 - accuracy: 0.7829 - val_loss: 1.2417 - val_accuracy: 0.6142
# Epoch 63/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5669 - accuracy: 0.7786
# Epoch 00063: val_accuracy did not improve from 0.62333
# 139/139 [==============================] - 76s 546ms/step - loss: 0.5669 - accuracy: 0.7786 - val_loss: 1.3616 - val_accuracy: 0.5921
# Epoch 64/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5606 - accuracy: 0.7806
# Epoch 00064: val_accuracy did not improve from 0.62333
# 139/139 [==============================] - 75s 541ms/step - loss: 0.5606 - accuracy: 0.7806 - val_loss: 1.3160 - val_accuracy: 0.6233
# Epoch 65/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5573 - accuracy: 0.7828
# Epoch 00065: val_accuracy did not improve from 0.62333
# 139/139 [==============================] - 75s 541ms/step - loss: 0.5573 - accuracy: 0.7828 - val_loss: 1.3835 - val_accuracy: 0.6025
# Epoch 66/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5548 - accuracy: 0.7851
# Epoch 00066: val_accuracy improved from 0.62333 to 0.62458, saving model to rong_test_2_7.hdf5
# 139/139 [==============================] - 75s 541ms/step - loss: 0.5548 - accuracy: 0.7851 - val_loss: 1.3811 - val_accuracy: 0.6246
# Epoch 67/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5563 - accuracy: 0.7846
# Epoch 00067: val_accuracy did not improve from 0.62458
# 139/139 [==============================] - 75s 541ms/step - loss: 0.5563 - accuracy: 0.7846 - val_loss: 1.4597 - val_accuracy: 0.6054
# Epoch 68/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5510 - accuracy: 0.7837
# Epoch 00068: val_accuracy did not improve from 0.62458
# 139/139 [==============================] - 75s 541ms/step - loss: 0.5510 - accuracy: 0.7837 - val_loss: 1.3977 - val_accuracy: 0.6133
# Epoch 69/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5450 - accuracy: 0.7901
# Epoch 00069: val_accuracy did not improve from 0.62458
# 139/139 [==============================] - 75s 540ms/step - loss: 0.5450 - accuracy: 0.7901 - val_loss: 1.4185 - val_accuracy: 0.6150
# Epoch 70/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5485 - accuracy: 0.7874
# Epoch 00070: val_accuracy did not improve from 0.62458
# 139/139 [==============================] - 75s 539ms/step - loss: 0.5485 - accuracy: 0.7874 - val_loss: 1.3290 - val_accuracy: 0.6037
# Epoch 71/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5453 - accuracy: 0.7888
# Epoch 00071: val_accuracy did not improve from 0.62458
# 139/139 [==============================] - 75s 539ms/step - loss: 0.5453 - accuracy: 0.7888 - val_loss: 1.3370 - val_accuracy: 0.6037
# Epoch 72/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5445 - accuracy: 0.7869
# Epoch 00072: val_accuracy did not improve from 0.62458
# 139/139 [==============================] - 75s 540ms/step - loss: 0.5445 - accuracy: 0.7869 - val_loss: 1.3721 - val_accuracy: 0.6150
# Epoch 73/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5439 - accuracy: 0.7911
# Epoch 00073: val_accuracy improved from 0.62458 to 0.62500, saving model to rong_test_2_7.hdf5
# 139/139 [==============================] - 75s 541ms/step - loss: 0.5439 - accuracy: 0.7911 - val_loss: 1.4324 - val_accuracy: 0.6250
# Epoch 74/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5416 - accuracy: 0.7914
# Epoch 00074: val_accuracy did not improve from 0.62500
# 139/139 [==============================] - 75s 539ms/step - loss: 0.5416 - accuracy: 0.7914 - val_loss: 1.4499 - val_accuracy: 0.6162
# Epoch 75/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5355 - accuracy: 0.7928
# Epoch 00075: val_accuracy did not improve from 0.62500
# 139/139 [==============================] - 75s 540ms/step - loss: 0.5355 - accuracy: 0.7928 - val_loss: 1.3847 - val_accuracy: 0.6225
# Epoch 76/200
# 139/139 [==============================] - ETA: 0s - loss: 0.5412 - accuracy: 0.7899
# Epoch 00076: val_accuracy did not improve from 0.62500
# 139/139 [==============================] - 75s 540ms/step - loss: 0.
[==============================] - ETA: 0s - loss: 0.4060 - accuracy: 0.8420
# Epoch 00200: val_accuracy did not improve from 0.62750
# 139/139 [==============================] - 75s 536ms/step - loss: 0.4060 - accuracy: 0.8420 - val_loss: 1.9946 - val_accuracy: 0.6179
# CPU times: user 1d 2h 28min 23s, sys: 1h 16min 52s, total: 1d 3h 45min 16s
# Wall time: 4h 14min 47s

# %%
print(model_info.history.keys())

import matplotlib.pyplot as plt
plt.plot(model_info.history['loss'])
plt.plot(model_info.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# model.load_weights('rong_test_2_5.h5')

# %%
# model_info = model.fit_generator(
#             train_generator,
#             steps_per_epoch=nb_train_samples // batch_size,
#             epochs=epochs,
#             callbacks = callbacks,
#             validation_data=validation_generator,
#             validation_steps=nb_validation_samples // batch_size)

# %%
# plt.plot(model_info.history['loss'])
# plt.plot(model_info.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
# model.load_weights('rong_test_2.h5')
# # history = model.fit_generator(
# #     train_generator,
# #     steps_per_epoch = nb_train_samples // batch_size,
# #     epochs = epochs,
# #     callbacks = callbacks,
# #     validation_data = validation_generator,
# #     validation_steps = nb_validation_samples // batch_size)

# %%
# import matplotlib.pyplot as plt
# import sklearn
# from sklearn.metrics import classification_report, confusion_matrix
# import numpy as np
# # Found 28709 images belonging to 7 classes.
# # Found 3589 images belonging to 7 classes.


# # nb_train_samples = 28273
# # nb_validation_samples = 3534
# nb_train_samples = 140
# nb_validation_samples = 70

# # We need to recreate our validation generator with shuffle = false
# validation_generator = val_datagen.flow_from_directory(
#         validation_data_dir,
#         color_mode = 'grayscale',
#         target_size=(img_rows, img_cols),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=False)

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# #Confution Matrix and Classification Report
# Y_pred = model.predict_generator(validation_generator, nb_validation_samples // batch_size+1)
# y_pred = np.argmax(Y_pred, axis=1)

# print('Confusion Matrix')
# print(confusion_matrix(validation_generator.classes, y_pred))
# print('Classification Report')
# target_names = list(class_labels.values())
# print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# plt.figure(figsize=(8,8))
# cnf_matrix = confusion_matrix(validation_generator.classes, y_pred)

# plt.imshow(cnf_matrix, interpolation='nearest')
# plt.colorbar()
# tick_marks = np.arange(len(classes))
# _ = plt.xticks(tick_marks, classes, rotation=90)
# _ = plt.yticks(tick_marks, classes)

# %%
# classifier = load_model('./emotion_detector_models/model_v3_71.hdf5')

# %%
# validation_generator = val_datagen.flow_from_directory(
#         validation_data_dir,
#         color_mode = 'grayscale',
#         target_size=(img_rows, img_cols),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=False)

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())
# print(class_labels)

# %%
# from keras.models import load_model
# from keras.optimizers import RMSprop, SGD, Adam
# from keras.preprocessing import image
# import numpy as np
# import os
# import cv2
# import numpy as np
# from os import listdir
# from os.path import isfile, join
# import re

# def draw_test(name, pred, im, true_label):
#     BLACK = [0,0,0]
#     expanded_image = cv2.copyMakeBorder(im, 160, 0, 0, 300 ,cv2.BORDER_CONSTANT,value=BLACK)
#     cv2.putText(expanded_image, "predited - "+ pred, (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,0,255), 2)
#     cv2.putText(expanded_image, "true - "+ true_label, (20, 120) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,255,0), 2)
#     cv2.imshow(name, expanded_image)


# def getRandomImage(path, img_width, img_height):
#     """function loads a random images from a random folder in our test path """
#     folders = path
#     random_directory = np.random.randint(0,len(folders))
#     path_class = folders[random_directory]
#     file_path = path
#     file_names = [f for f in listdir(file_path)]
#     random_file_index = np.random.randint(0,len(file_names))
#     image_name = file_names[random_file_index]
#     final_path = file_path + "/" + image_name
#     return image.load_img(final_path, target_size = (img_width, img_height),grayscale=True), final_path, path_class

# # dimensions of our images
# img_width, img_height = 48, 48

# # We use a very small learning rate 
# model.compile(loss = 'categorical_crossentropy',
#               optimizer = RMSprop(lr = 0.001),
#               metrics = ['accuracy'])

# files = []
# predictions = []
# true_labels = []

# # predicting images
# for i in range(0, 10):
#     path = '../non_load/fer2013/train' 
#     img, final_path, true_label = getRandomImage(path, img_width, img_height)
#     files.append(final_path)
#     true_labels.append(true_label)
#     x = image.img_to_array(img)
#     x = x * 1./255
#     x = np.expand_dims(x, axis=0)
#     images = np.vstack([x])
#     classes = model.predict_classes(images, batch_size = 10)
#     predictions.append(classes)
    
# for i in range(0, len(files)):
#     image = cv2.imread((files[i]))
#     image = cv2.resize(image, None, fx=3, fy=3, interpolation = cv2.INTER_CUBIC)
#     draw_test("Prediction", class_labels[predictions[i][0]], image, true_labels[i])
#     cv2.waitKey(0)

# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# from time import sleep
# from keras.preprocessing.image import img_to_array

# face_classifier = cv2.CascadeClassifier('../datasets/classifiers/haarcascade_frontalface_default.xml')
# classifier =load_model('rong_test_2_1.hdf5')

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# def face_detector(img):
#     # Convert image to grayscale
#     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#     faces = face_classifier.detectMultiScale(gray, 1.3, 5)
#     if faces is ():
#         return (0,0,0,0), np.zeros((48,48), np.uint8), img
    
#     for (x,y,w,h) in faces:
#         cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#         roi_gray = gray[y:y+h, x:x+w]

#     try:
#         roi_gray = cv2.resize(roi_gray, (48, 48), interpolation = cv2.INTER_AREA)
#     except:
#         return (x,w,y,h), np.zeros((48,48), np.uint8), img
#     return (x,w,y,h), roi_gray, img

# cap = cv2.VideoCapture(0)

# while True:

#     ret, frame = cap.read()
#     rect, face, image = face_detector(frame)
#     if np.sum([face]) != 0.0:
#         roi = face.astype("float") / 255.0
#         roi = img_to_array(roi)
#         roi = np.expand_dims(roi, axis=0)

#         # make a prediction on the ROI, then lookup the class
#         preds = classifier.predict(roi)[0]
#         label = class_labels[preds.argmax()]  
#         label_position = (rect[0] + int((rect[1]/2)), rect[2] + 25)
#         cv2.putText(image, label, label_position , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
#     else:
#         cv2.putText(image, "No Face Found", (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
        
#     cv2.imshow('All', image)
#     if cv2.waitKey(1) == 13: #13 is the Enter Key
#         break
        
# cap.release()
cv2.destroyAllWindows()

# %%
# cap.release()
# cv2.destroyAllWindows()
