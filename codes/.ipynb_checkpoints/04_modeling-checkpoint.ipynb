# %% [markdown]
# credits: APEKSHA PRIYA, Priya Dwivedi
#
# https://github.com/priya-dwivedi/face_and_emotion_detection/blob/master/src/EmotionDetector_v2.ipynb
# https://towardsdatascience.com/face-detection-recognition-and-emotion-detection-in-8-lines-of-code-b2ce32d4d5de

# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

# from keras.models import Sequential
# from keras.layers.normalization import BatchNormalization
# from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.advanced_activations import ELU
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras.optimizers import RMSprop, SGD, Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import regularizers
from keras.regularizers import l1
from sklearn.metrics import confusion_matrix

from keras.models import load_model

import cv2
import random
import numpy as np
# import os, os.path
# import glob
# from skimage.feature import Cascade
# import skimage 
# from skimage import data, color
# import matplotlib.pyplot as plt
# from PIL import Image

# %%
# initializing
num_classes = 4
img_rows, img_cols = 48, 48
batch_size = 64 #(change back for full load)

train_data_dir = '../datasets/train_cropped_original/train'
validation_data_dir = '../datasets/train_cropped_original/val'

# %%
# Let's use some data augmentaiton 

val_datagen = ImageDataGenerator(rescale=1./255) #
train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 19601 images belonging to 4 classes.
# Found 4198 images belonging to 4 classes.

# %%
print(validation_generator.class_indices)
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
#create model 

# model= Sequential()

# %%
# # Create the model 2
# model = Sequential()

# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(48,48,1)))
# # model.add(BatchNormalization())

# model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# # # model.add(BatchNormalization())

# model.add(Conv2D(128, kernel_size=(2, 2), activation='relu'))
# # model.add(BatchNormalization())

# model.add(Flatten())

# model.add(Dense(120, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(4, activation='softmax'))
# #model.add(Activation("softmax"))

# model.summary()
# # model.add(Dense(1024, activation='relu'))
# # model.add(Dropout(0.5))
# # model.add(Dense(7, activation='softmax'))
# # model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# # model.add(BatchNormalization())
# # model.add(Activation("softmax"))

# %%
# Create the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(48,48,1)))
model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(1, 1), activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(4, kernel_size=(4, 4), activation='relu'))
model.add(BatchNormalization())

model.add(Flatten())

model.add(Activation("softmax"))

model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 46, 46, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 64)          16448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 1, 4)           4100
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1, 1, 4)           16
# _________________________________________________________________
# flatten (Flatten)            (None, 4)                 0
# _________________________________________________________________
# activation (Activation)      (None, 4)                 0
# =================================================================
# Total params: 408,788
# Trainable params: 408,588
# Non-trainable params: 200
# _________________________________________________________________

# %%
# %%time
# If you want to train the same model or try other models, go for this


# filepath = os.path.join("./emotion_detector_models/model_v6_{epoch}.hdf5")

checkpoint = keras.callbacks.ModelCheckpoint('cp_mod_test_1.hdf5',
                                             monitor='val_categorical_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                             mode='max')

callbacks = [checkpoint]

# checkpoint = ModelCheckpoint('rong_test_2.hdf5',
#                              monitor='val_accuracy',
#                              mode='min',
#                              save_best_only=True,
#                              verbose=1)

earlystop = EarlyStopping(monitor='val_categorical_accuracy',
                          min_delta=0,
                          patience=9,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = ReduceLROnPlateau(monitor='val_categorical_accuracy',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.001)

# callbacks = [checkpoint,reduce_lr]
# callbacks = [earlystop,checkpoint,reduce_lr]


# if mode == "train":
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001, decay=1e-6),metrics=['categorical_accuracy'])
nb_train_samples = 6873
nb_validation_samples = 1829
epochs = 200

model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)

# plot_model_history(model_info)
model.save_weights('weight_mod_test_1.h5')
model.save('mod_mod_test_1.h5')
# Out:
# WARNING:tensorflow:From <timed exec>:49: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/200
# 107/107 [==============================] - ETA: 0s - loss: 1.3622 - categorical_accuracy: 0.3752
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.40402, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 40s 376ms/step - loss: 1.3622 - categorical_accuracy: 0.3752 - val_loss: 1.2856 - val_categorical_accuracy: 0.4040
# Epoch 2/200
# 107/107 [==============================] - ETA: 0s - loss: 1.2460 - categorical_accuracy: 0.4521
# Epoch 00002: val_categorical_accuracy did not improve from 0.40402
# 107/107 [==============================] - 41s 381ms/step - loss: 1.2460 - categorical_accuracy: 0.4521 - val_loss: 1.3253 - val_categorical_accuracy: 0.3895
# Epoch 3/200
# 107/107 [==============================] - ETA: 0s - loss: 1.1157 - categorical_accuracy: 0.5415
# Epoch 00003: val_categorical_accuracy did not improve from 0.40402
# 107/107 [==============================] - 42s 389ms/step - loss: 1.1157 - categorical_accuracy: 0.5415 - val_loss: 1.3488 - val_categorical_accuracy: 0.3326
# Epoch 4/200
# 107/107 [==============================] - ETA: 0s - loss: 1.0216 - categorical_accuracy: 0.5899
# Epoch 00004: val_categorical_accuracy improved from 0.40402 to 0.42467, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 46s 427ms/step - loss: 1.0216 - categorical_accuracy: 0.5899 - val_loss: 1.2392 - val_categorical_accuracy: 0.4247
# Epoch 5/200
# 107/107 [==============================] - ETA: 0s - loss: 0.9562 - categorical_accuracy: 0.6126
# Epoch 00005: val_categorical_accuracy did not improve from 0.42467
# 107/107 [==============================] - 41s 385ms/step - loss: 0.9562 - categorical_accuracy: 0.6126 - val_loss: 1.3576 - val_categorical_accuracy: 0.4057
# Epoch 6/200
# 107/107 [==============================] - ETA: 0s - loss: 0.9122 - categorical_accuracy: 0.6367
# Epoch 00006: val_categorical_accuracy improved from 0.42467 to 0.55525, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 42s 392ms/step - loss: 0.9122 - categorical_accuracy: 0.6367 - val_loss: 1.0745 - val_categorical_accuracy: 0.5552
# Epoch 7/200
# 107/107 [==============================] - ETA: 0s - loss: 0.8791 - categorical_accuracy: 0.6474
# Epoch 00007: val_categorical_accuracy improved from 0.55525 to 0.63895, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 41s 385ms/step - loss: 0.8791 - categorical_accuracy: 0.6474 - val_loss: 0.8986 - val_categorical_accuracy: 0.6390
# Epoch 8/200
# 107/107 [==============================] - ETA: 0s - loss: 0.8683 - categorical_accuracy: 0.6515
# Epoch 00008: val_categorical_accuracy improved from 0.63895 to 0.67467, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 43s 401ms/step - loss: 0.8683 - categorical_accuracy: 0.6515 - val_loss: 0.8469 - val_categorical_accuracy: 0.6747
# Epoch 9/200
# 107/107 [==============================] - ETA: 0s - loss: 0.8292 - categorical_accuracy: 0.6736
# Epoch 00009: val_categorical_accuracy improved from 0.67467 to 0.68973, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 43s 405ms/step - loss: 0.8292 - categorical_accuracy: 0.6736 - val_loss: 0.7828 - val_categorical_accuracy: 0.6897
# Epoch 10/200
# 107/107 [==============================] - ETA: 0s - loss: 0.8053 - categorical_accuracy: 0.6859
# Epoch 00010: val_categorical_accuracy improved from 0.68973 to 0.71652, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 42s 392ms/step - loss: 0.8053 - categorical_accuracy: 0.6859 - val_loss: 0.7309 - val_categorical_accuracy: 0.7165
# Epoch 11/200
# 107/107 [==============================] - ETA: 0s - loss: 0.7918 - categorical_accuracy: 0.6865
# Epoch 00011: val_categorical_accuracy did not improve from 0.71652
# 107/107 [==============================] - 42s 395ms/step - loss: 0.7918 - categorical_accuracy: 0.6865 - val_loss: 0.7617 - val_categorical_accuracy: 0.7137
# Epoch 12/200
# 107/107 [==============================] - ETA: 0s - loss: 0.7742 - categorical_accuracy: 0.6967
# Epoch 00012: val_categorical_accuracy did not improve from 0.71652
# 107/107 [==============================] - 42s 389ms/step - loss: 0.7742 - categorical_accuracy: 0.6967 - val_loss: 0.7559 - val_categorical_accuracy: 0.7081
# Epoch 13/200
# 107/107 [==============================] - ETA: 0s - loss: 0.7520 - categorical_accuracy: 0.7061
# Epoch 00013: val_categorical_accuracy did not improve from 0.71652
# 107/107 [==============================] - 41s 384ms/step - loss: 0.7520 - categorical_accuracy: 0.7061 - val_loss: 0.7604 - val_categorical_accuracy: 0.7048
# Epoch 14/200
# 107/107 [==============================] - ETA: 0s - loss: 0.7599 - categorical_accuracy: 0.7031
# Epoch 00014: val_categorical_accuracy did not improve from 0.71652
# 107/107 [==============================] - 41s 382ms/step - loss: 0.7599 - categorical_accuracy: 0.7031 - val_loss: 0.7692 - val_categorical_accuracy: 0.6881
# Epoch 15/200
# 107/107 [==============================] - ETA: 0s - loss: 0.7490 - categorical_accuracy: 0.7097
# Epoch 00015: val_categorical_accuracy did not improve from 0.71652
# 107/107 [==============================] - 42s 393ms/step - loss: 0.7490 - categorical_accuracy: 0.7097 - val_loss: 0.7978 - val_categorical_accuracy: 0.6936
# Epoch 16/200
# 107/107 [==============================] - ETA: 0s - loss: 0.7323 - categorical_accuracy: 0.7208
# Epoch 00016: val_categorical_accuracy improved from 0.71652 to 0.72935, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 44s 415ms/step - loss: 0.7323 - categorical_accuracy: 0.7208 - val_loss: 0.7109 - val_categorical_accuracy: 0.7294
# Epoch 17/200
# 107/107 [==============================] - ETA: 0s - loss: 0.7228 - categorical_accuracy: 0.7176
# Epoch 00017: val_categorical_accuracy improved from 0.72935 to 0.74163, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 32s 295ms/step - loss: 0.7228 - categorical_accuracy: 0.7176 - val_loss: 0.6545 - val_categorical_accuracy: 0.7416
# Epoch 18/200
# 107/107 [==============================] - ETA: 0s - loss: 0.7177 - categorical_accuracy: 0.7186
# Epoch 00018: val_categorical_accuracy did not improve from 0.74163
# 107/107 [==============================] - 22s 202ms/step - loss: 0.7177 - categorical_accuracy: 0.7186 - val_loss: 0.7213 - val_categorical_accuracy: 0.6959
# Epoch 19/200
# 107/107 [==============================] - ETA: 0s - loss: 0.6965 - categorical_accuracy: 0.7317
# Epoch 00019: val_categorical_accuracy improved from 0.74163 to 0.74554, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] -
200
# 107/107 [==============================] - ETA: 0s - loss: 0.6168 - categorical_accuracy: 0.7643
# Epoch 00032: val_categorical_accuracy did not improve from 0.76004
# 107/107 [==============================] - 40s 372ms/step - loss: 0.6168 - categorical_accuracy: 0.7643 - val_loss: 0.6511 - val_categorical_accuracy: 0.7455
# Epoch 33/200
# 107/107 [==============================] - ETA: 0s - loss: 0.6502 - categorical_accuracy: 0.7500
# Epoch 00033: val_categorical_accuracy did not improve from 0.76004
# 107/107 [==============================] - 39s 365ms/step - loss: 0.6502 - categorical_accuracy: 0.7500 - val_loss: 0.7060 - val_categorical_accuracy: 0.7171
# Epoch 34/200
# 107/107 [==============================] - ETA: 0s - loss: 0.6219 - categorical_accuracy: 0.7567
# Epoch 00034: val_categorical_accuracy did not improve from 0.76004
# 107/107 [==============================] - 23s 211ms/step - loss: 0.6219 - categorical_accuracy: 0.7567 - val_loss: 0.6545 - val_categorical_accuracy: 0.7355
# Epoch 35/200
# 107/107 [==============================] - ETA: 0s - loss: 0.6328 - categorical_accuracy: 0.7522
# Epoch 00035: val_categorical_accuracy improved from 0.76004 to 0.76395, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 24s 225ms/step - loss: 0.6328 - categorical_accuracy: 0.7522 - val_loss: 0.6037 - val_categorical_accuracy: 0.7640
# Epoch 36/200
# 107/107 [==============================] - ETA: 0s - loss: 0.6275 - categorical_accuracy: 0.7580
# Epoch 00036: val_categorical_accuracy did not improve from 0.76395
# 107/107 [==============================] - 24s 221ms/step - loss: 0.6275 - categorical_accuracy: 0.7580 - val_loss: 0.6522 - val_categorical_accuracy: 0.7400
# Epoch 37/200
# 107/107 [==============================] - ETA: 0s - loss: 0.6125 - categorical_accuracy: 0.7624
# Epoch 00037: val_categorical_accuracy improved from 0.76395 to 0.77176, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 22s 206ms/step - loss: 0.6125 - categorical_accuracy: 0.7624 - val_loss: 0.5989 - val_categorical_accuracy: 0.7718
# Epoch 38/200
# 107/107 [==============================] - ETA: 0s - loss: 0.6220 - categorical_accuracy: 0.7569
# Epoch 00038: val_categorical_accuracy did not improve from 0.77176
# 107/107 [==============================] - 22s 207ms/step - loss: 0.6220 - categorical_accuracy: 0.7569 - val_loss: 0.6253 - val_categorical_accuracy: 0.7628
# Epoch 39/200
# 107/107 [==============================] - ETA: 0s - loss: 0.6189 - categorical_accuracy: 0.7586
# Epoch 00039: val_categorical_accuracy did not improve from 0.77176
# 107/107 [==============================] - 32s 301ms/step - loss: 0.6189 - categorical_accuracy: 0.7586 - val_loss: 0.9117 - val_categorical_accuracy: 0.6412
# Epoch 40/200
# 107/107 [==============================] - ETA: 0s - loss: 0.6041 - categorical_accuracy: 0.7684
# Epoch 00040: val_categorical_accuracy did not improve from 0.77176
# 107/107 [==============================] - 39s 365ms/step - loss: 0.6041 - categorical_accuracy: 0.7684 - val_loss: 0.7256 - val_categorical_accuracy: 0.7221
# Epoch 41/200
# 107/107 [==============================] - ETA: 0s - loss: 0.6143 - categorical_accuracy: 0.7671
# Epoch 00041: val_categorical_accuracy did not improve from 0.77176
# 107/107 [==============================] - 38s 358ms/step - loss: 0.6143 - categorical_accuracy: 0.7671 - val_loss: 0.7317 - val_categorical_accuracy: 0.7148
# Epoch 42/200
# 107/107 [==============================] - ETA: 0s - loss: 0.5953 - categorical_accuracy: 0.7703
# Epoch 00042: val_categorical_accuracy did not improve from 0.77176
# 107/107 [==============================] - 39s 365ms/step - loss: 0.5953 - categorical_accuracy: 0.7703 - val_loss: 0.6259 - val_categorical_accuracy: 0.7556
# Epoch 43/200
# 107/107 [==============================] - ETA: 0s - loss: 0.5941 - categorical_accuracy: 0.7736
# Epoch 00043: val_categorical_accuracy improved from 0.77176 to 0.78292, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] -
val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 37s 343ms/step - loss: 0.4491 - categorical_accuracy: 0.8302 - val_loss: 0.5721 - val_categorical_accuracy: 0.7868
# Epoch 159/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4397 - categorical_accuracy: 0.8352
# Epoch 00159: val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 37s 342ms/step - loss: 0.4397 - categorical_accuracy: 0.8352 - val_loss: 0.5569 - val_categorical_accuracy: 0.7846
# Epoch 160/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4462 - categorical_accuracy: 0.8363
# Epoch 00160: val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 37s 342ms/step - loss: 0.4462 - categorical_accuracy: 0.8363 - val_loss: 0.5297 - val_categorical_accuracy: 0.8013
# Epoch 161/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4643 - categorical_accuracy: 0.8287
# Epoch 00161: val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 37s 346ms/step - loss: 0.4643 - categorical_accuracy: 0.8287 - val_loss: 0.5618 - val_categorical_accuracy: 0.7818
# Epoch 162/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4259 - categorical_accuracy: 0.8365
# Epoch 00162: val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 36s 339ms/step - loss: 0.4259 - categorical_accuracy: 0.8365 - val_loss: 0.5282 - val_categorical_accuracy: 0.8069
# Epoch 163/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4489 - categorical_accuracy: 0.8305
# Epoch 00163: val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 36s 340ms/step - loss: 0.4489 - categorical_accuracy: 0.8305 - val_loss: 0.5768 - val_categorical_accuracy: 0.7891
# Epoch 164/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4571 - categorical_accuracy: 0.8252
# Epoch 00164: val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 37s 344ms/step - loss: 0.4571 - categorical_accuracy: 0.8252 - val_loss: 0.5660 - val_categorical_accuracy: 0.7885
# Epoch 165/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4495 - categorical_accuracy: 0.8363
# Epoch 00165: val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 36s 340ms/step - loss: 0.4495 - categorical_accuracy: 0.8363 - val_loss: 0.5957 - val_categorical_accuracy: 0.7762
# Epoch 166/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4325 - categorical_accuracy: 0.8354
# Epoch 00166: val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 37s 343ms/step - loss: 0.4325 - categorical_accuracy: 0.8354 - val_loss: 0.5569 - val_categorical_accuracy: 0.7913
# Epoch 167/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4325 - categorical_accuracy: 0.8379
# Epoch 00167: val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 36s 340ms/step - loss: 0.4325 - categorical_accuracy: 0.8379 - val_loss: 0.5697 - val_categorical_accuracy: 0.7919
# Epoch 168/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4331 - categorical_accuracy: 0.8368
# Epoch 00168: val_categorical_accuracy did not improve from 0.81306
# 107/107 [==============================] - 37s 344ms/step - loss: 0.4331 - categorical_accuracy: 0.8368 - val_loss: 0.5432 - val_categorical_accuracy: 0.7919
# Epoch 169/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4499 - categorical_accuracy: 0.8303
# Epoch 00169: val_categorical_accuracy improved from 0.81306 to 0.81473, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 36s 340ms/step - loss: 0.4499 - categorical_accuracy: 0.8303 - val_loss: 0.4969 - val_categorical_accuracy: 0.8147
# Epoch 170/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4322 - categorical_accuracy: 0.8413
# Epoch 00170: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 36s 336ms/step - loss: 0.4322 - categorical_accuracy: 0.8413 - val_loss: 0.5451 - val_categorical_accuracy: 0.8013
# Epoch 171/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4324 - categorical_accuracy: 0.8381
# Epoch 00171: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 36s 339ms/step - loss: 0.4324 - categorical_accuracy: 0.8381 - val_loss: 0.6495 - val_categorical_accuracy: 0.7539
# Epoch 172/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4402 - categorical_accuracy: 0.8296
# Epoch 00172: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 36s 341ms/step - loss: 0.4402 - categorical_accuracy: 0.8296 - val_loss: 0.5624 - val_categorical_accuracy: 0.8025
# Epoch 173/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4327 - categorical_accuracy: 0.8356
# Epoch 00173: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 37s 342ms/step - loss: 0.4327 - categorical_accuracy: 0.8356 - val_loss: 0.6309 - val_categorical_accuracy: 0.7734
# Epoch 174/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4327 - categorical_accuracy: 0.8405
# Epoch 00174: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 36s 334ms/step - loss: 0.4327 - categorical_accuracy: 0.8405 - val_loss: 0.5716 - val_categorical_accuracy: 0.7857
# Epoch 175/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4439 - categorical_accuracy: 0.8363
# Epoch 00175: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 36s 341ms/step - loss: 0.4439 - categorical_accuracy: 0.8363 - val_loss: 0.5707 - val_categorical_accuracy: 0.7980
# Epoch 176/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4274 - categorical_accuracy: 0.8426
# Epoch 00176: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 37s 341ms/step - loss: 0.4274 - categorical_accuracy: 0.8426 - val_loss: 0.5279 - val_categorical_accuracy: 0.8047
# Epoch 177/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4497 - categorical_accuracy: 0.8300
# Epoch 00177: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 37s 342ms/step - loss: 0.4497 - categorical_accuracy: 0.8300 - val_loss: 0.5173 - val_categorical_accuracy: 0.8047
# Epoch 178/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4245 - categorical_accuracy: 0.8427
# Epoch 00178: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 36s 340ms/step - loss: 0.4245 - categorical_accuracy: 0.8427 - val_loss: 0.5766 - val_categorical_accuracy: 0.7835
# Epoch 179/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4188 - categorical_accuracy: 0.8443
# Epoch 00179: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 37s 342ms/step - loss: 0.4188 - categorical_accuracy: 0.8443 - val_loss: 0.5421 - val_categorical_accuracy: 0.7891
# Epoch 180/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4391 - categorical_accuracy: 0.8356
# Epoch 00180: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 37s 345ms/step - loss: 0.4391 - categorical_accuracy: 0.8356 - val_loss: 0.5809 - val_categorical_accuracy: 0.7812
# Epoch 181/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4204 - categorical_accuracy: 0.8397
# Epoch 00181: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 36s 338ms/step - loss: 0.4204 - categorical_accuracy: 0.8397 - val_loss: 0.6221 - val_categorical_accuracy: 0.7628
# Epoch 182/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4404 - categorical_accuracy: 0.8347
# Epoch 00182: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 37s 342ms/step - loss: 0.4404 - categorical_accuracy: 0.8347 - val_loss: 0.5947 - val_categorical_accuracy: 0.7969
# Epoch 183/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4318 - categorical_accuracy: 0.8368
# Epoch 00183: val_categorical_accuracy did not improve from 0.81473
# 107/107 [==============================] - 37s 342ms/step - loss: 0.4318 - categorical_accuracy: 0.8368 - val_loss: 0.6579 - val_categorical_accuracy: 0.7673
# Epoch 184/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4225 - categorical_accuracy: 0.8402
# Epoch 00184: val_categorical_accuracy improved from 0.81473 to 0.81529, saving model to cp_mod_test_1.hdf5
# 107/107 [==============================] - 37s 344ms/step - loss: 0.4225 - categorical_accuracy: 0.8402 - val_loss: 0.5093 - val_categorical_accuracy: 0.8153
# Epoch 185/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4414 - categorical_accuracy: 0.8360
# Epoch 00185: val_categorical_accuracy did not improve from 0.81529
# 107/107 [==============================] - 33s 305ms/step - loss: 0.4414 - categorical_accuracy: 0.8360 - val_loss: 0.5664 - val_categorical_accuracy: 0.7824
# Epoch 186/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4411 - categorical_accuracy: 0.8303
# Epoch 00186: val_categorical_accuracy did not improve from 0.81529
# 107/107 [==============================] - 21s 198ms/step - loss: 0.4411 - categorical_accuracy: 0.8303 - val_loss: 0.5691 - val_categorical_accuracy: 0.7907
# Epoch 187/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4400 - categorical_accuracy: 0.8351
# Epoch 00187: val_categorical_accuracy did not improve from 0.81529
# 107/107 [==============================] - 21s 199ms/step - loss: 0.4400 - categorical_accuracy: 0.8351 - val_loss: 0.6114 - val_categorical_accuracy: 0.7712
# Epoch 188/200
# 107/107 [==============================] - ETA: 0s - loss: 0.4176 - categorical_accuracy: 0.8454
# Epoch 00188: val_categorical_accuracy did not improve from 0.81529
# 107/107 [==============================] - 21s
history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy'])

# %%
plt.plot(model_info.history["categorical_accuracy"], label = 'Train Accuracy')
plt.plot(model_info.history["val_categorical_accuracy"], label = 'Validation Accuracy')
plt.legend();

# %%
# model.load_weights('rong_test_2_5.h5')

# %%
# model_info = model.fit_generator(
#             train_generator,
#             steps_per_epoch=nb_train_samples // batch_size,
#             epochs=epochs,
#             callbacks = callbacks,
#             validation_data=validation_generator,
#             validation_steps=nb_validation_samples // batch_size)

# %%
# plt.plot(model_info.history['loss'])
# plt.plot(model_info.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
# model.load_weights('rong_test_2.h5')
# # history = model.fit_generator(
# #     train_generator,
# #     steps_per_epoch = nb_train_samples // batch_size,
# #     epochs = epochs,
# #     callbacks = callbacks,
# #     validation_data = validation_generator,
# #     validation_steps = nb_validation_samples // batch_size)

# %%
# import matplotlib.pyplot as plt
# import sklearn
# from sklearn.metrics import classification_report, confusion_matrix
# import numpy as np
# # Found 28709 images belonging to 7 classes.
# # Found 3589 images belonging to 7 classes.


# nb_train_samples = 28273
# nb_validation_samples = 3534
# nb_train_samples = 140
# nb_validation_samples = 70

# # We need to recreate our validation generator with shuffle = false
# validation_generator = val_datagen.flow_from_directory(
#         validation_data_dir,
#         color_mode = 'grayscale',
#         target_size=(img_rows, img_cols),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=False)

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# #Confution Matrix and Classification Report
# Y_pred = model.predict_generator(validation_generator, nb_validation_samples // batch_size+1)
# y_pred = np.argmax(Y_pred, axis=1)

# print('Confusion Matrix')
# print(confusion_matrix(validation_generator.classes, y_pred))
# print('Classification Report')
# target_names = list(class_labels.values())
# print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# plt.figure(figsize=(8,8))
# cnf_matrix = confusion_matrix(validation_generator.classes, y_pred)

# plt.imshow(cnf_matrix, interpolation='nearest')
# plt.colorbar()
# tick_marks = np.arange(len(classes))
# _ = plt.xticks(tick_marks, classes, rotation=90)
# _ = plt.yticks(tick_marks, classes)

# %%
# classifier = load_model('./emotion_detector_models/model_v3_71.hdf5')

# %%
# validation_generator = val_datagen.flow_from_directory(
#         validation_data_dir,
#         color_mode = 'grayscale',
#         target_size=(img_rows, img_cols),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=False)

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())
# print(class_labels)

# %%
# from keras.models import load_model
# from keras.optimizers import RMSprop, SGD, Adam
# from keras.preprocessing import image
# import numpy as np
# import os
# import cv2
# import numpy as np
# from os import listdir
# from os.path import isfile, join
# import re

# def draw_test(name, pred, im, true_label):
#     BLACK = [0,0,0]
#     expanded_image = cv2.copyMakeBorder(im, 160, 0, 0, 300 ,cv2.BORDER_CONSTANT,value=BLACK)
#     cv2.putText(expanded_image, "predited - "+ pred, (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,0,255), 2)
#     cv2.putText(expanded_image, "true - "+ true_label, (20, 120) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,255,0), 2)
#     cv2.imshow(name, expanded_image)


# def getRandomImage(path, img_width, img_height):
#     """function loads a random images from a random folder in our test path """
#     folders = path
#     random_directory = np.random.randint(0,len(folders))
#     path_class = folders[random_directory]
#     file_path = path
#     file_names = [f for f in listdir(file_path)]
#     random_file_index = np.random.randint(0,len(file_names))
#     image_name = file_names[random_file_index]
#     final_path = file_path + "/" + image_name
#     return image.load_img(final_path, target_size = (img_width, img_height),grayscale=True), final_path, path_class

# # dimensions of our images
# img_width, img_height = 48, 48

# # We use a very small learning rate 
# model.compile(loss = 'categorical_crossentropy',
#               optimizer = RMSprop(lr = 0.001),
#               metrics = ['accuracy'])

# files = []
# predictions = []
# true_labels = []

# # predicting images
# for i in range(0, 10):
#     path = '../non_load/fer2013/train' 
#     img, final_path, true_label = getRandomImage(path, img_width, img_height)
#     files.append(final_path)
#     true_labels.append(true_label)
#     x = image.img_to_array(img)
#     x = x * 1./255
#     x = np.expand_dims(x, axis=0)
#     images = np.vstack([x])
#     classes = model.predict_classes(images, batch_size = 10)
#     predictions.append(classes)
    
# for i in range(0, len(files)):
#     image = cv2.imread((files[i]))
#     image = cv2.resize(image, None, fx=3, fy=3, interpolation = cv2.INTER_CUBIC)
#     draw_test("Prediction", class_labels[predictions[i][0]], image, true_labels[i])
#     cv2.waitKey(0)

# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# from time import sleep
# from keras.preprocessing.image import img_to_array

# face_classifier = cv2.CascadeClassifier('../datasets/classifiers/haarcascade_frontalface_default.xml')
# classifier =load_model('rong_test_2_1.hdf5')

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# def face_detector(img):
#     # Convert image to grayscale
#     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#     faces = face_classifier.detectMultiScale(gray, 1.3, 5)
#     if faces is ():
#         return (0,0,0,0), np.zeros((48,48), np.uint8), img
    
#     for (x,y,w,h) in faces:
#         cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#         roi_gray = gray[y:y+h, x:x+w]

#     try:
#         roi_gray = cv2.resize(roi_gray, (48, 48), interpolation = cv2.INTER_AREA)
#     except:
#         return (x,w,y,h), np.zeros((48,48), np.uint8), img
#     return (x,w,y,h), roi_gray, img

# cap = cv2.VideoCapture(0)

# while True:

#     ret, frame = cap.read()
#     rect, face, image = face_detector(frame)
#     if np.sum([face]) != 0.0:
#         roi = face.astype("float") / 255.0
#         roi = img_to_array(roi)
#         roi = np.expand_dims(roi, axis=0)

#         # make a prediction on the ROI, then lookup the class
#         preds = classifier.predict(roi)[0]
#         label = class_labels[preds.argmax()]  
#         label_position = (rect[0] + int((rect[1]/2)), rect[2] + 25)
#         cv2.putText(image, label, label_position , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
#     else:
#         cv2.putText(image, "No Face Found", (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
        
#     cv2.imshow('All', image)
#     if cv2.waitKey(1) == 13: #13 is the Enter Key
#         break
        
# cap.release()
# cv2.destroyAllWindows()

# %%
# cap.release()
# cv2.destroyAllWindows()
