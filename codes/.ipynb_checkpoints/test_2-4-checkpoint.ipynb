# %% [markdown]
# credits: APEKSHA PRIYA, Priya Dwivedi
#
# https://github.com/priya-dwivedi/face_and_emotion_detection/blob/master/src/EmotionDetector_v2.ipynb
# https://towardsdatascience.com/face-detection-recognition-and-emotion-detection-in-8-lines-of-code-b2ce32d4d5de

# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
import os
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.advanced_activations import ELU
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras.optimizers import RMSprop, SGD, Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import regularizers
from keras.regularizers import l1

from keras.models import load_model

# %%
# initializing
num_classes = 3
img_rows, img_cols = 48, 48
batch_size = 120 #(change back for full load)

train_data_dir = '../test/train'
validation_data_dir = '../test/validation'

# %%
# Let's use some data augmentaiton 
# train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 16944 images belonging to 3 classes.
# Found 2099 images belonging to 3 classes.

# %%
print(validation_generator.class_indices)
# Out:
# {'happy': 0, 'neutral': 1, 'sad': 2}

# %%
# Create the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='elu',input_shape=(48,48,1)))
# model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3, 3), activation='elu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='elu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.5))
model.add(Conv2D(128, kernel_size=(3, 3), activation='elu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(5, kernel_size=(4, 4), activation='elu'))
# # model.add(BatchNormalization())

model.add(Conv2D(3, kernel_size=(6, 6), activation='elu'))
# model.add(BatchNormalization())

model.add(Flatten())

model.add(Activation("softmax"))

model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 46, 46, 32)        320
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 44, 44, 64)        18496
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 42, 42, 128)       73856
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 21, 21, 128)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 19, 19, 128)       147584
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 9, 9, 128)         0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 6, 6, 5)           10245
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 1, 1, 3)           543
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 3)                 0
# _________________________________________________________________
# activation_5 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 251,044
# Trainable params: 251,044
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # Create the model 2
# model = Sequential()

# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(48,48,1)))
# # model.add(BatchNormalization())

# model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(7, kernel_size=(1, 1), activation='relu'))
# # # model.add(BatchNormalization())

# model.add(Conv2D(7, kernel_size=(4, 4), activation='relu'))
# # model.add(BatchNormalization())

# model.add(Flatten())

# model.add(Dense(120, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# #model.add(Activation("softmax"))

# model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())
# model.add(Activation("softmax"))

# %%
# If you want to train the same model or try other models, go for this


# filepath = os.path.join("./emotion_detector_models/model_v6_{epoch}.hdf5")

checkpoint = keras.callbacks.ModelCheckpoint('rong_test_2_4.hdf5',
                                             monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                             mode='max')

callbacks = [checkpoint]

# checkpoint = ModelCheckpoint('rong_test_2.hdf5',
#                              monitor='val_loss',
#                              mode='min',
#                              save_best_only=True,
#                              verbose=1)

# earlystop = EarlyStopping(monitor='val_loss',
#                           min_delta=0,
#                           patience=9,
#                           verbose=1,
#                           restore_best_weights=True
#                           )

# reduce_lr = ReduceLROnPlateau(monitor='val_loss',
#                               factor=0.2,
#                               patience=3,
#                               verbose=1,
#                               min_delta=0.0001)

# callbacks = [checkpoint,reduce_lr]
# callbacks = [earlystop,checkpoint,reduce_lr]


# if mode == "train":
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])
nb_train_samples = 16944
nb_validation_samples = 2099
epochs = 100

model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)

# plot_model_history(model_info)
model.save_weights('rong_test_2_4.h5')
# Out:
# Epoch 1/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0703 - accuracy: 0.4302
# Epoch 00001: val_accuracy improved from -inf to 0.43186, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 192s 1s/step - loss: 1.0703 - accuracy: 0.4302 - val_loss: 1.0658 - val_accuracy: 0.4319
# Epoch 2/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0523 - accuracy: 0.4492
# Epoch 00002: val_accuracy improved from 0.43186 to 0.48039, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 199s 1s/step - loss: 1.0523 - accuracy: 0.4492 - val_loss: 1.0414 - val_accuracy: 0.4804
# Epoch 3/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0273 - accuracy: 0.4868
# Epoch 00003: val_accuracy improved from 0.48039 to 0.48284, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 193s 1s/step - loss: 1.0273 - accuracy: 0.4868 - val_loss: 1.0336 - val_accuracy: 0.4828
# Epoch 4/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0019 - accuracy: 0.5086
# Epoch 00004: val_accuracy improved from 0.48284 to 0.51127, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 196s 1s/step - loss: 1.0019 - accuracy: 0.5086 - val_loss: 0.9991 - val_accuracy: 0.5113
# Epoch 5/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9795 - accuracy: 0.5292
# Epoch 00005: val_accuracy improved from 0.51127 to 0.51912, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 204s 1s/step - loss: 0.9795 - accuracy: 0.5292 - val_loss: 0.9869 - val_accuracy: 0.5191
# Epoch 6/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9577 - accuracy: 0.5426
# Epoch 00006: val_accuracy improved from 0.51912 to 0.52794, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 195s 1s/step - loss: 0.9577 - accuracy: 0.5426 - val_loss: 0.9772 - val_accuracy: 0.5279
# Epoch 7/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9476 - accuracy: 0.5491
# Epoch 00007: val_accuracy improved from 0.52794 to 0.52892, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 242s 2s/step - loss: 0.9476 - accuracy: 0.5491 - val_loss: 1.0092 - val_accuracy: 0.5289
# Epoch 8/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9450 - accuracy: 0.5493
# Epoch 00008: val_accuracy improved from 0.52892 to 0.53480, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 202s 1s/step - loss: 0.9450 - accuracy: 0.5493 - val_loss: 0.9843 - val_accuracy: 0.5348
# Epoch 9/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9294 - accuracy: 0.5625
# Epoch 00009: val_accuracy improved from 0.53480 to 0.54216, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 238s 2s/step - loss: 0.9294 - accuracy: 0.5625 - val_loss: 0.9713 - val_accuracy: 0.5422
# Epoch 10/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9266 - accuracy: 0.5592
# Epoch 00010: val_accuracy did not improve from 0.54216
# 141/141 [==============================] - 232s 2s/step - loss: 0.9266 - accuracy: 0.5592 - val_loss: 0.9930 - val_accuracy: 0.5230
# Epoch 11/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9193 - accuracy: 0.5662
# Epoch 00011: val_accuracy did not improve from 0.54216
# 141/141 [==============================] - 220s 2s/step - loss: 0.9193 - accuracy: 0.5662 - val_loss: 0.9788 - val_accuracy: 0.5402
# Epoch 12/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9090 - accuracy: 0.5711
# Epoch 00012: val_accuracy improved from 0.54216 to 0.54314, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 212s 2s/step - loss: 0.9090 - accuracy: 0.5711 - val_loss: 0.9715 - val_accuracy: 0.5431
# Epoch 13/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9085 - accuracy: 0.5715
# Epoch 00013: val_accuracy improved from 0.54314 to 0.54363, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 250s 2s/step - loss: 0.9085 - accuracy: 0.5715 - val_loss: 0.9534 - val_accuracy: 0.5436
# Epoch 14/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9011 - accuracy: 0.5770
# Epoch 00014: val_accuracy improved from 0.54363 to 0.54608, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 250s 2s/step - loss: 0.9011 - accuracy: 0.5770 - val_loss: 0.9619 - val_accuracy: 0.5461
# Epoch 15/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8959 - accuracy: 0.5755
# Epoch 00015: val_accuracy improved from 0.54608 to 0.55196, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 227s 2s/step - loss: 0.8959 - accuracy: 0.5755 - val_loss: 0.9795 - val_accuracy: 0.5520
# Epoch 16/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8861 - accuracy: 0.5860
# Epoch 00016: val_accuracy did not improve from 0.55196
# 141/141 [==============================] - 224s 2s/step - loss: 0.8861 - accuracy: 0.5860 - val_loss: 0.9539 - val_accuracy: 0.5480
# Epoch 17/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8814 - accuracy: 0.5821
# Epoch 00017: val_accuracy improved from 0.55196 to 0.56324, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 237s 2s/step - loss: 0.8814 - accuracy: 0.5821 - val_loss: 0.9431 - val_accuracy: 0.5632
# Epoch 18/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8794 - accuracy: 0.5889
# Epoch 00018: val_accuracy did not improve from 0.56324
# 141/141 [==============================] - 188s 1s/step - loss: 0.8794 - accuracy: 0.5889 - val_loss: 0.9434 - val_accuracy: 0.5559
# Epoch 19/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8699 - accuracy: 0.5911
# Epoch 00019: val_accuracy did not improve from 0.56324
# 141/141 [==============================] - 185s 1s/step - loss: 0.8699 - accuracy: 0.5911 - val_loss: 0.9638 - val_accuracy: 0.5554
# Epoch 20/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8673 - accuracy: 0.5912
# Epoch 00020: val_accuracy did not improve from 0.56324
# 141/141 [==============================] - 185s 1s/step - loss: 0.8673 - accuracy: 0.5912 - val_loss: 0.9594 - val_accuracy: 0.5529
# Epoch 21/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8605 - accuracy: 0.6012
# Epoch 00021: val_accuracy did not improve from 0.56324
# 141/141 [==============================] - 184s 1s/step - loss: 0.8605 - accuracy: 0.6012 - val_loss: 0.9343 - val_accuracy: 0.5578
# Epoch 22/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8633 - accuracy: 0.5962
# Epoch 00022: val_accuracy did not improve from 0.56324
# 141/141 [==============================] - 185s 1s/step - loss: 0.8633 - accuracy: 0.5962 - val_loss: 0.9289 - val_accuracy: 0.5583
# Epoch 23/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8562 - accuracy: 0.6029
# Epoch 00023: val_accuracy improved from 0.56324 to 0.56667, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 184s 1s/step - loss: 0.8562 - accuracy: 0.6029 - val_loss: 0.9359 - val_accuracy: 0.5667
# Epoch 24/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8472 - accuracy: 0.6096
# Epoch 00024: val_accuracy did not improve from 0.56667
# 141/141 [==============================] - 185s 1s/step - loss: 0.8472 - accuracy: 0.6096 - val_loss: 0.9430 - val_accuracy: 0.5623
# Epoch 25/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8379 - accuracy: 0.6114
# Epoch 00025: val_accuracy improved from 0.56667 to 0.57647, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 184s 1s/step - loss: 0.8379 - accuracy: 0.6114 - val_loss: 0.9464 - val_accuracy: 0.5765
# Epoch 26/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8419 - accuracy: 0.6122
# Epoch 00026: val_accuracy did not improve from 0.57647
# 141/141 [==============================] - 185s 1s/step - loss: 0.8419 - accuracy: 0.6122 - val_loss: 0.9443 - val_accuracy: 0.5642
# Epoch 27/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8303 - accuracy: 0.6153
# Epoch 00027: val_accuracy improved from 0.57647 to 0.57696, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 184s 1s/step - loss: 0.8303 - accuracy: 0.6153 - val_loss: 0.9421 - val_accuracy: 0.5770
# Epoch 28/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8256 - accuracy: 0.6207
# Epoch 00028: val_accuracy did not improve from 0.57696
# 141/141 [==============================] - 185s 1s/step - loss: 0.8256 - accuracy: 0.6207 - val_loss: 0.9227 - val_accuracy: 0.5696
# Epoch 29/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8220 - accuracy: 0.6195
# Epoch 00029: val_accuracy did not improve from 0.57696
# 141/141 [==============================] - 185s 1s/step - loss: 0.8220 - accuracy: 0.6195 - val_loss: 0.9285 - val_accuracy: 0.5735
# Epoch 30/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8145 - accuracy: 0.6296
# Epoch 00030: val_accuracy did not improve from 0.57696
# 141/141 [==============================] - 185s 1s/step - loss: 0.8145 - accuracy: 0.6296 - val_loss: 0.9476 - val_accuracy: 0.5721
# Epoch 31/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8114 - accuracy: 0.6211
# Epoch 00031: val_accuracy improved from 0.57696 to 0.57941, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 186s 1s/step - loss: 0.8114 - accuracy: 0.6211 - val_loss: 0.9327 - val_accuracy: 0.5794
# Epoch 32/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8050 - accuracy: 0.6312
# Epoch 00032: val_accuracy did not improve from 0.57941
# 141/141 [==============================] - 185s 1s/step - loss: 0.8050 - accuracy: 0.6312 - val_loss: 0.9371 - val_accuracy: 0.5775
# Epoch 33/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8057 - accuracy: 0.6301
# Epoch 00033: val_accuracy did not improve from 0.57941
# 141/141 [==============================] - 185s 1s/step - loss: 0.8057 - accuracy: 0.6301 - val_loss: 0.9503 - val_accuracy: 0.5711
# Epoch 34/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7958 - accuracy: 0.6370
# Epoch 00034: val_accuracy improved from 0.57941 to 0.58039, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 184s 1s/step - loss: 0.7958 - accuracy: 0.6370 - val_loss: 0.9258 - val_accuracy: 0.5804
# Epoch 35/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7958 - accuracy: 0.6321
# Epoch 00035: val_accuracy improved from 0.58039 to 0.58627, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 186s 1s/step - loss: 0.7958 - accuracy: 0.6321 - val_loss: 0.9142 - val_accuracy: 0.5863
# Epoch 36/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7886 - accuracy: 0.6391
# Epoch 00036: val_accuracy improved from 0.58627 to 0.58922, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 185s 1s/step - loss: 0.7886 - accuracy: 0.6391 - val_loss: 0.9490 - val_accuracy: 0.5892
# Epoch 37/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7843 - accuracy: 0.6400
# Epoch 00037: val_accuracy did not improve from 0.58922
# 141/141 [==============================] - 194s 1s/step - loss: 0.7843 - accuracy: 0.6400 - val_loss: 0.9271 - val_accuracy: 0.5858
# Epoch 38/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7830 - accuracy: 0.6394
# Epoch 00038: val_accuracy did not improve from 0.58922
# 141/141 [==============================] - 218s 2s/step - loss: 0.7830 - accuracy: 0.6394 - val_loss: 1.0185 - val_accuracy: 0.5770
# Epoch 39/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7779 - accuracy: 0.6446
# Epoch 00039: val_accuracy did not improve from 0.58922
# 141/141 [==============================] - 206s 1s/step - loss: 0.7779 - accuracy: 0.6446 - val_loss: 0.9685 - val_accuracy: 0.5858
# Epoch 40/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7721 - accuracy: 0.6516
# Epoch 00040: val_accuracy improved from 0.58922 to 0.59706, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 226s 2s/step - loss: 0.7721 - accuracy: 0.6516 - val_loss: 0.9715 - val_accuracy: 0.5971
# Epoch 41/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7640 - accuracy: 0.6525
# Epoch 00041: val_accuracy did not improve from 0.59706
# 141/141 [==============================] - 219s 2s/step - loss: 0.7640 - accuracy: 0.6525 - val_loss: 0.9379 - val_accuracy: 0.5917
# Epoch 42/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7648 - accuracy: 0.6519
# Epoch 00042: val_accuracy did not improve from 0.59706
# 141/141 [==============================] - 241s 2s/step - loss: 0.7648 - accuracy: 0.6519 - val_loss: 0.9407 - val_accuracy: 0.5936
# Epoch 43/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.6552
# Epoch 00043: val_accuracy improved from 0.59706 to 0.59902, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 220s 2s/step - loss: 0.7637 - accuracy: 0.6552 - val_loss: 0.9558 - val_accuracy: 0.5990
# Epoch 44/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7569 - accuracy: 0.6569
# Epoch 00044: val_accuracy did not improve from 0.59902
# 141/141 [==============================] - 208s 1s/step - loss: 0.7569 - accuracy: 0.6569 - val_loss: 0.9197 - val_accuracy: 0.5828
# Epoch 45/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7588 - accuracy: 0.6569
# Epoch 00045: val_accuracy did not improve from 0.59902
# 141/141 [==============================] - 227s 2s/step - loss: 0.7588 - accuracy: 0.6569 - val_loss: 0.9639 - val_accuracy: 0.5912
# Epoch 46/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7469 - accuracy: 0.6618
# Epoch 00046: val_accuracy improved from 0.59902 to 0.60196, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 133s 945ms/step - loss: 0.7469 - accuracy: 0.6618 - val_loss: 0.9450 - val_accuracy: 0.6020
# Epoch 47/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7548 - accuracy: 0.6586
# Epoch 00047: val_accuracy did not improve from 0.60196
# 141/141 [==============================] - 115s 819ms/step - loss: 0.7548 - accuracy: 0.6586 - val_loss: 0.9383 - val_accuracy: 0.5951
# Epoch 48/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7486 - accuracy: 0.6602
# Epoch 00048: val_accuracy did not improve from 0.60196
# 141/141 [==============================] - 111s 785ms/step - loss: 0.7486 - accuracy: 0.6602 - val_loss: 0.9230 - val_accuracy: 0.5912
# Epoch 49/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7443 - accuracy: 0.6636
# Epoch 00049: val_accuracy did not improve from 0.60196
# 141/141 [==============================] - 113s 802ms/step - loss: 0.7443 - accuracy: 0.6636 - val_loss: 0.9392 - val_accuracy: 0.5966
# Epoch 50/100
# 141/141 [==============================] - ETA: 0s - loss: 0.
100
# 141/141 [==============================] - ETA: 0s - loss: 0.6780 - accuracy: 0.6979
# Epoch 00088: val_accuracy improved from 0.62696 to 0.62892, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 104s 740ms/step - loss: 0.6780 - accuracy: 0.6979 - val_loss: 0.9627 - val_accuracy: 0.6289
# Epoch 89/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6756 - accuracy: 0.7012
# Epoch 00089: val_accuracy did not improve from 0.62892
# 141/141 [==============================] - 103s 733ms/step - loss: 0.6756 - accuracy: 0.7012 - val_loss: 0.9558 - val_accuracy: 0.6152
# Epoch 90/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6766 - accuracy: 0.7017
# Epoch 00090: val_accuracy did not improve from 0.62892
# 141/141 [==============================] - 103s 732ms/step - loss: 0.6766 - accuracy: 0.7017 - val_loss: 0.9620 - val_accuracy: 0.6235
# Epoch 91/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6751 - accuracy: 0.7036
# Epoch 00091: val_accuracy did not improve from 0.62892
# 141/141 [==============================] - 107s 758ms/step - loss: 0.6751 - accuracy: 0.7036 - val_loss: 0.9604 - val_accuracy: 0.6206
# Epoch 92/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6710 - accuracy: 0.7084
# Epoch 00092: val_accuracy did not improve from 0.62892
# 141/141 [==============================] - 103s 730ms/step - loss: 0.6710 - accuracy: 0.7084 - val_loss: 0.9470 - val_accuracy: 0.6186
# Epoch 93/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6774 - accuracy: 0.7013
# Epoch 00093: val_accuracy did not improve from 0.62892
# 141/141 [==============================] - 137s 974ms/step - loss: 0.6774 - accuracy: 0.7013 - val_loss: 0.9487 - val_accuracy: 0.6250
# Epoch 94/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6735 - accuracy: 0.7035
# Epoch 00094: val_accuracy did not improve from 0.62892
# 141/141 [==============================] - 137s 971ms/step - loss: 0.6735 - accuracy: 0.7035 - val_loss: 0.9247 - val_accuracy: 0.6289
# Epoch 95/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6667 - accuracy: 0.7083
# Epoch 00095: val_accuracy did not improve from 0.62892
# 141/141 [==============================] - 112s 797ms/step - loss: 0.6667 - accuracy: 0.7083 - val_loss: 0.9408 - val_accuracy: 0.6230
# Epoch 96/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6655 - accuracy: 0.7083
# Epoch 00096: val_accuracy improved from 0.62892 to 0.63284, saving model to rong_test_2_4.hdf5
# 141/141 [==============================] - 135s 960ms/step - loss: 0.6655 - accuracy: 0.7083 - val_loss: 0.9875 - val_accuracy: 0.6328
# Epoch 97/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6697 - accuracy: 0.7069
# Epoch 00097: val_accuracy did not improve from 0.63284
# 141/141 [==============================] - 139s 984ms/step - loss: 0.6697 - accuracy: 0.7069 - val_loss: 0.9809 - val_accuracy: 0.6279
# Epoch 98/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6645 - accuracy: 0.7068
# Epoch 00098: val_accuracy did not improve from 0.63284
# 141/141 [==============================] - 148s 1s/step - loss: 0.6645 - accuracy: 0.7068 - val_loss: 0.9956 - val_accuracy: 0.6186
# Epoch 99/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6676 - accuracy: 0.7032
# Epoch 00099: val_accuracy did not improve from 0.63284
# 141/141 [==============================] - 106s 751ms/step - loss: 0.6676 - accuracy: 0.7032 - val_loss: 0.9485 - val_accuracy: 0.6324
# Epoch 100/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6623 - accuracy: 0.7089
# Epoch 00100: val_accuracy did not improve from 0.63284
# 141/141 [==============================] - 106s 750ms/step - loss: 0.6623 - accuracy: 0.7089 - val_loss: 0.9275 - val_accuracy: 0.6186

# %%
print(model_info.history.keys())

import matplotlib.pyplot as plt
plt.plot(model_info.history['loss'])
plt.plot(model_info.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# model.load_weights('rong_test_2.h5')

# %%
# model_info = model.fit_generator(
#             train_generator,
#             steps_per_epoch=nb_train_samples // batch_size,
#             epochs=epochs,
#             callbacks = callbacks,
#             validation_data=validation_generator,
#             validation_steps=nb_validation_samples // batch_size)

# %%
# plt.plot(model_info.history['loss'])
# plt.plot(model_info.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
# model.load_weights('rong_test_2.h5')
# # history = model.fit_generator(
# #     train_generator,
# #     steps_per_epoch = nb_train_samples // batch_size,
# #     epochs = epochs,
# #     callbacks = callbacks,
# #     validation_data = validation_generator,
# #     validation_steps = nb_validation_samples // batch_size)

# %%
# import matplotlib.pyplot as plt
# import sklearn
# from sklearn.metrics import classification_report, confusion_matrix
# import numpy as np
# # Found 28709 images belonging to 7 classes.
# # Found 3589 images belonging to 7 classes.


# # nb_train_samples = 28273
# # nb_validation_samples = 3534
# nb_train_samples = 140
# nb_validation_samples = 70

# # We need to recreate our validation generator with shuffle = false
# validation_generator = val_datagen.flow_from_directory(
#         validation_data_dir,
#         color_mode = 'grayscale',
#         target_size=(img_rows, img_cols),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=False)

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# #Confution Matrix and Classification Report
# Y_pred = model.predict_generator(validation_generator, nb_validation_samples // batch_size+1)
# y_pred = np.argmax(Y_pred, axis=1)

# print('Confusion Matrix')
# print(confusion_matrix(validation_generator.classes, y_pred))
# print('Classification Report')
# target_names = list(class_labels.values())
# print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# plt.figure(figsize=(8,8))
# cnf_matrix = confusion_matrix(validation_generator.classes, y_pred)

# plt.imshow(cnf_matrix, interpolation='nearest')
# plt.colorbar()
# tick_marks = np.arange(len(classes))
# _ = plt.xticks(tick_marks, classes, rotation=90)
# _ = plt.yticks(tick_marks, classes)

# %%
# classifier = load_model('./emotion_detector_models/model_v3_71.hdf5')

# %%
# validation_generator = val_datagen.flow_from_directory(
#         validation_data_dir,
#         color_mode = 'grayscale',
#         target_size=(img_rows, img_cols),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=False)

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())
# print(class_labels)

# %%
# from keras.models import load_model
# from keras.optimizers import RMSprop, SGD, Adam
# from keras.preprocessing import image
# import numpy as np
# import os
# import cv2
# import numpy as np
# from os import listdir
# from os.path import isfile, join
# import re

# def draw_test(name, pred, im, true_label):
#     BLACK = [0,0,0]
#     expanded_image = cv2.copyMakeBorder(im, 160, 0, 0, 300 ,cv2.BORDER_CONSTANT,value=BLACK)
#     cv2.putText(expanded_image, "predited - "+ pred, (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,0,255), 2)
#     cv2.putText(expanded_image, "true - "+ true_label, (20, 120) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,255,0), 2)
#     cv2.imshow(name, expanded_image)


# def getRandomImage(path, img_width, img_height):
#     """function loads a random images from a random folder in our test path """
#     folders = path
#     random_directory = np.random.randint(0,len(folders))
#     path_class = folders[random_directory]
#     file_path = path
#     file_names = [f for f in listdir(file_path)]
#     random_file_index = np.random.randint(0,len(file_names))
#     image_name = file_names[random_file_index]
#     final_path = file_path + "/" + image_name
#     return image.load_img(final_path, target_size = (img_width, img_height),grayscale=True), final_path, path_class

# # dimensions of our images
# img_width, img_height = 48, 48

# # We use a very small learning rate 
# model.compile(loss = 'categorical_crossentropy',
#               optimizer = RMSprop(lr = 0.001),
#               metrics = ['accuracy'])

# files = []
# predictions = []
# true_labels = []

# # predicting images
# for i in range(0, 10):
#     path = '../non_load/fer2013/train' 
#     img, final_path, true_label = getRandomImage(path, img_width, img_height)
#     files.append(final_path)
#     true_labels.append(true_label)
#     x = image.img_to_array(img)
#     x = x * 1./255
#     x = np.expand_dims(x, axis=0)
#     images = np.vstack([x])
#     classes = model.predict_classes(images, batch_size = 10)
#     predictions.append(classes)
    
# for i in range(0, len(files)):
#     image = cv2.imread((files[i]))
#     image = cv2.resize(image, None, fx=3, fy=3, interpolation = cv2.INTER_CUBIC)
#     draw_test("Prediction", class_labels[predictions[i][0]], image, true_labels[i])
#     cv2.waitKey(0)

# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# from time import sleep
# from keras.preprocessing.image import img_to_array

# face_classifier = cv2.CascadeClassifier('../datasets/classifiers/haarcascade_frontalface_default.xml')
# classifier =load_model('rong_test_2_1.hdf5')

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# def face_detector(img):
#     # Convert image to grayscale
#     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#     faces = face_classifier.detectMultiScale(gray, 1.3, 5)
#     if faces is ():
#         return (0,0,0,0), np.zeros((48,48), np.uint8), img
    
#     for (x,y,w,h) in faces:
#         cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#         roi_gray = gray[y:y+h, x:x+w]

#     try:
#         roi_gray = cv2.resize(roi_gray, (48, 48), interpolation = cv2.INTER_AREA)
#     except:
#         return (x,w,y,h), np.zeros((48,48), np.uint8), img
#     return (x,w,y,h), roi_gray, img

# cap = cv2.VideoCapture(0)

# while True:

#     ret, frame = cap.read()
#     rect, face, image = face_detector(frame)
#     if np.sum([face]) != 0.0:
#         roi = face.astype("float") / 255.0
#         roi = img_to_array(roi)
#         roi = np.expand_dims(roi, axis=0)

#         # make a prediction on the ROI, then lookup the class
#         preds = classifier.predict(roi)[0]
#         label = class_labels[preds.argmax()]  
#         label_position = (rect[0] + int((rect[1]/2)), rect[2] + 25)
#         cv2.putText(image, label, label_position , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
#     else:
#         cv2.putText(image, "No Face Found", (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
        
#     cv2.imshow('All', image)
#     if cv2.waitKey(1) == 13: #13 is the Enter Key
#         break
        
# cap.release()
cv2.destroyAllWindows()

# %%
# cap.release()
# cv2.destroyAllWindows()
