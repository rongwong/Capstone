# %% [markdown]
# credits: APEKSHA PRIYA, Priya Dwivedi
#
# https://github.com/priya-dwivedi/face_and_emotion_detection/blob/master/src/EmotionDetector_v2.ipynb
# https://towardsdatascience.com/face-detection-recognition-and-emotion-detection-in-8-lines-of-code-b2ce32d4d5de

# %%
from __future__ import print_function
import keras

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

# from keras.models import Sequential
# from keras.layers.normalization import BatchNormalization
# from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.advanced_activations import ELU
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras.optimizers import RMSprop, SGD, Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import regularizers
from keras.regularizers import l1

from keras.models import load_model

import cv2
import random
import numpy as np
# import os, os.path
# import glob
# from skimage.feature import Cascade
# import skimage 
# from skimage import data, color
# import matplotlib.pyplot as plt
# from PIL import Image

# %%
# initializing
num_classes = 4
img_rows, img_cols = 48, 48
batch_size = 200 #(change back for full load)

train_data_dir = '../test_full/train_cropped'
validation_data_dir = '../test_full/validation'

# %%
# Let's use some data augmentaiton 
# train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 27800 images belonging to 4 classes.
# Found 2590 images belonging to 4 classes.

# %%
print(validation_generator.class_indices)
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
# Create the model 2
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='elu',input_shape=(48,48,1)))
# model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3, 3), activation='elu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='elu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, kernel_size=(3, 3), activation='elu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(2, 2), activation='elu'))
# model.add(BatchNormalization())

model.add(Flatten())

model.add(Dense(120, activation='elu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))
#model.add(Activation("softmax"))

model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())
# model.add(Activation("softmax"))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 256)         590080
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 1, 128)         131200
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               15480
# _________________________________________________________________
# dropout (Dropout)            (None, 120)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 484
# =================================================================
# Total params: 1,125,084
# Trainable params: 1,125,084
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # Create the model
# model = Sequential()

# model.add(Conv2D(32, kernel_size=(3, 3), activation='elu',input_shape=(48,48,1)))
# # model.add(BatchNormalization())

# model.add(Conv2D(64, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(128, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(256, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(64, kernel_size=(1, 1), activation='elu'))
# # # model.add(BatchNormalization())

# model.add(Conv2D(3, kernel_size=(4, 4), activation='elu'))
# # model.add(BatchNormalization())

# model.add(Flatten())

# model.add(Activation("softmax"))

# model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())

# %%
# %%time
# If you want to train the same model or try other models, go for this


# filepath = os.path.join("./emotion_detector_models/model_v6_{epoch}.hdf5")

checkpoint = keras.callbacks.ModelCheckpoint('rong_test_2_8.hdf5',
                                             monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                             mode='max')

callbacks = [checkpoint]

# checkpoint = ModelCheckpoint('rong_test_2.hdf5',
#                              monitor='val_loss',
#                              mode='min',
#                              save_best_only=True,
#                              verbose=1)

# earlystop = EarlyStopping(monitor='val_loss',
#                           min_delta=0,
#                           patience=9,
#                           verbose=1,
#                           restore_best_weights=True
#                           )

# reduce_lr = ReduceLROnPlateau(monitor='val_loss',
#                               factor=0.2,
#                               patience=3,
#                               verbose=1,
#                               min_delta=0.0001)

# callbacks = [checkpoint,reduce_lr]
# callbacks = [earlystop,checkpoint,reduce_lr]


# if mode == "train":
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001, decay=1e-6),metrics=['accuracy'])
nb_train_samples = 27800
nb_validation_samples = 2590
epochs = 200

model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)

# plot_model_history(model_info)
model.save_weights('rong_test_2_8_weights.h5')
model.save('rong_test_2_8model_file.h5')
# Out:
# WARNING:tensorflow:From <timed exec>:49: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/200
# 139/139 [==============================] - ETA: 0s - loss: 1.2967 - accuracy: 0.4098
# Epoch 00001: val_accuracy improved from -inf to 0.41875, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 129s 927ms/step - loss: 1.2967 - accuracy: 0.4098 - val_loss: 1.3120 - val_accuracy: 0.4187
# Epoch 2/200
# 139/139 [==============================] - ETA: 0s - loss: 1.1298 - accuracy: 0.5133
# Epoch 00002: val_accuracy improved from 0.41875 to 0.47000, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 158s 1s/step - loss: 1.1298 - accuracy: 0.5133 - val_loss: 1.2537 - val_accuracy: 0.4700
# Epoch 3/200
# 139/139 [==============================] - ETA: 0s - loss: 1.0488 - accuracy: 0.5545
# Epoch 00003: val_accuracy improved from 0.47000 to 0.49833, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 160s 1s/step - loss: 1.0488 - accuracy: 0.5545 - val_loss: 1.2766 - val_accuracy: 0.4983
# Epoch 4/200
# 139/139 [==============================] - ETA: 0s - loss: 0.9874 - accuracy: 0.5835
# Epoch 00004: val_accuracy did not improve from 0.49833
# 139/139 [==============================] - 169s 1s/step - loss: 0.9874 - accuracy: 0.5835 - val_loss: 1.1717 - val_accuracy: 0.4971
# Epoch 5/200
# 139/139 [==============================] - ETA: 0s - loss: 0.9518 - accuracy: 0.6011
# Epoch 00005: val_accuracy improved from 0.49833 to 0.51250, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 174s 1s/step - loss: 0.9518 - accuracy: 0.6011 - val_loss: 1.2589 - val_accuracy: 0.5125
# Epoch 6/200
# 139/139 [==============================] - ETA: 0s - loss: 0.9281 - accuracy: 0.6104
# Epoch 00006: val_accuracy improved from 0.51250 to 0.54208, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 171s 1s/step - loss: 0.9281 - accuracy: 0.6104 - val_loss: 1.1654 - val_accuracy: 0.5421
# Epoch 7/200
# 139/139 [==============================] - ETA: 0s - loss: 0.9037 - accuracy: 0.6204
# Epoch 00007: val_accuracy did not improve from 0.54208
# 139/139 [==============================] - 149s 1s/step - loss: 0.9037 - accuracy: 0.6204 - val_loss: 1.1702 - val_accuracy: 0.5304
# Epoch 8/200
# 139/139 [==============================] - ETA: 0s - loss: 0.8742 - accuracy: 0.6363
# Epoch 00008: val_accuracy improved from 0.54208 to 0.54250, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 159s 1s/step - loss: 0.8742 - accuracy: 0.6363 - val_loss: 1.2417 - val_accuracy: 0.5425
# Epoch 9/200
# 139/139 [==============================] - ETA: 0s - loss: 0.8505 - accuracy: 0.6495
# Epoch 00009: val_accuracy improved from 0.54250 to 0.55458, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 155s 1s/step - loss: 0.8505 - accuracy: 0.6495 - val_loss: 1.1316 - val_accuracy: 0.5546
# Epoch 10/200
# 139/139 [==============================] - ETA: 0s - loss: 0.8351 - accuracy: 0.6581
# Epoch 00010: val_accuracy improved from 0.55458 to 0.56083, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 156s 1s/step - loss: 0.8351 - accuracy: 0.6581 - val_loss: 1.1310 - val_accuracy: 0.5608
# Epoch 11/200
# 139/139 [==============================] - ETA: 0s - loss: 0.8190 - accuracy: 0.6622
# Epoch 00011: val_accuracy did not improve from 0.56083
# 139/139 [==============================] - 155s 1s/step - loss: 0.8190 - accuracy: 0.6622 - val_loss: 1.1378 - val_accuracy: 0.5537
# Epoch 12/200
# 139/139 [==============================] - ETA: 0s - loss: 0.8013 - accuracy: 0.6732
# Epoch 00012: val_accuracy improved from 0.56083 to 0.58250, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 155s 1s/step - loss: 0.8013 - accuracy: 0.6732 - val_loss: 1.1417 - val_accuracy: 0.5825
# Epoch 13/200
# 139/139 [==============================] - ETA: 0s - loss: 0.7819 - accuracy: 0.6814
# Epoch 00013: val_accuracy improved from 0.58250 to 0.58708, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 145s 1s/step - loss: 0.7819 - accuracy: 0.6814 - val_loss: 1.1569 - val_accuracy: 0.5871
# Epoch 14/200
# 139/139 [==============================] - ETA: 0s - loss: 0.7760 - accuracy: 0.6824
# Epoch 00014: val_accuracy did not improve from 0.58708
# 139/139 [==============================] - 157s 1s/step - loss: 0.7760 - accuracy: 0.6824 - val_loss: 1.1454 - val_accuracy: 0.5642
# Epoch 15/200
# 139/139 [==============================] - ETA: 0s - loss: 0.7557 - accuracy: 0.6933
# Epoch 00015: val_accuracy did not improve from 0.58708
# 139/139 [==============================] - 153s 1s/step - loss: 0.7557 - accuracy: 0.6933 - val_loss: 1.1686 - val_accuracy: 0.5671
# Epoch 16/200
# 139/139 [==============================] - ETA: 0s - loss: 0.7479 - accuracy: 0.6992
# Epoch 00016: val_accuracy did not improve from 0.58708
# 139/139 [==============================] - 154s 1s/step - loss: 0.7479 - accuracy: 0.6992 - val_loss: 1.2450 - val_accuracy: 0.5871
# Epoch 17/200
# 139/139 [==============================] - ETA: 0s - loss: 0.7352 - accuracy: 0.7029
# Epoch 00017: val_accuracy improved from 0.58708 to 0.59375, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 154s 1s/step - loss: 0.7352 - accuracy: 0.7029 - val_loss: 1.1870 - val_accuracy: 0.5938
# Epoch 18/200
# 139/139 [==============================] - ETA: 0s - loss: 0.7217 - accuracy: 0.7092
# Epoch 00018: val_accuracy did not improve from 0.59375
# 139/139 [==============================] - 153s 1s/step - loss: 0.7217 - accuracy: 0.7092 - val_loss: 1.1473 - val_accuracy: 0.5929
# Epoch 19/200
# 139/139 [==============================] - ETA: 0s - loss: 0.7156 - accuracy: 0.7125
# Epoch 00019: val_accuracy did not improve from 0.59375
# 139/139 [==============================] - 152s 1s/step - loss: 0.7156 - accuracy: 0.7125 - val_loss: 1.1878 - val_accuracy: 0.5733
# Epoch 20/200
# 139/139 [==============================] - ETA: 0s - loss: 0.6955 - accuracy: 0.7220
# Epoch 00020: val_accuracy improved from 0.59375 to 0.60167, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 152s 1s/step - loss: 0.6955 - accuracy: 0.7220 - val_loss: 1.1608 - val_accuracy: 0.6017
# Epoch 21/200
# 139/139 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.7236
# Epoch 00021: val_accuracy did not improve from 0.60167
# 139/139 [==============================] - 154s 1s/step - loss: 0.6909 - accuracy: 0.7236 - val_loss: 1.1354 - val_accuracy: 0.5971
# Epoch 22/200
# 139/139 [==============================] - ETA: 0s - loss: 0.6743 - accuracy: 0.7327
# Epoch 00022: val_accuracy did not improve from 0.60167
# 139/139 [==============================] - 153s 1s/step - loss: 0.6743 - accuracy: 0.7327 - val_loss: 1.1205 - val_accuracy: 0.5975
# Epoch 23/200
# 139/139 [==============================] - ETA: 0s - loss: 0.6761 - accuracy: 0.7318
# Epoch 00023: val_accuracy improved from 0.60167 to 0.60417, saving model to rong_test_2_8.hdf5
# 139/139 [==============================] - 153s 1s/step - loss: 0.6761 - accuracy: 0.7318 - val_loss: 1.1346 - val_accuracy: 0.6042
# Epoch 24/200
# 139/139 [==============================] - ETA: 0s - loss: 0.6600 - accuracy: 0
200
# 139/139 [==============================] - ETA: 0s - loss: 0.2727 - accuracy: 0.8995
# Epoch 00177: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2727 - accuracy: 0.8995 - val_loss: 2.7190 - val_accuracy: 0.6021
# Epoch 178/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2777 - accuracy: 0.8991
# Epoch 00178: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 149s 1s/step - loss: 0.2777 - accuracy: 0.8991 - val_loss: 2.7527 - val_accuracy: 0.5933
# Epoch 179/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.9005
# Epoch 00179: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2667 - accuracy: 0.9005 - val_loss: 2.7250 - val_accuracy: 0.6121
# Epoch 180/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.9008
# Epoch 00180: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 149s 1s/step - loss: 0.2746 - accuracy: 0.9008 - val_loss: 2.5225 - val_accuracy: 0.6158
# Epoch 181/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2740 - accuracy: 0.9004
# Epoch 00181: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 149s 1s/step - loss: 0.2740 - accuracy: 0.9004 - val_loss: 2.6950 - val_accuracy: 0.6146
# Epoch 182/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9055
# Epoch 00182: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 149s 1s/step - loss: 0.2597 - accuracy: 0.9055 - val_loss: 2.7920 - val_accuracy: 0.5962
# Epoch 183/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.9003
# Epoch 00183: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2749 - accuracy: 0.9003 - val_loss: 2.7190 - val_accuracy: 0.5979
# Epoch 184/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2615 - accuracy: 0.9048
# Epoch 00184: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 151s 1s/step - loss: 0.2615 - accuracy: 0.9048 - val_loss: 2.4692 - val_accuracy: 0.6029
# Epoch 185/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.9031
# Epoch 00185: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2634 - accuracy: 0.9031 - val_loss: 3.1366 - val_accuracy: 0.6004
# Epoch 186/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.9008
# Epoch 00186: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 149s 1s/step - loss: 0.2717 - accuracy: 0.9008 - val_loss: 2.9880 - val_accuracy: 0.5983
# Epoch 187/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.9021
# Epoch 00187: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2648 - accuracy: 0.9021 - val_loss: 2.5579 - val_accuracy: 0.6075
# Epoch 188/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2743 - accuracy: 0.9001
# Epoch 00188: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2743 - accuracy: 0.9001 - val_loss: 2.6682 - val_accuracy: 0.6112
# Epoch 189/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2626 - accuracy: 0.9027
# Epoch 00189: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2626 - accuracy: 0.9027 - val_loss: 2.6144 - val_accuracy: 0.6104
# Epoch 190/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2619 - accuracy: 0.9043
# Epoch 00190: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2619 - accuracy: 0.9043 - val_loss: 3.0174 - val_accuracy: 0.6029
# Epoch 191/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2615 - accuracy: 0.9041
# Epoch 00191: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2615 - accuracy: 0.9041 - val_loss: 2.6940 - val_accuracy: 0.5996
# Epoch 192/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2625 - accuracy: 0.9043
# Epoch 00192: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 149s 1s/step - loss: 0.2625 - accuracy: 0.9043 - val_loss: 2.7278 - val_accuracy: 0.5938
# Epoch 193/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.9025
# Epoch 00193: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2676 - accuracy: 0.9025 - val_loss: 2.5222 - val_accuracy: 0.6042
# Epoch 194/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.9051
# Epoch 00194: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 149s 1s/step - loss: 0.2611 - accuracy: 0.9051 - val_loss: 3.1548 - val_accuracy: 0.6054
# Epoch 195/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2639 - accuracy: 0.9043
# Epoch 00195: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2639 - accuracy: 0.9043 - val_loss: 3.0049 - val_accuracy: 0.6167
# Epoch 196/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2546 - accuracy: 0.9050
# Epoch 00196: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 149s 1s/step - loss: 0.2546 - accuracy: 0.9050 - val_loss: 2.8889 - val_accuracy: 0.6112
# Epoch 197/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9044
# Epoch 00197: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2623 - accuracy: 0.9044 - val_loss: 2.9536 - val_accuracy: 0.5942
# Epoch 198/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2555 - accuracy: 0.9076
# Epoch 00198: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 147s 1s/step - loss: 0.2555 - accuracy: 0.9076 - val_loss: 3.1258 - val_accuracy: 0.6154
# Epoch 199/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2567 - accuracy: 0.9041
# Epoch 00199: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 151s 1s/step - loss: 0.2567 - accuracy: 0.9041 - val_loss: 2.8381 - val_accuracy: 0.6083
# Epoch 200/200
# 139/139 [==============================] - ETA: 0s - loss: 0.2557 - accuracy: 0.9071
# Epoch 00200: val_accuracy did not improve from 0.62792
# 139/139 [==============================] - 150s 1s/step - loss: 0.2557 - accuracy: 0.9071 - val_loss: 2.7251 - val_accuracy: 0.6054
# CPU times: user 1d 6h 34min 22s, sys: 1h 45min 51s, total: 1d 8h 20min 14s
# Wall time: 8h 41min 1s

# %%
print(model_info.history.keys())

import matplotlib.pyplot as plt
plt.plot(model_info.history['loss'])
plt.plot(model_info.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# model.load_weights('rong_test_2_5.h5')

# %%
# model_info = model.fit_generator(
#             train_generator,
#             steps_per_epoch=nb_train_samples // batch_size,
#             epochs=epochs,
#             callbacks = callbacks,
#             validation_data=validation_generator,
#             validation_steps=nb_validation_samples // batch_size)

# %%
# plt.plot(model_info.history['loss'])
# plt.plot(model_info.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
# model.load_weights('rong_test_2.h5')
# # history = model.fit_generator(
# #     train_generator,
# #     steps_per_epoch = nb_train_samples // batch_size,
# #     epochs = epochs,
# #     callbacks = callbacks,
# #     validation_data = validation_generator,
# #     validation_steps = nb_validation_samples // batch_size)

# %%
# import matplotlib.pyplot as plt
# import sklearn
# from sklearn.metrics import classification_report, confusion_matrix
# import numpy as np
# # Found 28709 images belonging to 7 classes.
# # Found 3589 images belonging to 7 classes.


# # nb_train_samples = 28273
# # nb_validation_samples = 3534
# nb_train_samples = 140
# nb_validation_samples = 70

# We need to recreate our validation generator with shuffle = false
validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

class_labels = validation_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())

#Confution Matrix and Classification Report
Y_pred = model.predict_generator(validation_generator, nb_validation_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
print(confusion_matrix(validation_generator.classes, y_pred))
print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

plt.figure(figsize=(8,8))
cnf_matrix = confusion_matrix(validation_generator.classes, y_pred)

plt.imshow(cnf_matrix, interpolation='nearest')
plt.colorbar()
tick_marks = np.arange(len(classes))
_ = plt.xticks(tick_marks, classes, rotation=90)
_ = plt.yticks(tick_marks, classes)
# Out:
# Found 2590 images belonging to 4 classes.
# WARNING:tensorflow:From <ipython-input-13-948a64080fa0>:28: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# Confusion Matrix
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-948a64080fa0> in <module>
#      30
#      31 print('Confusion Matrix')
# ---> 32 print(confusion_matrix(validation_generator.classes, y_pred))
#      33 print('Classification Report')
#      34 target_names = list(class_labels.values())
#
# NameError: name 'confusion_matrix' is not defined

# %%
# classifier = load_model('./emotion_detector_models/model_v3_71.hdf5')

# %%
validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

class_labels = validation_generator.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())
print(class_labels)

# %%
# from keras.models import load_model
# from keras.optimizers import RMSprop, SGD, Adam
# from keras.preprocessing import image
# import numpy as np
# import os
# import cv2
# import numpy as np
# from os import listdir
# from os.path import isfile, join
# import re

# def draw_test(name, pred, im, true_label):
#     BLACK = [0,0,0]
#     expanded_image = cv2.copyMakeBorder(im, 160, 0, 0, 300 ,cv2.BORDER_CONSTANT,value=BLACK)
#     cv2.putText(expanded_image, "predited - "+ pred, (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,0,255), 2)
#     cv2.putText(expanded_image, "true - "+ true_label, (20, 120) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,255,0), 2)
#     cv2.imshow(name, expanded_image)


# def getRandomImage(path, img_width, img_height):
#     """function loads a random images from a random folder in our test path """
#     folders = path
#     random_directory = np.random.randint(0,len(folders))
#     path_class = folders[random_directory]
#     file_path = path
#     file_names = [f for f in listdir(file_path)]
#     random_file_index = np.random.randint(0,len(file_names))
#     image_name = file_names[random_file_index]
#     final_path = file_path + "/" + image_name
#     return image.load_img(final_path, target_size = (img_width, img_height),grayscale=True), final_path, path_class

# # dimensions of our images
# img_width, img_height = 48, 48

# # We use a very small learning rate 
# model.compile(loss = 'categorical_crossentropy',
#               optimizer = RMSprop(lr = 0.001),
#               metrics = ['accuracy'])

# files = []
# predictions = []
# true_labels = []

# # predicting images
# for i in range(0, 10):
#     path = '../non_load/fer2013/train' 
#     img, final_path, true_label = getRandomImage(path, img_width, img_height)
#     files.append(final_path)
#     true_labels.append(true_label)
#     x = image.img_to_array(img)
#     x = x * 1./255
#     x = np.expand_dims(x, axis=0)
#     images = np.vstack([x])
#     classes = model.predict_classes(images, batch_size = 10)
#     predictions.append(classes)
    
# for i in range(0, len(files)):
#     image = cv2.imread((files[i]))
#     image = cv2.resize(image, None, fx=3, fy=3, interpolation = cv2.INTER_CUBIC)
#     draw_test("Prediction", class_labels[predictions[i][0]], image, true_labels[i])
#     cv2.waitKey(0)

# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# from time import sleep
# from keras.preprocessing.image import img_to_array

# face_classifier = cv2.CascadeClassifier('../datasets/classifiers/haarcascade_frontalface_default.xml')
# classifier =load_model('rong_test_2_1.hdf5')

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# def face_detector(img):
#     # Convert image to grayscale
#     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#     faces = face_classifier.detectMultiScale(gray, 1.3, 5)
#     if faces is ():
#         return (0,0,0,0), np.zeros((48,48), np.uint8), img
    
#     for (x,y,w,h) in faces:
#         cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#         roi_gray = gray[y:y+h, x:x+w]

#     try:
#         roi_gray = cv2.resize(roi_gray, (48, 48), interpolation = cv2.INTER_AREA)
#     except:
#         return (x,w,y,h), np.zeros((48,48), np.uint8), img
#     return (x,w,y,h), roi_gray, img

# cap = cv2.VideoCapture(0)

# while True:

#     ret, frame = cap.read()
#     rect, face, image = face_detector(frame)
#     if np.sum([face]) != 0.0:
#         roi = face.astype("float") / 255.0
#         roi = img_to_array(roi)
#         roi = np.expand_dims(roi, axis=0)

#         # make a prediction on the ROI, then lookup the class
#         preds = classifier.predict(roi)[0]
#         label = class_labels[preds.argmax()]  
#         label_position = (rect[0] + int((rect[1]/2)), rect[2] + 25)
#         cv2.putText(image, label, label_position , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
#     else:
#         cv2.putText(image, "No Face Found", (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
        
#     cv2.imshow('All', image)
#     if cv2.waitKey(1) == 13: #13 is the Enter Key
#         break
        
# cap.release()
# cv2.destroyAllWindows()

# %%
# cap.release()
# cv2.destroyAllWindows()
