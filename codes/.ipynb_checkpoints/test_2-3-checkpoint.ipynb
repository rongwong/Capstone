# %% [markdown]
# credits: APEKSHA PRIYA, Priya Dwivedi
#
# https://github.com/priya-dwivedi/face_and_emotion_detection/blob/master/src/EmotionDetector_v2.ipynb
# https://towardsdatascience.com/face-detection-recognition-and-emotion-detection-in-8-lines-of-code-b2ce32d4d5de

# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
import os
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.advanced_activations import ELU
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras.optimizers import RMSprop, SGD, Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import regularizers
from keras.regularizers import l1

from keras.models import load_model

# %%
# initializing
num_classes = 3
img_rows, img_cols = 48, 48
batch_size = 120 #(change back for full load)

train_data_dir = '../test/train'
validation_data_dir = '../test/validation'

# %%
# Let's use some data augmentaiton 
# train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 16944 images belonging to 3 classes.
# Found 2099 images belonging to 3 classes.

# %%
print(validation_generator.class_indices)
# Out:
# {'happy': 0, 'neutral': 1, 'sad': 2}

# %%
# Create the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(48,48,1)))
# model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(5, kernel_size=(1, 1), activation='relu'))
# # model.add(BatchNormalization())

model.add(Conv2D(3, kernel_size=(4, 4), activation='relu'))
# model.add(BatchNormalization())

model.add(Flatten())

model.add(Activation("softmax"))

model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 5)           645
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 1, 3)           243
# _________________________________________________________________
# flatten (Flatten)            (None, 3)                 0
# _________________________________________________________________
# activation (Activation)      (None, 3)                 0
# =================================================================
# Total params: 241,144
# Trainable params: 241,144
# Non-trainable params: 0
# _________________________________________________________________

# %%
# # Create the model 2
# model = Sequential()

# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu',input_shape=(48,48,1)))
# # model.add(BatchNormalization())

# model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(7, kernel_size=(1, 1), activation='relu'))
# # # model.add(BatchNormalization())

# model.add(Conv2D(7, kernel_size=(4, 4), activation='relu'))
# # model.add(BatchNormalization())

# model.add(Flatten())

# model.add(Dense(120, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# #model.add(Activation("softmax"))

# model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())
# model.add(Activation("softmax"))

# %%
# If you want to train the same model or try other models, go for this


# filepath = os.path.join("./emotion_detector_models/model_v6_{epoch}.hdf5")

checkpoint = keras.callbacks.ModelCheckpoint('rong_test_2_2.hdf5',
                                             monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                             mode='max')

callbacks = [checkpoint]

# checkpoint = ModelCheckpoint('rong_test_2.hdf5',
#                              monitor='val_loss',
#                              mode='min',
#                              save_best_only=True,
#                              verbose=1)

# earlystop = EarlyStopping(monitor='val_loss',
#                           min_delta=0,
#                           patience=9,
#                           verbose=1,
#                           restore_best_weights=True
#                           )

# reduce_lr = ReduceLROnPlateau(monitor='val_loss',
#                               factor=0.2,
#                               patience=3,
#                               verbose=1,
#                               min_delta=0.0001)

# callbacks = [checkpoint,reduce_lr]
# callbacks = [earlystop,checkpoint,reduce_lr]


# if mode == "train":
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])
nb_train_samples = 16944
nb_validation_samples = 2099
epochs = 100

model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)

# plot_model_history(model_info)
model.save_weights('rong_test_2_2.h5')
# Out:
# WARNING:tensorflow:From <ipython-input-7-387a9af5253b>:49: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0776 - accuracy: 0.4259
# Epoch 00001: val_accuracy improved from -inf to 0.41863, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 75s 532ms/step - loss: 1.0776 - accuracy: 0.4259 - val_loss: 1.0725 - val_accuracy: 0.4186
# Epoch 2/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0673 - accuracy: 0.4257
# Epoch 00002: val_accuracy improved from 0.41863 to 0.42059, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 72s 512ms/step - loss: 1.0673 - accuracy: 0.4257 - val_loss: 1.0621 - val_accuracy: 0.4206
# Epoch 3/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0589 - accuracy: 0.4268
# Epoch 00003: val_accuracy did not improve from 0.42059
# 141/141 [==============================] - 75s 534ms/step - loss: 1.0589 - accuracy: 0.4268 - val_loss: 1.0526 - val_accuracy: 0.4191
# Epoch 4/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0506 - accuracy: 0.4300
# Epoch 00004: val_accuracy did not improve from 0.42059
# 141/141 [==============================] - 81s 573ms/step - loss: 1.0506 - accuracy: 0.4300 - val_loss: 1.0416 - val_accuracy: 0.4206
# Epoch 5/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0437 - accuracy: 0.4304
# Epoch 00005: val_accuracy improved from 0.42059 to 0.42304, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 71s 506ms/step - loss: 1.0437 - accuracy: 0.4304 - val_loss: 1.0370 - val_accuracy: 0.4230
# Epoch 6/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0387 - accuracy: 0.4289
# Epoch 00006: val_accuracy improved from 0.42304 to 0.42402, saving model to rong_test_2_2.hdf5
# Epoch 00055: val_accuracy improved from 0.58578 to 0.59314, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 68s 485ms/step - loss: 0.8173 - accuracy: 0.6172 - val_loss: 0.9631 - val_accuracy: 0.5931
# Epoch 56/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8141 - accuracy: 0.6186
# Epoch 00056: val_accuracy did not improve from 0.59314
# 141/141 [==============================] - 69s 489ms/step - loss: 0.8141 - accuracy: 0.6186 - val_loss: 0.9499 - val_accuracy: 0.5922
# Epoch 57/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8107 - accuracy: 0.6224
# Epoch 00057: val_accuracy did not improve from 0.59314
# 141/141 [==============================] - 68s 484ms/step - loss: 0.8107 - accuracy: 0.6224 - val_loss: 0.9619 - val_accuracy: 0.5789
# Epoch 58/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8087 - accuracy: 0.6221
# Epoch 00058: val_accuracy did not improve from 0.59314
# 141/141 [==============================] - 67s 478ms/step - loss: 0.8087 - accuracy: 0.6221 - val_loss: 0.9575 - val_accuracy: 0.5868
# Epoch 59/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8009 - accuracy: 0.6267
# Epoch 00059: val_accuracy did not improve from 0.59314
# 141/141 [==============================] - 68s 481ms/step - loss: 0.8009 - accuracy: 0.6267 - val_loss: 0.9594 - val_accuracy: 0.5868
# Epoch 60/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8016 - accuracy: 0.6316
# Epoch 00060: val_accuracy did not improve from 0.59314
# 141/141 [==============================] - 69s 488ms/step - loss: 0.8016 - accuracy: 0.6316 - val_loss: 0.9852 - val_accuracy: 0.5770
# Epoch 61/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7969 - accuracy: 0.6298
# Epoch 00061: val_accuracy did not improve from 0.59314
# 141/141 [==============================] - 68s 483ms/step - loss: 0.7969 - accuracy: 0.6298 - val_loss: 0.9804 - val_accuracy: 0.5721
# Epoch 62/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7941 - accuracy: 0.6269
# Epoch 00062: val_accuracy did not improve from 0.59314
# 141/141 [==============================] - 67s 476ms/step - loss: 0.7941 - accuracy: 0.6269 - val_loss: 0.9620 - val_accuracy: 0.5907
# Epoch 63/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7895 - accuracy: 0.6301
# Epoch 00063: val_accuracy improved from 0.59314 to 0.59559, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 68s 482ms/step - loss: 0.7895 - accuracy: 0.6301 - val_loss: 0.9700 - val_accuracy: 0.5956
# Epoch 64/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7802 - accuracy: 0.6403
# Epoch 00064: val_accuracy improved from 0.59559 to 0.59853, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 68s 483ms/step - loss: 0.7802 - accuracy: 0.6403 - val_loss: 0.9463 - val_accuracy: 0.5985
# Epoch 65/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7814 - accuracy: 0.6395
# Epoch 00065: val_accuracy did not improve from 0.59853
# 141/141 [==============================] - 68s 483ms/step - loss: 0.7814 - accuracy: 0.6395 - val_loss: 0.9800 - val_accuracy: 0.5858
# Epoch 66/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7811 - accuracy: 0.6380
# Epoch 00066: val_accuracy did not improve from 0.59853
# 141/141 [==============================] - 46s 328ms/step - loss: 0.7811 - accuracy: 0.6380 - val_loss: 0.9477 - val_accuracy: 0.5941
# Epoch 67/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7813 - accuracy: 0.6413
# Epoch 00067: val_accuracy did not improve from 0.59853
# 141/141 [==============================] - 40s 281ms/step - loss: 0.7813 - accuracy: 0.6413 - val_loss: 0.9571 - val_accuracy: 0.5917
# Epoch 68/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7719 - accuracy: 0.6472
# Epoch 00068: val_accuracy did not improve from 0.59853
# 141/141 [==============================] - 40s 280ms/step - loss: 0.7719 - accuracy: 0.6472 - val_loss: 0.9544 - val_accuracy: 0.5951
# Epoch 69/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7723 - accuracy: 0.6467
# Epoch 00069: val_accuracy did not improve from 0.59853
# 141/141 [==============================] - 40s 281ms/step - loss: 0.7723 - accuracy: 0.6467 - val_loss: 0.9733 - val_accuracy: 0.5912
# Epoch 70/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7693 - accuracy: 0.6495
# Epoch 00070: val_accuracy did not improve from 0.59853
# 141/141 [==============================] - 40s 281ms/step - loss: 0.7693 - accuracy: 0.6495 - val_loss: 0.9929 - val_accuracy: 0.5804
# Epoch 71/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7671 - accuracy: 0.6462
# Epoch 00071: val_accuracy improved from 0.59853 to 0.60196, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 40s 283ms/step - loss: 0.7671 - accuracy: 0.6462 - val_loss: 0.9589 - val_accuracy: 0.6020
# Epoch 72/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7639 - accuracy: 0.6463
# Epoch 00072: val_accuracy improved from 0.60196 to 0.60735, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 41s 289ms/step - loss: 0.7639 - accuracy: 0.6463 - val_loss: 0.9575 - val_accuracy: 0.6074
# Epoch 73/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7619 - accuracy: 0.6526
# Epoch 00073: val_accuracy did not improve from 0.60735
# 141/141 [==============================] - 41s 289ms/step - loss: 0.7619 - accuracy: 0.6526 - val_loss: 0.9593 - val_accuracy: 0.6034
# Epoch 74/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7593 - accuracy: 0.6477
# Epoch 00074: val_accuracy did not improve from 0.60735
# 141/141 [==============================] - 41s 287ms/step - loss: 0.7593 - accuracy: 0.6477 - val_loss: 0.9671 - val_accuracy: 0.5902
# Epoch 75/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7616 - accuracy: 0.6476
# Epoch 00075: val_accuracy improved from 0.60735 to 0.60784, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 40s 282ms/step - loss: 0.7616 - accuracy: 0.6476 - val_loss: 0.9817 - val_accuracy: 0.6078
# Epoch 76/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7617 - accuracy: 0.6466
# Epoch 00076: val_accuracy did not improve from 0.60784
# 141/141 [==============================] - 39s 279ms/step - loss: 0.7617 - accuracy: 0.6466 - val_loss: 0.9406 - val_accuracy: 0.6059
# Epoch 77/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7584 - accuracy: 0.6535
# Epoch 00077: val_accuracy did not improve from 0.60784
# 141/141 [==============================] - 40s 281ms/step - loss: 0.7584 - accuracy: 0.6535 - val_loss: 0.9797 - val_accuracy: 0.5966
# Epoch 78/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7433 - accuracy: 0.6609
# Epoch 00078: val_accuracy improved from 0.60784 to 0.61078, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 40s 282ms/step - loss: 0.7433 - accuracy: 0.6609 - val_loss: 0.9731 - val_accuracy: 0.6108
# Epoch 79/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7473 - accuracy: 0.6580
# Epoch 00079: val_accuracy improved from 0.61078 to 0.61471, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 40s 283ms/step - loss: 0.7473 - accuracy: 0.6580 - val_loss: 0.9609 - val_accuracy: 0.6147
# Epoch 80/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7513 - accuracy: 0.6569
# Epoch 00080: val_accuracy did not improve from 0.61471
# 141/141 [==============================] - 40s 282ms/step - loss: 0.7513 - accuracy: 0.6569 - val_loss: 0.9867 - val_accuracy: 0.6010
# Epoch 81/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7501 - accuracy: 0.6620
# Epoch 00081: val_accuracy did not improve from 0.61471
# 141/141 [==============================] - 41s 288ms/step - loss: 0.7501 - accuracy: 0.6620 - val_loss: 0.9788 - val_accuracy: 0.6103
# Epoch 82/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7458 - accuracy: 0.6628
# Epoch 00082: val_accuracy did not improve from 0.61471
# 141/141 [==============================] - 41s 289ms/step - loss: 0.7458 - accuracy: 0.6628 - val_loss: 0.9739 - val_accuracy: 0.6083
# Epoch 83/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7400 - accuracy: 0.6629
# Epoch 00083: val_accuracy did not improve from 0.61471
# 141/141 [==============================] - 41s 289ms/step - loss: 0.7400 - accuracy: 0.6629 - val_loss: 0.9749 - val_accuracy: 0.5990
# Epoch 84/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7350 - accuracy: 0.6682
# Epoch 00084: val_accuracy did not improve from 0.61471
# 141/141 [==============================] - 40s 284ms/step - loss: 0.7350 - accuracy: 0.6682 - val_loss: 0.9772 - val_accuracy: 0.6005
# Epoch 85/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7374 - accuracy: 0.6606
# Epoch 00085: val_accuracy did not improve from 0.61471
# 141/141 [==============================] - 40s 283ms/step - loss: 0.7374 - accuracy: 0.6606 - val_loss: 0.9671 - val_accuracy: 0.6083
# Epoch 86/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7401 - accuracy: 0.6602
# Epoch 00086: val_accuracy did not improve from 0.61471
# 141/141 [==============================] - 40s 282ms/step - loss: 0.7401 - accuracy: 0.6602 - val_loss: 0.9779 - val_accuracy: 0.5971
# Epoch 87/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7355 - accuracy: 0.6667
# Epoch 00087: val_accuracy did not improve from 0.61471
# 141/141 [==============================] - 40s 282ms/step - loss: 0.7355 - accuracy: 0.6667 - val_loss: 0.9734 - val_accuracy: 0.6029
# Epoch 88/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7329 - accuracy: 0.6675
# Epoch 00088: val_accuracy did not improve from 0.61471
# 141/141 [==============================] - 40s 280ms/step - loss: 0.7329 - accuracy: 0.6675 - val_loss: 0.9607 - val_accuracy: 0.6108
# Epoch 89/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7306 - accuracy: 0.6683
# Epoch 00089: val_accuracy did not improve from 0.61471
# 141/141 [==============================] - 40s 286ms/step - loss: 0.7306 - accuracy: 0.6683 - val_loss: 0.9629 - val_accuracy: 0.5936
# Epoch 90/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7232 - accuracy: 0.6702
# Epoch 00090: val_accuracy improved from 0.61471 to 0.61569, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 41s 290ms/step - loss: 0.7232 - accuracy: 0.6702 - val_loss: 0.9796 - val_accuracy: 0.6157
# Epoch 91/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7243 - accuracy: 0.6704
# Epoch 00091: val_accuracy did not improve from 0.61569
# 141/141 [==============================] - 41s 288ms/step - loss: 0.7243 - accuracy: 0.6704 - val_loss: 0.9672 - val_accuracy: 0.6069
# Epoch 92/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7243 - accuracy: 0.6686
# Epoch 00092: val_accuracy improved from 0.61569 to 0.61961, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 41s 291ms/step - loss: 0.7243 - accuracy: 0.6686 - val_loss: 0.9700 - val_accuracy: 0.6196
# Epoch 93/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7225 - accuracy: 0.6694
# Epoch 00093: val_accuracy did not improve from 0.61961
# 141/141 [==============================] - 40s 282ms/step - loss: 0.7225 - accuracy: 0.6694 - val_loss: 0.9677 - val_accuracy: 0.6069
# Epoch 94/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7236 - accuracy: 0.6730
# Epoch 00094: val_accuracy did not improve from 0.61961
# 141/141 [==============================] - 40s 283ms/step - loss: 0.7236 - accuracy: 0.6730 - val_loss: 0.9623 - val_accuracy: 0.5980
# Epoch 95/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7199 - accuracy: 0.6739
# Epoch 00095: val_accuracy improved from 0.61961 to 0.62059, saving model to rong_test_2_2.hdf5
# 141/141 [==============================] - 40s 283ms/step - loss: 0.7199 - accuracy: 0.6739 - val_loss: 0.9653 - val_accuracy: 0.6206
# Epoch 96/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7211 - accuracy: 0.6761
# Epoch 00096: val_accuracy did not improve from 0.62059
# 141/141 [==============================] - 40s 282ms/step - loss: 0.7211 - accuracy: 0.6761 - val_loss: 0.9622 - val_accuracy: 0.5975
# Epoch 97/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7194 - accuracy: 0.6778
# Epoch 00097: val_accuracy did not improve from 0.62059
# 141/141 [==============================] - 39s 280ms/step - loss: 0.7194 - accuracy: 0.6778 - val_loss: 0.9599 - val_accuracy: 0.5990
# Epoch 98/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7158 - accuracy: 0.6743
# Epoch 00098: val_accuracy did not improve from 0.62059
# 141/141 [==============================] - 40s 281ms/step - loss: 0.7158 - accuracy: 0.6743 - val_loss: 0.9746 - val_accuracy: 0.6118
# Epoch 99/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.6800
# Epoch 00099: val_accuracy did not improve from 0.62059
# 141/141 [==============================] - 40s 286ms/step - loss: 0.7120 - accuracy: 0.6800 - val_loss: 0.9778 - val_accuracy: 0.5980
# Epoch 100/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7107 - accuracy: 0.6780
# Epoch 00100: val_accuracy did not improve from 0.62059
# 141/141 [==============================] - 41s 290ms/step - loss: 0.7107 - accuracy: 0.6780 - val_loss: 0.9652 - val_accuracy: 0.6034

# %%
print(model_info.history.keys())

import matplotlib.pyplot as plt
plt.plot(model_info.history['loss'])
plt.plot(model_info.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# model.load_weights('rong_test_2.h5')

# %%
# model_info = model.fit_generator(
#             train_generator,
#             steps_per_epoch=nb_train_samples // batch_size,
#             epochs=epochs,
#             callbacks = callbacks,
#             validation_data=validation_generator,
#             validation_steps=nb_validation_samples // batch_size)

# %%
# plt.plot(model_info.history['loss'])
# plt.plot(model_info.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
# model.load_weights('rong_test_2.h5')
# # history = model.fit_generator(
# #     train_generator,
# #     steps_per_epoch = nb_train_samples // batch_size,
# #     epochs = epochs,
# #     callbacks = callbacks,
# #     validation_data = validation_generator,
# #     validation_steps = nb_validation_samples // batch_size)

# %%
# import matplotlib.pyplot as plt
# import sklearn
# from sklearn.metrics import classification_report, confusion_matrix
# import numpy as np
# # Found 28709 images belonging to 7 classes.
# # Found 3589 images belonging to 7 classes.


# # nb_train_samples = 28273
# # nb_validation_samples = 3534
# nb_train_samples = 140
# nb_validation_samples = 70

# # We need to recreate our validation generator with shuffle = false
# validation_generator = val_datagen.flow_from_directory(
#         validation_data_dir,
#         color_mode = 'grayscale',
#         target_size=(img_rows, img_cols),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=False)

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# #Confution Matrix and Classification Report
# Y_pred = model.predict_generator(validation_generator, nb_validation_samples // batch_size+1)
# y_pred = np.argmax(Y_pred, axis=1)

# print('Confusion Matrix')
# print(confusion_matrix(validation_generator.classes, y_pred))
# print('Classification Report')
# target_names = list(class_labels.values())
# print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# plt.figure(figsize=(8,8))
# cnf_matrix = confusion_matrix(validation_generator.classes, y_pred)

# plt.imshow(cnf_matrix, interpolation='nearest')
# plt.colorbar()
# tick_marks = np.arange(len(classes))
# _ = plt.xticks(tick_marks, classes, rotation=90)
# _ = plt.yticks(tick_marks, classes)

# %%
# classifier = load_model('./emotion_detector_models/model_v3_71.hdf5')

# %%
# validation_generator = val_datagen.flow_from_directory(
#         validation_data_dir,
#         color_mode = 'grayscale',
#         target_size=(img_rows, img_cols),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=False)

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())
# print(class_labels)

# %%
# from keras.models import load_model
# from keras.optimizers import RMSprop, SGD, Adam
# from keras.preprocessing import image
# import numpy as np
# import os
# import cv2
# import numpy as np
# from os import listdir
# from os.path import isfile, join
# import re

# def draw_test(name, pred, im, true_label):
#     BLACK = [0,0,0]
#     expanded_image = cv2.copyMakeBorder(im, 160, 0, 0, 300 ,cv2.BORDER_CONSTANT,value=BLACK)
#     cv2.putText(expanded_image, "predited - "+ pred, (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,0,255), 2)
#     cv2.putText(expanded_image, "true - "+ true_label, (20, 120) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,255,0), 2)
#     cv2.imshow(name, expanded_image)


# def getRandomImage(path, img_width, img_height):
#     """function loads a random images from a random folder in our test path """
#     folders = path
#     random_directory = np.random.randint(0,len(folders))
#     path_class = folders[random_directory]
#     file_path = path
#     file_names = [f for f in listdir(file_path)]
#     random_file_index = np.random.randint(0,len(file_names))
#     image_name = file_names[random_file_index]
#     final_path = file_path + "/" + image_name
#     return image.load_img(final_path, target_size = (img_width, img_height),grayscale=True), final_path, path_class

# # dimensions of our images
# img_width, img_height = 48, 48

# # We use a very small learning rate 
# model.compile(loss = 'categorical_crossentropy',
#               optimizer = RMSprop(lr = 0.001),
#               metrics = ['accuracy'])

# files = []
# predictions = []
# true_labels = []

# # predicting images
# for i in range(0, 10):
#     path = '../non_load/fer2013/train' 
#     img, final_path, true_label = getRandomImage(path, img_width, img_height)
#     files.append(final_path)
#     true_labels.append(true_label)
#     x = image.img_to_array(img)
#     x = x * 1./255
#     x = np.expand_dims(x, axis=0)
#     images = np.vstack([x])
#     classes = model.predict_classes(images, batch_size = 10)
#     predictions.append(classes)
    
# for i in range(0, len(files)):
#     image = cv2.imread((files[i]))
#     image = cv2.resize(image, None, fx=3, fy=3, interpolation = cv2.INTER_CUBIC)
#     draw_test("Prediction", class_labels[predictions[i][0]], image, true_labels[i])
#     cv2.waitKey(0)

# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# from time import sleep
# from keras.preprocessing.image import img_to_array

# face_classifier = cv2.CascadeClassifier('../datasets/classifiers/haarcascade_frontalface_default.xml')
# classifier =load_model('rong_test_2_1.hdf5')

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# def face_detector(img):
#     # Convert image to grayscale
#     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#     faces = face_classifier.detectMultiScale(gray, 1.3, 5)
#     if faces is ():
#         return (0,0,0,0), np.zeros((48,48), np.uint8), img
    
#     for (x,y,w,h) in faces:
#         cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#         roi_gray = gray[y:y+h, x:x+w]

#     try:
#         roi_gray = cv2.resize(roi_gray, (48, 48), interpolation = cv2.INTER_AREA)
#     except:
#         return (x,w,y,h), np.zeros((48,48), np.uint8), img
#     return (x,w,y,h), roi_gray, img

# cap = cv2.VideoCapture(0)

# while True:

#     ret, frame = cap.read()
#     rect, face, image = face_detector(frame)
#     if np.sum([face]) != 0.0:
#         roi = face.astype("float") / 255.0
#         roi = img_to_array(roi)
#         roi = np.expand_dims(roi, axis=0)

#         # make a prediction on the ROI, then lookup the class
#         preds = classifier.predict(roi)[0]
#         label = class_labels[preds.argmax()]  
#         label_position = (rect[0] + int((rect[1]/2)), rect[2] + 25)
#         cv2.putText(image, label, label_position , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
#     else:
#         cv2.putText(image, "No Face Found", (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
        
#     cv2.imshow('All', image)
#     if cv2.waitKey(1) == 13: #13 is the Enter Key
#         break
        
# cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-28936e0903ba> in <module>
#      52
#      53 # cap.release()
# ---> 54 cv2.destroyAllWindows()
#
# NameError: name 'cv2' is not defined

# %%
# cap.release()
# cv2.destroyAllWindows()
