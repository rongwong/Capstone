# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Important note: this notebook creates folders, do not re-run this notebook!</b>
#
# to re-run:
# - train_cropped_original/combined folder to move to bin
# </div>

# %% [markdown]
# # 4.0 Model and Dataset Selection - Final Dataset
#
# In seperate notebooks, the 5 datasets were trained and validated, as well as a sixth baseline model trained on the original dataset.

# %% [markdown]
# ***

# %% [markdown]
# ### Installations Required

# %%
#!pip install pydot

#for mac: also install this
#!pip install pydot_ng

# %%
# pip install graphviz

#for mac:
#brew install graphviz in terminal

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import glob
import shutil

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Flatten, Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator, img_to_array
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.models import load_model
from keras.utils.vis_utils import plot_model


import sklearn
from sklearn.metrics import classification_report, confusion_matrix


plt.style.use('fast')
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ### Defined Functions

# %%
def show_image(image, image_name, axis='off'):
    """ displays image from path"""
    image = plt.imread(image)
    plt.imshow(image, cmap="gray")
    plt.title(image_name)
    plt.axis(axis);

# %%
def convolution(image, kernel_):
    """applies filter onto image"""
    kernel = np.array(kernel_)
    result = np.zeros(image.shape)
    
    #output
    for ii in range(image.shape[0] - 3):
        for jj in range(image.shape[1] - 3):
            result[ii, jj] = (image[ii:ii+3, jj:jj+3] * kernel).sum()

    return result

# %%
def show_filtered(kernel_, subplot, kernel_name):
    """ showing on subplot for filtered: test_img_read"""
    filtered_img1 = convolution(test_img_read, kernel_)
    plt.subplot(subplot)
    plt.imshow(filtered_img1, cmap='bone')
    plt.title(f"Visualising {kernel_name}");

# %%
def show_conv(activations, subplots, conv_title):
    """ showing on subplot for conv layer filter"""

    plt.subplot(subplots)
    plt.imshow(activations, cmap='bone')
    plt.title(f"Visualising {conv_title}");

# %% [markdown]
# ***

# %% [markdown]
# ## Combine Train and Validation Set in AE Dataset for Final Fit

# %%
#to combine training and validation set for refit

#create new combined folder in destination
#copy training folder over
shutil.copytree("../datasets/train_cropped_aee/train","../datasets/train_cropped_ae/combined_test")

#copy val files into folder
for files in glob.glob("../datasets/train_cropped_ae/val/angry/*"):
    shutil.copy(files,"../datasets/train_cropped_ae/combined_test/angry/")
    
for files in glob.glob("../datasets/train_cropped_ae/val/happy/*"):
    shutil.copy(files,"../datasets/train_cropped_ae/combined_test/happy/")

for files in glob.glob("../datasets/train_cropped_ae/val/neutral/*"):
    shutil.copy(files,"../datasets/train_cropped_ae/combined_test/neutral/")
    
for files in glob.glob("../datasets/train_cropped_ae/val/sad/*"):
    shutil.copy(files,"../datasets/train_cropped_ae/combined_test/sad/")

# %% [markdown]
# ## Fit best model using combined dataset

# %%
#shaping X_train and X_test
train_data_dir = "../datasets/train_cropped_ae/combined_test"
validation_data_dir = "../datasets/train_cropped_ae/test"
filepath = "../models/best_model_ae_final_cp.hdf5"

img_rows, img_cols = 48, 48
num_classes = 4
epochs = 100
batch_size = 64

# %%
#callbacks
checkpoint = ModelCheckpoint(filepath,
                             monitor='val_categorical_accuracy',
                             mode='max',
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_categorical_accuracy',
                          min_delta=0,
                          mode='auto',
                          patience=15,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = ReduceLROnPlateau(monitor='val_categorical_accuracy',
                              factor=0.2,
                              mode='auto',
                              patience=5,
                              verbose=1,
                              min_delta=0.001)

callbacks = [earlystop,checkpoint,reduce_lr]

# %%
#data augmentation for train dataset, normalize all 

val_datagen = ImageDataGenerator(rescale=1./255)

train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')


train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 23799 images belonging to 4 classes.
# Found 4205 images belonging to 4 classes.

# %%
global train_samples, validation_samples
train_samples = 23799
validation_samples = 4205


print(validation_generator.class_indices)
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
#Model
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation="relu", input_shape= (48,48,1)))
model.add(Conv2D(16, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Flatten())
model.add(Dense(4, activation="softmax"))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 16)        2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 128)         73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 2052
# =================================================================
# Total params: 286,036
# Trainable params: 286,036
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file = "../images/model_plot_final.png", show_shapes=True, show_layer_names=True)

# %%
#compile model
model.compile(optimizer= Adam(lr=0.001, decay=1e-6),
              loss="categorical_crossentropy",
              metrics=["categorical_accuracy"])

# %%
# %%time

#fit model
history = model.fit_generator(
            train_generator,
            steps_per_epoch=train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From <timed exec>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 371/371 [==============================] - ETA: 0s - loss: 1.2692 - categorical_accuracy: 0.4040
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.50529, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 35s 94ms/step - loss: 1.2692 - categorical_accuracy: 0.4040 - val_loss: 1.1865 - val_categorical_accuracy: 0.5053 - lr: 0.0010
# Epoch 2/100
# 371/371 [==============================] - ETA: 0s - loss: 1.0966 - categorical_accuracy: 0.5454
# Epoch 00002: val_categorical_accuracy improved from 0.50529 to 0.60673, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 34s 91ms/step - loss: 1.0966 - categorical_accuracy: 0.5454 - val_loss: 0.9613 - val_categorical_accuracy: 0.6067 - lr: 0.0010
# Epoch 3/100
# 371/371 [==============================] - ETA: 0s - loss: 0.9547 - categorical_accuracy: 0.6098
# Epoch 00003: val_categorical_accuracy improved from 0.60673 to 0.65913, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 34s 92ms/step - loss: 0.9547 - categorical_accuracy: 0.6098 - val_loss: 0.8400 - val_categorical_accuracy: 0.6591 - lr: 0.0010
# Epoch 4/100
# 371/371 [==============================] - ETA: 0s - loss: 0.8814 - categorical_accuracy: 0.6410
# Epoch 00004: val_categorical_accuracy improved from 0.65913 to 0.68870, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 33s 90ms/step - loss: 0.8814 - categorical_accuracy: 0.6410 - val_loss: 0.7852 - val_categorical_accuracy: 0.6887 - lr: 0.0010
# Epoch 5/100
# 371/371 [==============================] - ETA: 0s - loss: 0.8231 - categorical_accuracy: 0.6706
# Epoch 00005: val_categorical_accuracy did not improve from 0.68870
# 371/371 [==============================] - 33s 89ms/step - loss: 0.8231 - categorical_accuracy: 0.6706 - val_loss: 0.7827 - val_categorical_accuracy: 0.6880 - lr: 0.0010
# Epoch 6/100
# 371/371 [==============================] - ETA: 0s - loss: 0.7808 - categorical_accuracy: 0.6843
# Epoch 00006: val_categorical_accuracy improved from 0.68870 to 0.71322, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 33s 89ms/step - loss: 0.7808 - categorical_accuracy: 0.6843 - val_loss: 0.7315 - val_categorical_accuracy: 0.7132 - lr: 0.0010
# Epoch 7/100
# 371/371 [==============================] - ETA: 0s - loss: 0.7568 - categorical_accuracy: 0.6959
# Epoch 00007: val_categorical_accuracy did not improve from 0.71322
# 371/371 [==============================] - 33s 90ms/step - loss: 0.7568 - categorical_accuracy: 0.6959 - val_loss: 0.7356 - val_categorical_accuracy: 0.7072 - lr: 0.0010
# Epoch 8/100
# 371/371 [==============================] - ETA: 0s - loss: 0.7283 - categorical_accuracy: 0.7106
# Epoch 00008: val_categorical_accuracy did not improve from 0.71322
# 371/371 [==============================] - 33s 89ms/step - loss: 0.7283 - categorical_accuracy: 0.7106 - val_loss: 0.7258 - val_categorical_accuracy: 0.7127 - lr: 0.0010
# Epoch 9/100
# 371/371 [==============================] - ETA: 0s - loss: 0.7084 - categorical_accuracy: 0.7209
# Epoch 00009: val_categorical_accuracy improved from 0.71322 to 0.72452, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 33s 89ms/step - loss: 0.7084 - categorical_accuracy: 0.7209 - val_loss: 0.6993 - val_categorical_accuracy: 0.7245 - lr: 0.0010
# Epoch 10/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6938 - categorical_accuracy: 0.7266
# Epoch 00010: val_categorical_accuracy did not improve from 0.72452
# 371/371 [==============================] - 33s 89ms/step - loss: 0.6938 - categorical_accuracy: 0.7266 - val_loss: 0.7150 - val_categorical_accuracy: 0.7159 - lr: 0.0010
# Epoch 11/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6832 - categorical_accuracy: 0.7341
# Epoch 00011: val_categorical_accuracy improved from 0.72452 to 0.72909, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 33s 90ms/step - loss: 0.6832 - categorical_accuracy: 0.7341 - val_loss: 0.7005 - val_categorical_accuracy: 0.7291 - lr: 0.0010
# Epoch 12/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6737 - categorical_accuracy: 0.7363
# Epoch 00012: val_categorical_accuracy did not improve from 0.72909
# 371/371 [==============================] - 33s 90ms/step - loss: 0.6737 - categorical_accuracy: 0.7363 - val_loss: 0.7048 - val_categorical_accuracy: 0.7276 - lr: 0.0010
# Epoch 13/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6562 - categorical_accuracy: 0.7399
# Epoch 00013: val_categorical_accuracy improved from 0.72909 to 0.74904, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 33s 88ms/step - loss: 0.6562 - categorical_accuracy: 0.7399 - val_loss: 0.6651 - val_categorical_accuracy: 0.7490 - lr: 0.0010
# Epoch 14/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6483 - categorical_accuracy: 0.7447
# Epoch 00014: val_categorical_accuracy did not improve from 0.74904
# 371/371 [==============================] - 33s 90ms/step - loss: 0.6483 - categorical_accuracy: 0.7447 - val_loss: 0.7269 - val_categorical_accuracy: 0.7192 - lr: 0.0010
# Epoch 15/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6444 - categorical_accuracy: 0.7474
# Epoch 00015: val_categorical_accuracy improved from 0.74904 to 0.75649, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 33s 90ms/step - loss: 0.6444 - categorical_accuracy: 0.7474 - val_loss: 0.6253 - val_categorical_accuracy: 0.7565 - lr: 0.0010
# Epoch 16/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6348 - categorical_accuracy: 0.7534
# Epoch 00016: val_categorical_accuracy did not improve from 0.75649
# 371/371 [==============================] - 33s 88ms/step - loss: 0.6348 - categorical_accuracy: 0.7534 - val_loss: 0.6476 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 17/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6275 - categorical_accuracy: 0.7545
# Epoch 00017: val_categorical_accuracy did not improve from 0.75649
# 371/371 [==============================] - 34s 90ms/step - loss: 0.6275 - categorical_accuracy: 0.7545 - val_loss: 0.7423 - val_categorical_accuracy: 0.7154 - lr: 0.0010
# Epoch 18/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6261 - categorical_accuracy: 0.7556
# Epoch 00018: val_categorical_accuracy did not improve from 0.75649
# 371/371 [==============================] - 34s 91ms/step - loss: 0.6261 - categorical_accuracy: 0.7556 - val_loss: 0.6663 - val_categorical_accuracy: 0.7560 - lr: 0.0010
# Epoch 19/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6126 - categorical_accuracy: 0.7606
# Epoch 00019: val_categorical_accuracy improved from 0.75649 to 0.76250, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 34s 92ms/step - loss: 0.6126 - categorical_accuracy: 0.7606 - val_loss: 0.6338 - val_categorical_accuracy: 0.7625 - lr: 0.0010
# Epoch 20/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6153 - categorical_accuracy: 0.7626
# Epoch 00020: val_categorical_accuracy did not improve from 0.76250
# 371/371 [==============================] - 34s 92ms/step - loss: 0.6153 - categorical_accuracy: 0.7626 - val_loss: 0.6526 - val_categorical_accuracy: 0.7471 - lr: 0.0010
# Epoch 21/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6049 - categorical_accuracy: 0.7655
# Epoch 00021: val_categorical_accuracy did not improve from 0.76250
# 371/371 [==============================] - 34s 93ms/step - loss: 0.6049 - categorical_accuracy: 0.7655 - val_loss: 0.6349 - val_categorical_accuracy: 0.7575 - lr: 0.0010
# Epoch 22/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6110 - categorical_accuracy: 0.7638
# Epoch 00022: val_categorical_accuracy did not improve from 0.76250
# 371/371 [==============================] - 35s 94ms/step - loss: 0.6110 - categorical_accuracy: 0.7638 - val_loss: 0.6331 - val_categorical_accuracy: 0.7570 - lr: 0.0010
# Epoch 23/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6039 - categorical_accuracy: 0.7636
# Epoch 00023: val_categorical_accuracy did not improve from 0.76250
# 371/371 [==============================] - 37s 99ms/step - loss: 0.6039 - categorical_accuracy: 0.7636 - val_loss: 0.6489 - val_categorical_accuracy: 0.7536 - lr: 0.0010
# Epoch 24/100
# 371/371 [==============================] - ETA: 0s - loss: 0.6048 - categorical_accuracy: 0.7644
# Epoch 00024: val_categorical_accuracy did not improve from 0.76250
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 371/371 [==============================] - 35s 96ms/step - loss: 0.6048 - categorical_accuracy: 0.7644 - val_loss: 0.6427 - val_categorical_accuracy: 0.7440 - lr: 0.0010
# Epoch 25/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5584 - categorical_accuracy: 0.7857
# Epoch 00025: val_categorical_accuracy improved from 0.76250 to 0.76851, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 34s 92ms/step - loss: 0.5584 - categorical_accuracy: 0.7857 - val_loss: 0.6179 - val_categorical_accuracy: 0.7685 - lr: 2.0000e-04
# Epoch 26/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5512 - categorical_accuracy: 0.7895
# Epoch 00026: val_categorical_accuracy did not improve from 0.76851
# 371/371 [==============================] - 34s 93ms/step - loss: 0.5512 - categorical_accuracy: 0.7895 - val_loss: 0.6294 - val_categorical_accuracy: 0.7637 - lr: 2.0000e-04
# Epoch 27/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5463 - categorical_accuracy: 0.7899
# Epoch 00027: val_categorical_accuracy did not improve from 0.76851
# 371/371 [==============================] - 34s 91ms/step - loss: 0.5463 - categorical_accuracy: 0.7899 - val_loss: 0.6327 - val_categorical_accuracy: 0.7625 - lr: 2.0000e-04
# Epoch 28/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5410 - categorical_accuracy: 0.7922
# Epoch 00028: val_categorical_accuracy did not improve from 0.76851
# 371/371 [==============================] - 34s 91ms/step - loss: 0.5410 - categorical_accuracy: 0.7922 - val_loss: 0.6209 - val_categorical_accuracy: 0.7680 - lr: 2.0000e-04
# Epoch 29/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5379 - categorical_accuracy: 0.7921
# Epoch 00029: val_categorical_accuracy did not improve from 0.76851
# 371/371 [==============================] - 35s 93ms/step - loss: 0.5379 - categorical_accuracy: 0.7921 - val_loss: 0.6374 - val_categorical_accuracy: 0.7596 - lr: 2.0000e-04
# Epoch 30/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5368 - categorical_accuracy: 0.7930
# Epoch 00030: val_categorical_accuracy did not improve from 0.76851
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 371/371 [==============================] - 34s 92ms/step - loss: 0.5368 - categorical_accuracy: 0.7930 - val_loss: 0.6192 - val_categorical_accuracy: 0.7656 - lr: 2.0000e-04
# Epoch 31/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5260 - categorical_accuracy: 0.7982
# Epoch 00031: val_categorical_accuracy did not improve from 0.76851
# 371/371 [==============================] - 34s 92ms/step - loss: 0.5260 - categorical_accuracy: 0.7982 - val_loss: 0.6084 - val_categorical_accuracy: 0.7678 - lr: 4.0000e-05
# Epoch 32/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5265 - categorical_accuracy: 0.7982
# Epoch 00032: val_categorical_accuracy did not improve from 0.76851
# 371/371 [==============================] - 36s 96ms/step - loss: 0.5265 - categorical_accuracy: 0.7982 - val_loss: 0.6133 - val_categorical_accuracy: 0.7656 - lr: 4.0000e-05
# Epoch 33/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5264 - categorical_accuracy: 0.7997
# Epoch 00033: val_categorical_accuracy improved from 0.76851 to 0.76971, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 34s 92ms/step - loss: 0.5264 - categorical_accuracy: 0.7997 - val_loss: 0.6085 - val_categorical_accuracy: 0.7697 - lr: 4.0000e-05
# Epoch 34/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5267 - categorical_accuracy: 0.7981
# Epoch 00034: val_categorical_accuracy improved from 0.76971 to 0.77260, saving model to ../models/best_model_ae_final_cp.hdf5
# 371/371 [==============================] - 35s 95ms/step - loss: 0.5267 - categorical_accuracy: 0.7981 - val_loss: 0.5989 - val_categorical_accuracy: 0.7726 - lr: 4.0000e-05
# Epoch 35/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5221 - categorical_accuracy: 0.8004
# Epoch 00035: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 36s 98ms/step - loss: 0.5221 - categorical_accuracy: 0.8004 - val_loss: 0.6171 - val_categorical_accuracy: 0.7642 - lr: 4.0000e-05
# Epoch 36/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5251 - categorical_accuracy: 0.8019
# Epoch 00036: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 35s 93ms/step - loss: 0.5251 - categorical_accuracy: 0.8019 - val_loss: 0.6027 - val_categorical_accuracy: 0.7695 - lr: 4.0000e-05
# Epoch 37/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5245 - categorical_accuracy: 0.8011
# Epoch 00037: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 34s 91ms/step - loss: 0.5245 - categorical_accuracy: 0.8011 - val_loss: 0.6083 - val_categorical_accuracy: 0.7680 - lr: 4.0000e-05
# Epoch 38/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5219 - categorical_accuracy: 0.8017
# Epoch 00038: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 34s 92ms/step - loss: 0.5219 - categorical_accuracy: 0.8017 - val_loss: 0.6099 - val_categorical_accuracy: 0.7685 - lr: 4.0000e-05
# Epoch 39/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5222 - categorical_accuracy: 0.8013
# Epoch 00039: val_categorical_accuracy did not improve from 0.77260
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 371/371 [==============================] - 34s 93ms/step - loss: 0.5222 - categorical_accuracy: 0.8013 - val_loss: 0.6147 - val_categorical_accuracy: 0.7659 - lr: 4.0000e-05
# Epoch 40/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5218 - categorical_accuracy: 0.8022
# Epoch 00040: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 35s 94ms/step - loss: 0.5218 - categorical_accuracy: 0.8022 - val_loss: 0.6107 - val_categorical_accuracy: 0.7697 - lr: 8.0000e-06
# Epoch 41/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5198 - categorical_accuracy: 0.8034
# Epoch 00041: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 34s 93ms/step - loss: 0.5198 - categorical_accuracy: 0.8034 - val_loss: 0.6063 - val_categorical_accuracy: 0.7685 - lr: 8.0000e-06
# Epoch 42/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5163 - categorical_accuracy: 0.8058
# Epoch 00042: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 34s 92ms/step - loss: 0.5163 - categorical_accuracy: 0.8058 - val_loss: 0.6055 - val_categorical_accuracy: 0.7702 - lr: 8.0000e-06
# Epoch 43/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5180 - categorical_accuracy: 0.8034
# Epoch 00043: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 35s 93ms/step - loss: 0.5180 - categorical_accuracy: 0.8034 - val_loss: 0.6089 - val_categorical_accuracy: 0.7688 - lr: 8.0000e-06
# Epoch 44/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5245 - categorical_accuracy: 0.8008
# Epoch 00044: val_categorical_accuracy did not improve from 0.77260
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 371/371 [==============================] - 34s 92ms/step - loss: 0.5245 - categorical_accuracy: 0.8008 - val_loss: 0.6051 - val_categorical_accuracy: 0.7695 - lr: 8.0000e-06
# Epoch 45/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5191 - categorical_accuracy: 0.8027
# Epoch 00045: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 34s 93ms/step - loss: 0.5191 - categorical_accuracy: 0.8027 - val_loss: 0.6074 - val_categorical_accuracy: 0.7688 - lr: 1.6000e-06
# Epoch 46/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5198 - categorical_accuracy: 0.8022
# Epoch 00046: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 34s 91ms/step - loss: 0.5198 - categorical_accuracy: 0.8022 - val_loss: 0.6074 - val_categorical_accuracy: 0.7692 - lr: 1.6000e-06
# Epoch 47/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5210 - categorical_accuracy: 0.8009
# Epoch 00047: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 34s 92ms/step - loss: 0.5210 - categorical_accuracy: 0.8009 - val_loss: 0.6087 - val_categorical_accuracy: 0.7690 - lr: 1.6000e-06
# Epoch 48/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5181 - categorical_accuracy: 0.8007
# Epoch 00048: val_categorical_accuracy did not improve from 0.77260
# 371/371 [==============================] - 35s 95ms/step - loss: 0.5181 - categorical_accuracy: 0.8007 - val_loss: 0.6066 - val_categorical_accuracy: 0.7692 - lr: 1.6000e-06
# Epoch 49/100
# 371/371 [==============================] - ETA: 0s - loss: 0.5155 - categorical_accuracy: 0.8032Restoring model weights from the end of the best epoch.
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.77260
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 371/371 [==============================] - 35s 93ms/step - loss: 0.5155 - categorical_accuracy: 0.8032 - val_loss: 0.6064 - val_categorical_accuracy: 0.7688 - lr: 1.6000e-06
# Epoch 00049: early stopping
# CPU times: user 2h 30min 20s, sys: 18min 57s, total: 2h 49min 18s
# Wall time: 27min 57s

# %%
#plotting Accuracy and Loss curves
plt.figure(figsize=(15,5))

plt.subplot(121)
plt.plot(history.history["categorical_accuracy"], label = 'Train Accuracy', color ='slategrey')
plt.plot(history.history["val_categorical_accuracy"], label = 'Test Accuracy', color ='gold')
plt.title("Training and Test Accuracy by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend();

plt.subplot(122)
plt.plot(history.history["loss"], label = 'Train Loss', color ='slategrey')
plt.plot(history.history["val_loss"], label = 'Test Loss', color ='gold')
plt.title("Training and Test Loss by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend();

# %%
#Code credits: APEKSHA PRIYA, Priya Dwivedi
#confusion matrix and classification report

#validation generator with shuffle = false
validation_generator1 = val_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

class_labels1 = validation_generator1.class_indices
class_labels1 = {v: k for k, v in class_labels1.items()}
classes1 = list(class_labels1.values())

#Confusion Matrix and Classification Report
Y_pred1 = model.predict_generator(validation_generator1, validation_samples // batch_size+1)
y_pred1 = np.argmax(Y_pred1, axis=1)
y_test1 = validation_generator1.classes

#Generate Confusion Matrix
cnf_matrix1 = confusion_matrix(y_test1, y_pred1)


print('Classification Report for Final Model')
target_names1 = list(class_labels1.values())
print(classification_report(y_test1, y_pred1, target_names=target_names1))


#plot confusion matrix
plt.figure(figsize=(8,8))
ax= plt.subplot()
sns.heatmap(cnf_matrix1, annot=True, ax = ax, cmap='bone_r', fmt='g', cbar=False)
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix for Final Model'); 
ax.xaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad'])
ax.yaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad']);
# Out:
# Found 4205 images belonging to 4 classes.
# WARNING:tensorflow:From <ipython-input-18-25a148d971a5>:18: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# Classification Report for Final Model
#               precision    recall  f1-score   support
#
#        angry       0.64      0.71      0.67       546
#        happy       0.90      0.88      0.89      1667
#      neutral       0.75      0.76      0.76      1402
#          sad       0.60      0.56      0.58       590
#
#     accuracy                           0.77      4205
#    macro avg       0.72      0.73      0.73      4205
# weighted avg       0.78      0.77      0.77      4205

# %%
#save serialize model as json
model_json = model.to_json()
with open("../models/best_model_ae_final_model.json", "w") as json_file:
    json_file.write(model_json)
    
#save serialize model as HDF5
model.save_weights("../models/best_model_ae_final_model.h5")

print("Done (:")
# Out:
# Done (:

# %% [markdown]
# ## Closer Look At Kernel Responses

# %%
#reveal layers
model.layers
# Out:
# [<tensorflow.python.keras.layers.convolutional.Conv2D at 0x7fc71a16ff10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7fc71a172fd0>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7fc72a1ab150>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7fc72a1abcd0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7fc72a183650>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7fc6ea3b3950>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7fc6ea3b5a10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7fc71a1616d0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7fc6ea39dc90>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7fc71a162550>,
#  <tensorflow.python.keras.layers.core.Flatten at 0x7fc71a163210>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7fc71a16ef10>]

# %%
#getting model weights
conv1 = model.layers[0]
conv2 = model.layers[1]
conv3 = model.layers[3]
conv4 = model.layers[4]
conv5 = model.layers[5]
conv6 = model.layers[7]
conv7 = model.layers[8]

weights1 = conv1.get_weights()
weights2 = conv2.get_weights()
weights3 = conv3.get_weights()
weights4 = conv4.get_weights()
weights5 = conv5.get_weights()
weights6 = conv6.get_weights()
weights7 = conv7.get_weights()
print(f"weights: {len(weights7)}")


kernels1 = weights1[0]
kernels2 = weights2[0]
kernels3 = weights3[0]
kernels4 = weights4[0]
kernels5 = weights5[0]
kernels6 = weights6[0]
kernels7 = weights7[0]
print(f"kernel shape: {kernels7.shape}")

#visualising kernels by layers
kernel1_1 = kernels1[:,:,0,0]
kernel2_1 = kernels2[:,:,0,0]
kernel3_1 = kernels3[:,:,0,0]
kernel4_1 = kernels4[:,:,0,0]
kernel5_1 = kernels5[:,:,0,0]
kernel6_1 = kernels6[:,:,0,0]
kernel7_1 = kernels7[:,:,0,0]
print(f"kernel shape: {kernel1_1.shape}")

# kernels in layer 1
kernel1_1 = kernels1[:,:,0,0]
kernel1_2 = kernels1[:,:,0,1]
kernel1_3 = kernels1[:,:,0,2]
kernel1_4 = kernels1[:,:,0,9]
kernel1_5 = kernels1[:,:,0,10]
kernel1_6 = kernels1[:,:,0,14]
kernel1_7 = kernels1[:,:,0,15]
print(f"kernel shape: {kernel1_1.shape}")


#visualising kernels
plt.figure(figsize=(15,8))

plt.subplot(242)
plt.imshow(kernel1_1, cmap='bone_r')
plt.title("Kernel1_1");

plt.subplot(243)
plt.imshow(kernel1_2, cmap='bone_r')
plt.title("Kernel1_2");

plt.subplot(244)
plt.imshow(kernel1_3, cmap='bone_r')
plt.title("Kernel1_3");

plt.subplot(245)
plt.imshow(kernel1_4, cmap='bone_r')
plt.title("Kernel1_4");

plt.subplot(246)
plt.imshow(kernel1_5, cmap='bone_r')
plt.title("Kernel1_5");

plt.subplot(247)
plt.imshow(kernel1_6, cmap='bone_r')
plt.title("Kernel1_6");

plt.subplot(248)
plt.imshow(kernel1_7, cmap='bone_r')
plt.title("Kernel1_7")

plt.suptitle("Visualizing Kernels", fontsize=16);
# Out:
# weights: 2
# kernel shape: (3, 3, 128, 128)
# kernel shape: (3, 3)
# kernel shape: (3, 3)

# %%
#visualising kernels reponses

#loading test image
test_data = glob.glob("../datasets/train_cropped_original/test/angry/*")
test_img = test_data[0]
test_img_read = plt.imread(test_img)

plt.figure(figsize=(15,8))

#original

plt.subplot(241)
plt.title("test")
show_image(test_img, "Image from Final Dataset")

#filtered images
show_filtered(kernel1_1, 242, "kernel1_1")
show_filtered(kernel1_2, 243, "kernel1_2")
show_filtered(kernel1_3, 244, "kernel1_3")
show_filtered(kernel1_4, 245, "kernel1_4")
show_filtered(kernel1_5, 246, "kernel1_5")
show_filtered(kernel1_6, 247, "kernel1_6")
show_filtered(kernel1_7, 248, "kernel1_7")
plt.suptitle("Visualizing Layer 1 Kernel Responses on Image", fontsize=16);

# %%
#visualising kernels reponses by level

#loading test image
test_data = glob.glob("../datasets/train_cropped_original/test/angry/*")
test_img = test_data[0]
test_img_read = plt.imread(test_img)

plt.figure(figsize=(15,8))

#original
plt.subplot(241)
show_image(test_img, "Image from Final Dataset")

#filtered images
show_filtered(kernel1_1, 242, "kernel1_1")
show_filtered(kernel2_1, 243, "kernel2_1")
show_filtered(kernel3_1, 244, "kernel3_1")
show_filtered(kernel4_1, 245, "kernel4_1")
show_filtered(kernel5_1, 246, "kernel5_1")
show_filtered(kernel6_1, 247, "kernel6_1")
show_filtered(kernel7_1, 248, "kernel7_1")
plt.suptitle("Visualizing First 7 Layers of Kernel Responses on Image", fontsize=16);

# %% [markdown]
# ## Looking at Convolution Neuron Filter (Convolutional Mask) - Final Dataset

# %%
# looking at neuron filters in convolution layer

#sample image
sample = glob.glob("../datasets/train_cropped_ae/train/angry/*")
sample_img = Image.open(sample[1]).convert("L")
sample_img = img_to_array(sample_img)
sample_img = sample_img * 1./255
sample_img = np.expand_dims(sample_img, axis=0)
sample_img = np.vstack([sample_img])
sample_img.shape

#new model
layer_output = model.layers[0].output
layer_input = model.layers[0].input

layer_model =  Model(inputs= layer_input, outputs= layer_output)

# predict
activations = layer_model.predict(sample_img)

# plot activations
plt.figure(figsize=(15,8))
show_conv(activations[0,:,:,0], 241, "Convo Layer - Filter 1")
show_conv(activations[0,:,:,1], 242, "Convo Layer - Filter 2")
show_conv(activations[0,:,:,2], 243, "Convo Layer - Filter 3")
show_conv(activations[0,:,:,3], 244, "Convo Layer - Filter 4")
show_conv(activations[0,:,:,12], 245, "Convo Layer - Filter 13")
show_conv(activations[0,:,:,13], 246, "Convo Layer - Filter 14")
show_conv(activations[0,:,:,14], 247, "Convo Layer - Filter 15")
show_conv(activations[0,:,:,15], 248, "Convo Layer - Filter 16")
plt.suptitle("Visualizing Final Model's 1st Convolutional Layer filters on Final Image", fontsize=16);

# %% [markdown]
# ## Looking at Convolution Neuron Filter (Convolutional Mask) - Original Dataset

# %%
# looking at neuron filters in convolution layer

#sample image
sample = glob.glob("../datasets/train_cropped_original/train/angry/*")
sample_img = plt.imread(sample[1])
sample_img = img_to_array(sample_img)
sample_img = sample_img * 1./255
sample_img = np.expand_dims(sample_img, axis=0)
sample_img = np.vstack([sample_img])
sample_img.shape

#new model
layer_output = model.layers[0].output
layer_input = model.layers[0].input

layer_model =  Model(inputs= layer_input, outputs= layer_output)

# predict
activations = layer_model.predict(sample_img)

# plot activations
plt.figure(figsize=(15,8))

show_conv(activations[0,:,:,0], 241, "Convo Layer - Filter 1")
show_conv(activations[0,:,:,1], 242, "Convo Layer - Filter 2")
show_conv(activations[0,:,:,2], 243, "Convo Layer - Filter 3")
show_conv(activations[0,:,:,3], 244, "Convo Layer - Filter 4")
show_conv(activations[0,:,:,12], 245, "Convo Layer - Filter 13")
show_conv(activations[0,:,:,13], 246, "Convo Layer - Filter 14")
show_conv(activations[0,:,:,14], 247, "Convo Layer - Filter 15")
show_conv(activations[0,:,:,15], 248, "Convo Layer - Filter 16")
plt.suptitle("Visualizing Final Model's 1st Convolutional Layer filters on Original Image", fontsize=16);
