# %% [markdown]
# https://www.freecodecamp.org/news/facial-emotion-recognition-develop-a-c-n-n-and-break-into-kaggle-top-10-f618c024faa7/

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from keras.models import Sequential, model_from_json, load_model
from keras.layers import Conv2D, Activation, Dropout, MaxPooling2D, Flatten, Dense
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, TensorBoard, ModelCheckpoint
from keras.utils import to_categorical, plot_model
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Define Data Loading Mechanism
# Now, we will define the load_data() function which will efficiently parse the data file and extract necessary data and then convert it into a usable image format.
#
# All the images in our dataset are 48x48 in dimension. Since these images are gray-scale, there is only one channel. We will extract the image data and rearrange it into a 48x48 array. Then convert it into unsigned integers and divide it by 255 to normalize the data. 255 is the maximum possible value of a single cell. By dividing every element by 255, we ensure that all our values range between 0 and 1.
#
# We will check the Usage column and store the data in separate lists, one for training the network and the other for testing it.

# %%
# def load_data(dataset_path):
#     data = []
#     test_data = []
#     test_labels = []
#     labels =[]
#     with open(dataset_path, 'r') as file:
#         for line_no, line in enumerate(file.readlines()):
#             if 0 < line_no <= 35887:
#             curr_class, line, set_type = line.split(',')
#             image_data = np.asarray([int(x) for x in line.split()]).reshape(48, 48)
#             image_data =image_data.astype(np.uint8)/255.0
            
#             if (set_type.strip() == 'PrivateTest'):
              
#               test_data.append(image_data)
#               test_labels.append(curr_class)
#             else:
#               data.append(image_data)
#               labels.append(curr_class)
      
#         test_data = np.expand_dims(test_data, -1)
#         test_labels = to_categorical(test_labels, num_classes = 7)
#         data = np.expand_dims(data, -1)   
#         labels = to_categorical(labels, num_classes = 7)
    
#       return np.array(data), np.array(labels), np.array(test_data), np.array(test_labels)

# %% [markdown]
# Once our data is segregated, we will expand the dimensions of both testing and training data by one to accommodate the channel. Then, we will one hot encode all the labels using the to_categorical() function and return all the lists as numpy arrays.
#
# We will load the data by calling the load_data() function.

# %%
# dataset_path = "/content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/Data/fer2013.csv"
# train_data, train_labels, test_data, test_labels = load_data(dataset_path)
# print("Number of images in Training set:", len(train_data))
# print("Number of images in Test set:", len(test_data))

# %% [markdown]
# Our data is loaded and now let us get to the best part, defining the network.
#
# Defining the model.
# We will use Keras to create a Sequential Convolutional Network. Which means that our neural network will be a linear stack of layers. This network will have the following components:
#
# Convolutional Layers: These layers are the building blocks of our network and these compute dot product between their weights and the small regions to which they are linked. This is how these layers learn certain features from these images.
# Activation functions: are those functions which are applied to the outputs of all layers in the network. In this project, we will resort to the use of two functions— Relu and Softmax.
# Pooling Layers: These layers will downsample the operation along the dimensions. This helps reduce the spatial data and minimize the processing power that is required.
# Dense layers: These layers are present at the end of a C.N.N. They take in all the feature data generated by the convolution layers and do the decision making.
# Dropout Layers: randomly turns off a few neurons in the network to prevent overfitting.
# Batch Normalization: normalizes the output of a previous activation layer by subtracting the batch mean and dividing by the batch standard deviation. This speeds up the training process.

# %%
train_data_dir = '../test_full/train_cropped'
validation_data_dir = '../test_full/validation'

batch_size = 64

# %%
# Let's use some data augmentaiton 
# train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 27800 images belonging to 4 classes.
# Found 2590 images belonging to 4 classes.

# %%
print(validation_generator.class_indices)
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
# initializing
num_classes = 4
img_rows, img_cols = 48, 48

nb_train_samples = 27800
nb_validation_samples = 2590


epochs = 100
learning_rate = 0.001

# %%
# Create the model 2
model = Sequential()

model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1), kernel_regularizer=l2(0.01)))

model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(Dropout(0.5))    

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))    

model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))    

model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())

model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))    

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 9,014,532
# Trainable params: 9,009,028
# Non-trainable params: 5,504
# _________________________________________________________________

# %%
# plot_model(model, to_file= 'model.png')
# model_plot = plt.imread('model.png')
# plt.imshow(model_plot)

# %% [markdown]
# We will compile the network using Adam optimizer and will use a variable learning rate. Since we are dealing with a classification problem that involves multiple categories, we will use categorical_crossentropy as our loss function.

# %% [markdown]
# Callback functions
# Callback functions are those functions which are called after every epoch during the training process. We will be using the following callback functions:

# %%
adam = optimizers.Adam(lr = learning_rate)

model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3)
early_stopper = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=6, mode='auto')
checkpointer = ModelCheckpoint('rong_test_4_1_checkpoint_file.hd5', monitor='val_loss', verbose=1, save_best_only=True)

callbacks=[lr_reducer, checkpointer, early_stopper]

# %% [markdown]
# Time to train
# All our hard work is about to be put to the test. But before we fit the model, let us define some hyper-parameters.

# %%
# %%time
# epochs = 100
# batch_size = 64
# learning_rate = 0.001

# model.fit(train_data,
#           train_labels,
#           epochs = epochs,
#           batch_size = batch_size,
#           validation_split = 0.2,
#           shuffle = True,
#           callbacks=[lr_reducer, checkpointer, early_stopper]
#          )

model_info = model.fit(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)
# Out:
# Epoch 1/100
# 434/434 [==============================] - ETA: 0s - loss: 1.5781 - accuracy: 0.3160
# Epoch 00001: val_loss improved from inf to 1.38327, saving model to rong_test_4_1_checkpoint_file.hd5
# WARNING:tensorflow:From /Users/rong/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 968s 2s/step - loss: 1.5781 - accuracy: 0.3160 - val_loss: 1.3833 - val_accuracy: 0.3387 - lr: 0.0010
# Epoch 2/100
# 434/434 [==============================] - ETA: 0s - loss: 1.3696 - accuracy: 0.3543
# Epoch 00002: val_loss improved from 1.38327 to 1.37617, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 920s 2s/step - loss: 1.3696 - accuracy: 0.3543 - val_loss: 1.3762 - val_accuracy: 0.3410 - lr: 0.0010
# Epoch 3/100
# 434/434 [==============================] - ETA: 0s - loss: 1.3563 - accuracy: 0.3626
# Epoch 00003: val_loss did not improve from 1.37617
# 434/434 [==============================] - 888s 2s/step - loss: 1.3563 - accuracy: 0.3626 - val_loss: 1.3769 - val_accuracy: 0.3379 - lr: 0.0010
# Epoch 4/100
# 434/434 [==============================] - ETA: 0s - loss: 1.3478 - accuracy: 0.3640
# Epoch 00004: val_loss improved from 1.37617 to 1.37142, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 892s 2s/step - loss: 1.3478 - accuracy: 0.3640 - val_loss: 1.3714 - val_accuracy: 0.3391 - lr: 0.0010
# Epoch 5/100
# 434/434 [==============================] - ETA: 0s - loss: 1.3371 - accuracy: 0.3649
# Epoch 00005: val_loss did not improve from 1.37142
# 434/434 [==============================] - 881s 2s/step - loss: 1.3371 - accuracy: 0.3649 - val_loss: 1.3757 - val_accuracy: 0.3414 - lr: 0.0010
# Epoch 6/100
# 434/434 [==============================] - ETA: 0s - loss: 1.3306 - accuracy: 0.3642
# Epoch 00006: val_loss improved from 1.37142 to 1.36861, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 892s 2s/step - loss: 1.3306 - accuracy: 0.3642 - val_loss: 1.3686 - val_accuracy: 0.3391 - lr: 0.0010
# Epoch 7/100
# 434/434 [==============================] - ETA: 0s - loss: 1.3162 - accuracy: 0.3687
# Epoch 00007: val_loss improved from 1.36861 to 1.31566, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 906s 2s/step - loss: 1.3162 - accuracy: 0.3687 - val_loss: 1.3157 - val_accuracy: 0.3797 - lr: 0.0010
# Epoch 8/100
# 434/434 [==============================] - ETA: 0s - loss: 1.2857 - accuracy: 0.3927
# Epoch 00008: val_loss improved from 1.31566 to 1.29927, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 908s 2s/step - loss: 1.2857 - accuracy: 0.3927 - val_loss: 1.2993 - val_accuracy: 0.3801 - lr: 0.0010
# Epoch 9/100
# 434/434 [==============================] - ETA: 0s - loss: 1.2405 - accuracy: 0.4270
# Epoch 00009: val_loss did not improve from 1.29927
# 434/434 [==============================] - 899s 2s/step - loss: 1.2405 - accuracy: 0.4270 - val_loss: 1.3995 - val_accuracy: 0.2746 - lr: 0.0010
# Epoch 10/100
# 434/434 [==============================] - ETA: 0s - loss: 1.1925 - accuracy: 0.4756
# Epoch 00010: val_loss improved from 1.29927 to 1.23399, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 898s 2s/step - loss: 1.1925 - accuracy: 0.4756 - val_loss: 1.2340 - val_accuracy: 0.4176 - lr: 0.0010
# Epoch 11/100
# 434/434 [==============================] - ETA: 0s - loss: 1.1519 - accuracy: 0.5031
# Epoch 00011: val_loss improved from 1.23399 to 1.20356, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 900s 2s/step - loss: 1.1519 - accuracy: 0.5031 - val_loss: 1.2036 - val_accuracy: 0.4379 - lr: 0.0010
# Epoch 12/100
# 434/434 [==============================] - ETA: 0s - loss: 1.1100 - accuracy: 0.5243
# Epoch 00012: val_loss improved from 1.20356 to 1.14438, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 962s 2s/step - loss: 1.1100 - accuracy: 0.5243 - val_loss: 1.1444 - val_accuracy: 0.4480 - lr: 0.0010
# Epoch 13/100
# 434/434 [==============================] - ETA: 0s - loss: 1.0857 - accuracy: 0.5296
# Epoch 00013: val_loss did not improve from 1.14438
# 434/434 [==============================] - 919s 2s/step - loss: 1.0857 - accuracy: 0.5296 - val_loss: 1.1559 - val_accuracy: 0.4563 - lr: 0.0010
# Epoch 14/100
# 434/434 [==============================] - ETA: 0s - loss: 1.0642 - accuracy: 0.5411
# Epoch 00014: val_loss did not improve from 1.14438
# 434/434 [==============================] - 971s 2s/step - loss: 1.0642 - accuracy: 0.5411 - val_loss: 1.2082 - val_accuracy: 0.4508 - lr: 0.0010
# Epoch 15/100
# 434/434 [==============================] - ETA: 0s - loss: 1.0414 - accuracy: 0.5474
# Epoch 00015: val_loss improved from 1.14438 to 1.11443, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 934s 2s/step - loss: 1.0414 - accuracy: 0.5474 - val_loss: 1.1144 - val_accuracy: 0.4633 - lr: 0.0010
# Epoch 16/100
# 434/434 [==============================] - ETA: 0s - loss: 1.0276 - accuracy: 0.5508
# Epoch 00016: val_loss did not improve from 1.11443
# 434/434 [==============================] - 988s 2s/step - loss: 1.0276 - accuracy: 0.5508 - val_loss: 1.1838 - val_accuracy: 0.4445 - lr: 0.0010
# Epoch 17/100
# 434/434 [==============================] - ETA: 0s - loss: 1.0291 - accuracy: 0.5531
# Epoch 00017: val_loss did not improve from 1.11443
# 434/434 [==============================] - 945s 2s/step - loss: 1.0291 - accuracy: 0.5531 - val_loss: 1.1637 - val_accuracy: 0.4547 - lr: 0.0010
# Epoch 18/100
# 434/434 [==============================] - ETA: 0s - loss: 1.0146 - accuracy: 0.5569
# Epoch 00018: val_loss did not improve from 1.11443
# 434/434 [==============================] - 941s 2s/step - loss: 1.0146 - accuracy: 0.5569 - val_loss: 1.1240 - val_accuracy: 0.4574 - lr: 0.0010
# Epoch 19/100
# 434/434 [==============================] - ETA: 0s - loss: 1.0076 - accuracy: 0.5582
# Epoch 00019: val_loss improved from 1.11443 to 1.10792, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 934s 2s/step - loss: 1.0076 - accuracy: 0.5582 - val_loss: 1.1079 - val_accuracy: 0.4563 - lr: 9.0000e-04
# Epoch 20/100
# 434/434 [==============================] - ETA: 0s - loss: 0.9990 - accuracy: 0.5583
# Epoch 00020: val_loss did not improve from 1.10792
# 434/434 [==============================] - 878s 2s/step - loss: 0.9990 - accuracy: 0.5583 - val_loss: 1.1272 - val_accuracy: 0.4664 - lr: 9.0000e-04
# Epoch 21/100
# 434/434 [==============================] - ETA: 0s - loss: 0.9915 - accuracy: 0.5613
# Epoch 00021: val_loss did not improve from 1.10792
# 434/434 [==============================] - 879s 2s/step - loss: 0.9915 - accuracy: 0.5613 - val_loss: 1.1601 - val_accuracy: 0.4684 - lr: 9.0000e-04
# Epoch 22/100
# 434/434 [==============================] - ETA: 0s - loss: 0.9788 - accuracy: 0.5628
# Epoch 00022: val_loss did not improve from 1.10792
# 434/434 [==============================] - 878s 2s/step - loss: 0.9788 - accuracy: 0.5628 - val_loss: 1.1149 - val_accuracy: 0.4621 - lr: 9.0000e-04
# Epoch 23/100
# 434/434 [==============================] - ETA: 0s - loss: 0.9682 - accuracy: 0.5678
# Epoch 00023: val_loss did not improve from 1.10792
# 434/434 [==============================] - 878s 2s/step - loss: 0.9682 - accuracy: 0.5678 - val_loss: 1.1208 - val_accuracy: 0.4574 - lr: 8.1000e-04
# Epoch 24/100
# 434/434 [==============================] - ETA: 0s - loss: 0.9679 - accuracy: 0.5684
# Epoch 00024: val_loss improved from 1.10792 to 1.08421, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 888s 2s/step - loss: 0.9679 - accuracy: 0.5684 - val_loss: 1.0842 - val_accuracy: 0.4789 - lr: 8.1000e-04
# Epoch 25/100
# 434/434 [==============================] - ETA: 0s - loss: 0.9540 - accuracy: 0.5776
# Epoch 00025: val_loss improved from 1.08421 to 1.07716, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 891s 2s/step - loss: 0.9540 - accuracy: 0.5776 - val_loss: 1.0772 - val_accuracy: 0.4941 - lr: 8.1000e-04
# Epoch 26/100
# 434/434 [==============================] - ETA: 0s - loss: 0.9398 - accuracy: 0.5836
# Epoch 00026: val_loss did not improve from 1.07716
# 434/434 [==============================] - 877s 2s/step - loss: 0.9398 - accuracy: 0.5836 - val_loss: 1.2081 - val_accuracy: 0.4570 - lr: 8.1000e-04
# Epoch 27/100
# 434/434 [==============================] - ETA: 0s - loss: 0.9372 - accuracy: 0.5957
# Epoch 00027: val_loss did not improve from 1.07716
# 434/434 [==============================] - 878s 2s/step - loss: 0.9372 - accuracy: 0.5957 - val_loss: 1.1563 - val_accuracy: 0.4723 - lr: 8.1000e-04
# Epoch 28/100
# 434/434 [==============================] - ETA: 0s - loss: 0.9118 - accuracy: 0.6174
# Epoch 00028: val_loss improved from 1.07716 to 1.07290, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 892s 2s/step - loss: 0.9118 - accuracy: 0.6174 - val_loss: 1.0729 - val_accuracy: 0.5391 - lr: 8.1000e-04
# Epoch 29/100
# 434/434 [==============================] - ETA: 0s - loss: 0.9016 - accuracy: 0.6255
# Epoch 00029: val_loss did not improve from 1.07290
# 434/434 [==============================] - 893s 2s/step - loss: 0.9016 - accuracy: 0.6255 - val_loss: 1.0756 - val_accuracy: 0.5043 - lr: 8.1000e-04
# Epoch 30/100
# 434/434 [==============================] - ETA: 0s - loss: 0.8926 - accuracy: 0.6305
# Epoch 00030: val_loss improved from 1.07290 to 1.04665, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 887s 2s/step - loss: 0.8926 - accuracy: 0.6305 - val_loss: 1.0467 - val_accuracy: 0.5047 - lr: 8.1000e-04
# Epoch 31/100
# 434/434 [==============================] - ETA: 0s - loss: 0.8711 - accuracy: 0.6430
# Epoch 00031: val_loss did not improve from 1.04665
# 434/434 [==============================] - 874s 2s/step - loss: 0.8711 - accuracy: 0.6430 - val_loss: 1.1614 - val_accuracy: 0.4688 - lr: 8.1000e-04
# Epoch 32/100
# 434/434 [==============================] - ETA: 0s - loss: 0.8686 - accuracy: 0.6468
# Epoch 00032: val_loss did not improve from 1.04665
# 434/434 [==============================] - 876s 2s/step - loss: 0.8686 - accuracy: 0.6468 - val_loss: 1.0677 - val_accuracy: 0.5340 - lr: 8.1000e-04
# Epoch 33/100
# 434/434 [==============================] - ETA: 0s - loss: 0.8506 - accuracy: 0.6500
# Epoch 00033: val_loss did not improve from 1.04665
# 434/434 [==============================] - 876s 2s/step - loss: 0.8506 - accuracy: 0.6500 - val_loss: 1.0596 - val_accuracy: 0.5516 - lr: 8.1000e-04
# Epoch 34/100
# 434/434 [==============================] - ETA: 0s - loss: 0.8448 - accuracy: 0.6572
# Epoch 00034: val_loss did not improve from 1.04665
# 434/434 [==============================] - 879s 2s/step - loss: 0.8448 - accuracy: 0.6572 - val_loss: 1.0984 - val_accuracy: 0.5445 - lr: 7.2900e-04
# Epoch 35/100
# 434/434 [==============================] - ETA: 0s - loss: 0.8220 - accuracy: 0.6660
# Epoch 00035: val_loss did not improve from 1.04665
# 434/434 [==============================] - 641s 1s/step - loss: 0.8220 - accuracy: 0.6660 - val_loss: 1.0839 - val_accuracy: 0.5320 - lr: 7.2900e-04
# Epoch 36/100
# 434/434 [==============================] - ETA: 0s - loss: 0.8124 - accuracy: 0.6724
# Epoch 00036: val_loss did not improve from 1.04665
# 434/434 [==============================] - 471s 1s/step - loss: 0.8124 - accuracy: 0.6724 - val_loss: 1.2052 - val_accuracy: 0.5406 - lr: 7.2900e-04
# Epoch 37/100
# 434/434 [==============================] - ETA: 0s - loss: 0.8021 - accuracy: 0.6780
# Epoch 00037: val_loss did not improve from 1.04665
# 434/434 [==============================] - 471s 1s/step - loss: 0.8021 - accuracy: 0.6780 - val_loss: 1.1336 - val_accuracy: 0.5777 - lr: 6.5610e-04
# Epoch 38/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7972 - accuracy: 0.6805
# Epoch 00038: val_loss did not improve from 1.04665
# 434/434 [==============================] - 472s 1s/step - loss: 0.7972 - accuracy: 0.6805 - val_loss: 1.0652 - val_accuracy: 0.5652 - lr: 6.5610e-04
# Epoch 39/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7875 - accuracy: 0.6864
# Epoch 00039: val_loss did not improve from 1.04665
# 434/434 [==============================] - 470s 1s/step - loss: 0.7875 - accuracy: 0.6864 - val_loss: 1.0684 - val_accuracy: 0.5859 - lr: 6.5610e-04
# Epoch 40/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7744 - accuracy: 0.6923
# Epoch 00040: val_loss did not improve from 1.04665
# 434/434 [==============================] - 469s 1s/step - loss: 0.7744 - accuracy: 0.6923 - val_loss: 1.0953 - val_accuracy: 0.5859 - lr: 5.9049e-04
# Epoch 41/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7653 - accuracy: 0.7004
# Epoch 00041: val_loss did not improve from 1.04665
# 434/434 [==============================] - 467s 1s/step - loss: 0.7653 - accuracy: 0.7004 - val_loss: 1.1202 - val_accuracy: 0.5879 - lr: 5.9049e-04
# Epoch 42/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7611 - accuracy: 0.7025
# Epoch 00042: val_loss did not improve from 1.04665
# 434/434 [==============================] - 466s 1s/step - loss: 0.7611 - accuracy: 0.7025 - val_loss: 1.0916 - val_accuracy: 0.5922 - lr: 5.9049e-04
# Epoch 43/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7548 - accuracy: 0.7064
# Epoch 00043: val_loss did not improve from 1.04665
# 434/434 [==============================] - 466s 1s/step - loss: 0.7548 - accuracy: 0.7064 - val_loss: 1.0624 - val_accuracy: 0.5855 - lr: 5.3144e-04
# Epoch 44/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7518 - accuracy: 0.7103
# Epoch 00044: val_loss did not improve from 1.04665
# 434/434 [==============================] - 466s 1s/step - loss: 0.7518 - accuracy: 0.7103 - val_loss: 1.1468 - val_accuracy: 0.5656 - lr: 5.3144e-04
# Epoch 45/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7372 - accuracy: 0.7139
# Epoch 00045: val_loss did not improve from 1.04665
# 434/434 [==============================] - 469s 1s/step - loss: 0.7372 - accuracy: 0.7139 - val_loss: 1.1310 - val_accuracy: 0.5891 - lr: 5.3144e-04
# Epoch 46/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7358 - accuracy: 0.7127
# Epoch 00046: val_loss did not improve from 1.04665
# 434/434 [==============================] - 469s 1s/step - loss: 0.7358 - accuracy: 0.7127 - val_loss: 1.0834 - val_accuracy: 0.5945 - lr: 4.7830e-04
# Epoch 47/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7313 - accuracy: 0.7211
# Epoch 00047: val_loss did not improve from 1.04665
# 434/434 [==============================] - 466s 1s/step - loss: 0.7313 - accuracy: 0.7211 - val_loss: 1.0717 - val_accuracy: 0.6062 - lr: 4.7830e-04
# Epoch 48/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7190 - accuracy: 0.7224
# Epoch 00048: val_loss improved from 1.04665 to 1.04092, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 471s 1s/step - loss: 0.7190 - accuracy: 0.7224 - val_loss: 1.0409 - val_accuracy: 0.5879 - lr: 4.7830e-04
# Epoch 49/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7197 - accuracy: 0.7232
# Epoch 00049: val_loss improved from 1.04092 to 1.01321, saving model to rong_test_4_1_checkpoint_file.hd5
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# 434/434 [==============================] - 475s 1s/step - loss: 0.7197 - accuracy: 0.7232 - val_loss: 1.0132 - val_accuracy: 0.5949 - lr: 4.7830e-04
# Epoch 50/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7168 - accuracy: 0.7254
# Epoch 00050: val_loss did not improve from 1.01321
# 434/434 [==============================] - 471s 1s/step - loss: 0.7168 - accuracy: 0.7254 - val_loss: 1.0419 - val_accuracy: 0.6141 - lr: 4.7830e-04
# Epoch 51/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7042 - accuracy: 0.7296
# Epoch 00051: val_loss did not improve from 1.01321
# 434/434 [==============================] - 471s 1s/step - loss: 0.7042 - accuracy: 0.7296 - val_loss: 1.1262 - val_accuracy: 0.5977 - lr: 4.7830e-04
# Epoch 52/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 0.7311
# Epoch 00052: val_loss did not improve from 1.01321
# 434/434 [==============================] - 469s 1s/step - loss: 0.7049 - accuracy: 0.7311 - val_loss: 1.1433 - val_accuracy: 0.6098 - lr: 4.7830e-04
# Epoch 53/100
# 434/434 [==============================] - ETA: 0s - loss: 0.7022 - accuracy: 0.7329
# Epoch 00053: val_loss did not improve from 1.01321
# 434/434 [==============================] - 472s 1s/step - loss: 0.7022 - accuracy: 0.7329 - val_loss: 1.1089 - val_accuracy: 0.5980 - lr: 4.3047e-04
# Epoch 54/100
# 434/434 [==============================] - ETA: 0s - loss: 0.6942 - accuracy: 0.7367
# Epoch 00054: val_loss did not improve from 1.01321
# 434/434 [==============================] - 470s 1s/step - loss: 0.6942 - accuracy: 0.7367 - val_loss: 1.0728 - val_accuracy: 0.6195 - lr: 4.3047e-04
# Epoch 55/100
# 434/434 [==============================] - ETA: 0s - loss: 0.6891 - accuracy: 0.7381
# Epoch 00055: val_loss did not improve from 1.01321
# 434/434 [==============================] - 470s 1s/step - loss: 0.6891 - accuracy: 0.7381 - val_loss: 1.0394 - val_accuracy: 0.6145 - lr: 4.3047e-04
# Epoch 56/100
# 434/434 [==============================] - ETA: 0s - loss: 0.6835 - accuracy: 0.7397
# Epoch 00056: val_loss did not improve from 1.01321
# 434/434 [==============================] - 468s 1s/step - loss: 0.6835 - accuracy: 0.7397 - val_loss: 1.1147 - val_accuracy: 0.6055 - lr: 3.8742e-04
# Epoch 57/100
# 434/434 [==============================] - ETA: 0s - loss: 0.6786 - accuracy: 0.7451
# Epoch 00057: val_loss did not improve from 1.01321
# 434/434 [==============================] - 471s 1s/step - loss: 0.6786 - accuracy: 0.7451 - val_loss: 1.1415 - val_accuracy: 0.5992 - lr: 3.8742e-04
# Epoch 58/100
# 434/434 [==============================] - ETA: 0s - loss: 0.6779 - accuracy: 0.7433
# Epoch 00058: val_loss did not improve from 1.01321
# 434/434 [==============================] - 469s 1s/step - loss: 0.6779 - accuracy: 0.7433 - val_loss: 1.1155 - val_accuracy: 0.5875 - lr: 3.8742e-04
# Epoch 59/100
# 434/434 [==============================] - ETA: 0s - loss: 0.6726 - accuracy: 0.7453
# Epoch 00059: val_loss did not improve from 1.01321
# 434/434 [==============================] - 471s 1s/step - loss: 0.6726 - accuracy: 0.7453 - val_loss: 1.1410 - val_accuracy: 0.6051 - lr: 3.4868e-04
# Epoch 60/100
# 434/434 [==============================] - ETA: 0s - loss: 0.6674 - accuracy: 0.7497
# Epoch 00060: val_loss did not improve from 1.01321
# 434/434 [==============================] - 470s 1s/step - loss: 0.6674 - accuracy: 0.7497 - val_loss: 1.0698 - val_accuracy: 0.6125 - lr: 3.4868e-04
# CPU times: user 2d 3h 22min 11s, sys: 2h 9min 24s, total: 2d 5h 31min 36s
# Wall time: 12h 51s

# %% [markdown]
# WARNING:tensorflow:From <timed exec>:20: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 434/434 [==============================] - ETA: 0s - loss: 1.5823 - accuracy: 0.3100
# Epoch 00001: val_loss improved from inf to 1.37921, saving model to rong_test_4_1_checkpoint_file.hd5
# WARNING:tensorflow:From /Users/rong/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: rong_test_4_1_checkpoint_file.hd5/assets
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 434/434 [==============================] - 1045s 2s/step - loss: 1.5823 - accuracy: 0.3100 - val_loss: 1.3792 - val_accuracy: 0.3379 - lr: 0.0010
# Epoch 2/100
# 227/434 [==============>...............] - ETA: 7:55 - loss: 1.3783 - accuracy: 0.3505

# %% [markdown]
# Now that the network is being trained, I suggest that you go and finish that book you started or go for a run. It took me about an hour on Google Colab.
#
# Test the model
# Remember the private set we stored separately? That was for this very moment. This is the moment of truth and this is where we will reap the fruit of our labor.

# %%
# predicted_test_labels = np.argmax(model.predict(test_data), axis=1)
# test_labels = np.argmax(test_labels, axis=1)

# print ("Accuracy score = ", accuracy_score(test_labels, predicted_test_labels))

# %%
model_json = model.to_json()
with open("rong_test_4_1_model_file_json.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
# model.save_weights("/content/gdrive/My Drive/Colab Notebooks/Emotion Recognition/FERmodel.h5")
# print("Saved model to disk")

# %%
model.save_weights('rong_test_4_1_weights.h5')
model.save('rong_test_4_1_model_file.h5')

# %%
print(model_info.history.keys())

import matplotlib.pyplot as plt
plt.plot(model_info.history['loss'])
plt.plot(model_info.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
1+1
