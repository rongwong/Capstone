# %% [markdown]
# credits: APEKSHA PRIYA, Priya Dwivedi
#
# https://github.com/priya-dwivedi/face_and_emotion_detection/blob/master/src/EmotionDetector_v2.ipynb
# https://towardsdatascience.com/face-detection-recognition-and-emotion-detection-in-8-lines-of-code-b2ce32d4d5de

# %%
from __future__ import print_function
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
import os
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.advanced_activations import ELU
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras.optimizers import RMSprop, SGD, Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras import regularizers
from keras.regularizers import l1

from keras.models import load_model

# %%
# initializing
num_classes = 3
img_rows, img_cols = 48, 48
batch_size = 120 #(change back for full load)

train_data_dir = '../test/train'
validation_data_dir = '../test/validation'

# %%
# Let's use some data augmentaiton 
# train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 16944 images belonging to 3 classes.
# Found 2099 images belonging to 3 classes.

# %%
print(validation_generator.class_indices)
# Out:
# {'happy': 0, 'neutral': 1, 'sad': 2}

# %%
# # Create the model
# model = Sequential()

# model.add(Conv2D(32, kernel_size=(3, 3), activation='elu',input_shape=(48,48,1)))
# # model.add(BatchNormalization())

# model.add(Conv2D(64, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(128, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(256, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(64, kernel_size=(1, 1), activation='elu'))
# # # model.add(BatchNormalization())

# model.add(Conv2D(3, kernel_size=(4, 4), activation='elu'))
# # model.add(BatchNormalization())

# model.add(Flatten())

# model.add(Activation("softmax"))

# model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())

# %%
# Create the model 2
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='elu',input_shape=(48,48,1)))
# model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3, 3), activation='elu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation='elu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, kernel_size=(3, 3), activation='elu'))
# model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, kernel_size=(3, 3), activation='elu'))
# # model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(2, 2), activation='elu'))
# model.add(BatchNormalization())

model.add(Flatten())

model.add(Dense(120, activation='elu'))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))
#model.add(Activation("softmax"))

model.summary()
# model.add(Dense(1024, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(7, activation='softmax'))
# model.add(Conv2D(5, kernel_size=(4, 4), activation='relu', kernel_regularizer=regularizers.l2(0.0001)))
# model.add(BatchNormalization())
# model.add(Activation("softmax"))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 256)         590080
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 1, 1, 128)         131200
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               15480
# _________________________________________________________________
# dropout (Dropout)            (None, 120)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 363
# =================================================================
# Total params: 1,124,963
# Trainable params: 1,124,963
# Non-trainable params: 0
# _________________________________________________________________

# %%
# If you want to train the same model or try other models, go for this


# filepath = os.path.join("./emotion_detector_models/model_v6_{epoch}.hdf5")

checkpoint = keras.callbacks.ModelCheckpoint('rong_test_2_6.hdf5',
                                             monitor='val_accuracy',
                                             verbose=1,
                                             save_best_only=True,
                                             mode='max')

callbacks = [checkpoint]

# checkpoint = ModelCheckpoint('rong_test_2.hdf5',
#                              monitor='val_loss',
#                              mode='min',
#                              save_best_only=True,
#                              verbose=1)

# earlystop = EarlyStopping(monitor='val_loss',
#                           min_delta=0,
#                           patience=9,
#                           verbose=1,
#                           restore_best_weights=True
#                           )

# reduce_lr = ReduceLROnPlateau(monitor='val_loss',
#                               factor=0.2,
#                               patience=3,
#                               verbose=1,
#                               min_delta=0.0001)

# callbacks = [checkpoint,reduce_lr]
# callbacks = [earlystop,checkpoint,reduce_lr]


# if mode == "train":
model.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001, decay=1e-6),metrics=['accuracy'])
nb_train_samples = 16944
nb_validation_samples = 2099
epochs = 100

model_info = model.fit_generator(
            train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=nb_validation_samples // batch_size)

# plot_model_history(model_info)
model.save_weights('rong_test_2_6.h5')
# Out:
# WARNING:tensorflow:From <ipython-input-7-af3db663adf8>:49: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 141/141 [==============================] - ETA: 0s - loss: 1.0779 - accuracy: 0.4387
# Epoch 00001: val_accuracy improved from -inf to 0.52402, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 86s 611ms/step - loss: 1.0779 - accuracy: 0.4387 - val_loss: 1.0023 - val_accuracy: 0.5240
# Epoch 2/100
# 141/141 [==============================] - ETA: 0s - loss: 0.9504 - accuracy: 0.5424
# Epoch 00002: val_accuracy improved from 0.52402 to 0.56961, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 94s 670ms/step - loss: 0.9504 - accuracy: 0.5424 - val_loss: 0.9735 - val_accuracy: 0.5696
# Epoch 3/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8886 - accuracy: 0.5827
# Epoch 00003: val_accuracy did not improve from 0.56961
# 141/141 [==============================] - 99s 704ms/step - loss: 0.8886 - accuracy: 0.5827 - val_loss: 0.9878 - val_accuracy: 0.5618
# Epoch 4/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8427 - accuracy: 0.6113
# Epoch 00004: val_accuracy improved from 0.56961 to 0.59363, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 97s 690ms/step - loss: 0.8427 - accuracy: 0.6113 - val_loss: 0.9686 - val_accuracy: 0.5936
# Epoch 5/100
# 141/141 [==============================] - ETA: 0s - loss: 0.8082 - accuracy: 0.6261
# Epoch 00005: val_accuracy improved from 0.59363 to 0.60000, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 95s 671ms/step - loss: 0.8082 - accuracy: 0.6261 - val_loss: 1.0177 - val_accuracy: 0.6000
# Epoch 6/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7909 - accuracy: 0.6369
# Epoch 00006: val_accuracy improved from 0.60000 to 0.61324, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 95s 676ms/step - loss: 0.7909 - accuracy: 0.6369 - val_loss: 0.9992 - val_accuracy: 0.6132
# Epoch 7/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7659 - accuracy: 0.6465
# Epoch 00007: val_accuracy improved from 0.61324 to 0.62255, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 94s 669ms/step - loss: 0.7659 - accuracy: 0.6465 - val_loss: 0.9867 - val_accuracy: 0.6225
# Epoch 8/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7555 - accuracy: 0.6564
# Epoch 00008: val_accuracy did not improve from 0.62255
# 141/141 [==============================] - 94s 667ms/step - loss: 0.7555 - accuracy: 0.6564 - val_loss: 0.9697 - val_accuracy: 0.6083
# Epoch 9/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7345 - accuracy: 0.6711
# Epoch 00009: val_accuracy improved from 0.62255 to 0.63137, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 97s 690ms/step - loss: 0.7345 - accuracy: 0.6711 - val_loss: 0.8822 - val_accuracy: 0.6314
# Epoch 10/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7208 - accuracy: 0.6738
# Epoch 00010: val_accuracy did not improve from 0.63137
# 141/141 [==============================] - 110s 779ms/step - loss: 0.7208 - accuracy: 0.6738 - val_loss: 0.9711 - val_accuracy: 0.6113
# Epoch 11/100
# 141/141 [==============================] - ETA: 0s - loss: 0.7011 - accuracy: 0.6873
# Epoch 00011: val_accuracy did not improve from 0.63137
# 141/141 [==============================] - 105s 745ms/step - loss: 0.7011 - accuracy: 0.6873 - val_loss: 1.0139 - val_accuracy: 0.6211
# Epoch 12/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6861 - accuracy: 0.6948
# Epoch 00012: val_accuracy did not improve from 0.63137
# 141/141 [==============================] - 104s 736ms/step - loss: 0.6861 - accuracy: 0.6948 - val_loss: 1.0950 - val_accuracy: 0.5995
# Epoch 13/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6754 - accuracy: 0.6997
# Epoch 00013: val_accuracy did not improve from 0.63137
# 141/141 [==============================] - 102s 724ms/step - loss: 0.6754 - accuracy: 0.6997 - val_loss: 1.0218 - val_accuracy: 0.6196
# Epoch 14/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6642 - accuracy: 0.7067
# Epoch 00014: val_accuracy did not improve from 0.63137
# 141/141 [==============================] - 93s 659ms/step - loss: 0.6642 - accuracy: 0.7067 - val_loss: 0.9810 - val_accuracy: 0.6211
# Epoch 15/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6558 - accuracy: 0.7089
# Epoch 00015: val_accuracy did not improve from 0.63137
# 141/141 [==============================] - 92s 652ms/step - loss: 0.6558 - accuracy: 0.7089 - val_loss: 0.9619 - val_accuracy: 0.6299
# Epoch 16/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6481 - accuracy: 0.7138
# Epoch 00016: val_accuracy did not improve from 0.63137
# 141/141 [==============================] - 92s 653ms/step - loss: 0.6481 - accuracy: 0.7138 - val_loss: 0.9738 - val_accuracy: 0.6240
# Epoch 17/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6340 - accuracy: 0.7227
# Epoch 00017: val_accuracy improved from 0.63137 to 0.64412, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 92s 654ms/step - loss: 0.6340 - accuracy: 0.7227 - val_loss: 0.9538 - val_accuracy: 0.6441
# Epoch 18/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6297 - accuracy: 0.7224
# Epoch 00018: val_accuracy did not improve from 0.64412
# 141/141 [==============================] - 92s 656ms/step - loss: 0.6297 - accuracy: 0.7224 - val_loss: 0.8794 - val_accuracy: 0.6299
# Epoch 19/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6187 - accuracy: 0.7293
# Epoch 00019: val_accuracy did not improve from 0.64412
# 141/141 [==============================] - 92s 650ms/step - loss: 0.6187 - accuracy: 0.7293 - val_loss: 1.0642 - val_accuracy: 0.6373
# Epoch 20/100
# 141/141 [==============================] - ETA: 0s - loss: 0.6124 - accuracy: 0.7329
# Epoch 00020: val_accuracy improved from 0.64412 to 0.64510, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 92s 654ms/step - loss: 0.6124 - accuracy: 0.7329 - val_loss: 1.0472 - val_accuracy: 0.6451
# Epoch 21/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5945 - accuracy: 0.7419
# Epoch 00021: val_accuracy did not improve from 0.64510
# 141/141 [==============================] - 92s 649ms/step - loss: 0.5945 - accuracy: 0.7419 - val_loss: 1.0246 - val_accuracy: 0.6431
# Epoch 22/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5912 - accuracy: 0.7422
# Epoch 00022: val_accuracy improved from 0.64510 to 0.65343, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 92s 654ms/step - loss: 0.5912 - accuracy: 0.7422 - val_loss: 1.0422 - val_accuracy: 0.6534
# Epoch 23/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5880 - accuracy: 0.7436
# Epoch 00023: val_accuracy improved from 0.65343 to 0.65490, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 92s 652ms/step - loss: 0.5880 - accuracy: 0.7436 - val_loss: 1.0179 - val_accuracy: 0.6549
# Epoch 24/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5860 - accuracy: 0.7504
# Epoch 00024: val_accuracy did not improve from 0.65490
# 141/141 [==============================] - 91s 648ms/step - loss: 0.5860 - accuracy: 0.7504 - val_loss: 0.9902 - val_accuracy: 0.6495
# Epoch 25/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5711 - accuracy: 0.7512
# Epoch 00025: val_accuracy did not improve from 0.65490
# 141/141 [==============================] - 92s 653ms/step - loss: 0.5711 - accuracy: 0.7512 - val_loss: 1.0211 - val_accuracy: 0.6402
# Epoch 26/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5744 - accuracy: 0.7493
# Epoch 00026: val_accuracy did not improve from 0.65490
# 141/141 [==============================] - 91s 649ms/step - loss: 0.5744 - accuracy: 0.7493 - val_loss: 1.0624 - val_accuracy: 0.6426
# Epoch 27/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5629 - accuracy: 0.7557
# Epoch 00027: val_accuracy improved from 0.65490 to 0.65539, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 92s 649ms/step - loss: 0.5629 - accuracy: 0.7557 - val_loss: 1.0236 - val_accuracy: 0.6554
# Epoch 28/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5537 - accuracy: 0.7631
# Epoch 00028: val_accuracy improved from 0.65539 to 0.66176, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 92s 653ms/step - loss: 0.5537 - accuracy: 0.7631 - val_loss: 0.9536 - val_accuracy: 0.6618
# Epoch 29/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5463 - accuracy: 0.7677
# Epoch 00029: val_accuracy did not improve from 0.66176
# 141/141 [==============================] - 93s 656ms/step - loss: 0.5463 - accuracy: 0.7677 - val_loss: 1.0234 - val_accuracy: 0.6402
# Epoch 30/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5361 - accuracy: 0.7699
# Epoch 00030: val_accuracy did not improve from 0.66176
# 141/141 [==============================] - 92s 653ms/step - loss: 0.5361 - accuracy: 0.7699 - val_loss: 1.0332 - val_accuracy: 0.6520
# Epoch 31/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5389 - accuracy: 0.7709
# Epoch 00031: val_accuracy did not improve from 0.66176
# 141/141 [==============================] - 92s 650ms/step - loss: 0.5389 - accuracy: 0.7709 - val_loss: 1.0486 - val_accuracy: 0.6466
# Epoch 32/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5238 - accuracy: 0.7808
# Epoch 00032: val_accuracy did not improve from 0.66176
# 141/141 [==============================] - 92s 650ms/step - loss: 0.5238 - accuracy: 0.7808 - val_loss: 1.0014 - val_accuracy: 0.6588
# Epoch 33/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5235 - accuracy: 0.7775
# Epoch 00033: val_accuracy did not improve from 0.66176
# 141/141 [==============================] - 92s 655ms/step - loss: 0.5235 - accuracy: 0.7775 - val_loss: 0.9950 - val_accuracy: 0.6510
# Epoch 34/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5211 - accuracy: 0.7792
# Epoch 00034: val_accuracy improved from 0.66176 to 0.66324, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 92s 653ms/step - loss: 0.5211 - accuracy: 0.7792 - val_loss: 0.9751 - val_accuracy: 0.6632
# Epoch 35/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5094 - accuracy: 0.7860
# Epoch 00035: val_accuracy did not improve from 0.66324
# 141/141 [==============================] - 92s 652ms/step - loss: 0.5094 - accuracy: 0.7860 - val_loss: 1.0083 - val_accuracy: 0.6525
# Epoch 36/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5128 - accuracy: 0.7843
# Epoch 00036: val_accuracy improved from 0.66324 to 0.66520, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 93s 656ms/step - loss: 0.5128 - accuracy: 0.7843 - val_loss: 1.0530 - val_accuracy: 0.6652
# Epoch 37/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4981 - accuracy: 0.7924
# Epoch 00037: val_accuracy did not improve from 0.66520
# 141/141 [==============================] - 92s 655ms/step - loss: 0.4981 - accuracy: 0.7924 - val_loss: 1.1527 - val_accuracy: 0.6652
# Epoch 38/100
# 141/141 [==============================] - ETA: 0s - loss: 0.5045 - accuracy: 0.7874
# Epoch 00038: val_accuracy did not improve from 0.66520
# 141/141 [==============================] - 93s 657ms/step - loss: 0.5045 - accuracy: 0.7874 - val_loss: 1.1216 - val_accuracy: 0.6564
# Epoch 39/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4973 - accuracy: 0.7920
# Epoch 00039: val_accuracy did not improve from 0.66520
# 141/141 [==============================] - 93s 657ms/step - loss: 0.4973 - accuracy: 0.7920 - val_loss: 1.1812 - val_accuracy: 0.6642
# Epoch 40/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4979 - accuracy: 0.7925
# Epoch 00040: val_accuracy did not improve from 0.66520
# 141/141 [==============================] - 92s 651ms/step - loss: 0.4979 - accuracy: 0.7925 - val_loss: 1.2114 - val_accuracy: 0.6569
# Epoch 41/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4886 - accuracy: 0.7948
# Epoch 00041: val_accuracy did not improve from 0.66520
# 141/141 [==============================] - 92s 653ms/step - loss: 0.4886 - accuracy: 0.7948 - val_loss: 1.1771 - val_accuracy: 0.6529
# Epoch 42/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4836 - accuracy: 0.7999
# Epoch 00042: val_accuracy did not improve from 0.66520
# 141/141 [==============================] - 92s 654ms/step - loss: 0.4836 - accuracy: 0.7999 - val_loss: 1.1214 - val_accuracy: 0.6574
# Epoch 43/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4810 - accuracy: 0.8031
# Epoch 00043: val_accuracy did not improve from 0.66520
# 141/141 [==============================] - 92s 649ms/step - loss: 0.4810 - accuracy: 0.8031 - val_loss: 1.2666 - val_accuracy: 0.6549
# Epoch 44/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4686 - accuracy: 0.8021
# Epoch 00044: val_accuracy did not improve from 0.66520
# 141/141 [==============================] - 92s 653ms/step - loss: 0.4686 - accuracy: 0.8021 - val_loss: 1.1249 - val_accuracy: 0.6618
# Epoch 45/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4667 - accuracy: 0.8057
# Epoch 00045: val_accuracy improved from 0.66520 to 0.66814, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 92s 654ms/step - loss: 0.4667 - accuracy: 0.8057 - val_loss: 1.2683 - val_accuracy: 0.6681
# Epoch 46/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4730 - accuracy: 0.8041
# Epoch 00046: val_accuracy did not improve from 0.66814
# 141/141 [==============================] - 92s 653ms/step - loss: 0.4730 - accuracy: 0.8041 - val_loss: 1.3268 - val_accuracy: 0.6456
# Epoch 47/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4667 - accuracy: 0.8077
# Epoch 00047: val_accuracy did not improve from 0.66814
# 141/141 [==============================] - 92s 654ms/step - loss: 0.4667 - accuracy: 0.8077 - val_loss: 1.2649 - val_accuracy: 0.6593
# Epoch 48/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4602 - accuracy: 0.8106
# Epoch 00048: val_accuracy did not improve from 0.66814
# 141/141 [==============================] - 92s 655ms/step - loss: 0.4602 - accuracy: 0.8106 - val_loss: 1.1848 - val_accuracy: 0.6603
# Epoch 49/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4625 - accuracy: 0.8069
# Epoch 00049: val_accuracy did not improve from 0.66814
# 141/141 [==============================] - 93s 658ms/step - loss: 0.4625 - accuracy: 0.8069 - val_loss: 1.1916 - val_accuracy: 0.6608
# Epoch 50/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4551 - accuracy: 0.8100
# Epoch 00050: val_accuracy did not improve from 0.66814
# 141/141 [==============================] - 93s 661ms/step - loss: 0.4551 - accuracy: 0.8100 - val_loss: 1.1576 - val_accuracy: 0.6647
# Epoch 51/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4485 - accuracy: 0.8134
# Epoch 00051: val_accuracy did not improve from 0.66814
# 141/141 [==============================] - 93s 659ms/step - loss: 0.4485 - accuracy: 0.8134 - val_loss: 1.1740 - val_accuracy: 0.6608
# Epoch 52/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4445 - accuracy: 0.8145
# Epoch 00052: val_accuracy improved from 0.66814 to 0.67794, saving model to rong_test_2_6.hdf5
# 141/141 [==============================] - 94s 665ms/step - loss: 0.4445 - accuracy: 0.8145 - val_loss: 1.2653 - val_accuracy: 0.6779
# Epoch 53/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4383 - accuracy: 0.8212
# Epoch 00053: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 99s 703ms/step - loss: 0.4383 - accuracy: 0.8212 - val_loss: 1.2905 - val_accuracy: 0.6588
# Epoch 54/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4415 - accuracy: 0.8189
# Epoch 00054: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 101s 714ms/step - loss: 0.4415 - accuracy: 0.8189 - val_loss: 1.2226 - val_accuracy: 0.6618
# Epoch 55/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4403 - accuracy: 0.8215
# Epoch 00055: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 97s 685ms/step - loss: 0.4403 - accuracy: 0.8215 - val_loss: 1.4562 - val_accuracy: 0.6534
# Epoch 56/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4373 - accuracy: 0.8232
# Epoch 00056: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 93s 662ms/step - loss: 0.4373 - accuracy: 0.8232 - val_loss: 1.2666 - val_accuracy: 0.6520
# Epoch 57/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4288 - accuracy: 0.8248
# Epoch 00057: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 93s 657ms/step - loss: 0.4288 - accuracy: 0.8248 - val_loss: 1.2718 - val_accuracy: 0.6667
# Epoch 58/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4296 - accuracy: 0.8210
# Epoch 00058: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 92s 655ms/step - loss: 0.4296 - accuracy: 0.8210 - val_loss: 1.3732 - val_accuracy: 0.6623
# Epoch 59/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4218 - accuracy: 0.8278
# Epoch 00059: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 93s 657ms/step - loss: 0.4218 - accuracy: 0.8278 - val_loss: 1.4834 - val_accuracy: 0.6583
# Epoch 60/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4215 - accuracy: 0.8277
# Epoch 00060: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 92s 655ms/step - loss: 0.4215 - accuracy: 0.8277 - val_loss: 1.3746 - val_accuracy: 0.6578
# Epoch 61/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4151 - accuracy: 0.8311
# Epoch 00061: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 94s 670ms/step - loss: 0.4151 - accuracy: 0.8311 - val_loss: 1.3644 - val_accuracy: 0.6544
# Epoch 62/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4120 - accuracy: 0.8330
# Epoch 00062: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 100s 711ms/step - loss: 0.4120 - accuracy: 0.8330 - val_loss: 1.3793 - val_accuracy: 0.6613
# Epoch 63/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4088 - accuracy: 0.8367
# Epoch 00063: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 99s 701ms/step - loss: 0.4088 - accuracy: 0.8367 - val_loss: 1.3084 - val_accuracy: 0.6549
# Epoch 64/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4108 - accuracy: 0.8308
# Epoch 00064: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 100s 711ms/step - loss: 0.4108 - accuracy: 0.8308 - val_loss: 1.4729 - val_accuracy: 0.6539
# Epoch 65/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4082 - accuracy: 0.8345
# Epoch 00065: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 96s 678ms/step - loss: 0.4082 - accuracy: 0.8345 - val_loss: 1.3285 - val_accuracy: 0.6574
# Epoch 66/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3959 - accuracy: 0.8406
# Epoch 00066: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 103s 733ms/step - loss: 0.3959 - accuracy: 0.8406 - val_loss: 1.4114 - val_accuracy: 0.6466
# Epoch 67/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4074 - accuracy: 0.8323
# Epoch 00067: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 99s 705ms/step - loss: 0.4074 - accuracy: 0.8323 - val_loss: 1.4111 - val_accuracy: 0.6686
# Epoch 68/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3870 - accuracy: 0.8415
# Epoch 00068: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 97s 690ms/step - loss: 0.3870 - accuracy: 0.8415 - val_loss: 1.5530 - val_accuracy: 0.6529
# Epoch 69/100
# 141/141 [==============================] - ETA: 0s - loss: 0.4047 - accuracy: 0.8352
# Epoch 00069: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 100s 711ms/step - loss: 0.4047 - accuracy: 0.8352 - val_loss: 1.4695 - val_accuracy: 0.6647
# Epoch 70/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3913 - accuracy: 0.8400
# Epoch 00070: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 100s 708ms/step - loss: 0.3913 - accuracy: 0.8400 - val_loss: 1.4532 - val_accuracy: 0.6534
# Epoch 71/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3768 - accuracy: 0.8494
# Epoch 00071: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 100s 707ms/step - loss: 0.3768 - accuracy: 0.8494 - val_loss: 1.6112 - val_accuracy: 0.6662
# Epoch 72/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3855 - accuracy: 0.8453
# Epoch 00072: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 99s 704ms/step - loss: 0.3855 - accuracy: 0.8453 - val_loss: 1.5759 - val_accuracy: 0.6539
# Epoch 73/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3779 - accuracy: 0.8476
# Epoch 00073: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 97s 691ms/step - loss: 0.3779 - accuracy: 0.8476 - val_loss: 1.8060 - val_accuracy: 0.6632
# Epoch 74/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3795 - accuracy: 0.8474
# Epoch 00074: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 95s 676ms/step - loss: 0.3795 - accuracy: 0.8474 - val_loss: 1.7894 - val_accuracy: 0.6642
# Epoch 75/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3851 - accuracy: 0.8445
# Epoch 00075: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 95s 676ms/step - loss: 0.3851 - accuracy: 0.8445 - val_loss: 1.7395 - val_accuracy: 0.6417
# Epoch 76/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3678 - accuracy: 0.8525
# Epoch 00076: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 95s 675ms/step - loss: 0.3678 - accuracy: 0.8525 - val_loss: 1.7047 - val_accuracy: 0.6495
# Epoch 77/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3686 - accuracy: 0.8530
# Epoch 00077: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 96s 682ms/step - loss: 0.3686 - accuracy: 0.8530 - val_loss: 1.6155 - val_accuracy: 0.6564
# Epoch 78/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3748 - accuracy: 0.8497
# Epoch 00078: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 96s 679ms/step - loss: 0.3748 - accuracy: 0.8497 - val_loss: 1.5841 - val_accuracy: 0.6549
# Epoch 79/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3636 - accuracy: 0.8541
# Epoch 00079: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 96s 682ms/step - loss: 0.3636 - accuracy: 0.8541 - val_loss: 1.5167 - val_accuracy: 0.6397
# Epoch 80/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3686 - accuracy: 0.8517
# Epoch 00080: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 95s 672ms/step - loss: 0.3686 - accuracy: 0.8517 - val_loss: 1.4449 - val_accuracy: 0.6574
# Epoch 81/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3684 - accuracy: 0.8532
# Epoch 00081: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 107s 758ms/step - loss: 0.3684 - accuracy: 0.8532 - val_loss: 1.9364 - val_accuracy: 0.6554
# Epoch 82/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3617 - accuracy: 0.8560
# Epoch 00082: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 107s 757ms/step - loss: 0.3617 - accuracy: 0.8560 - val_loss: 1.5988 - val_accuracy: 0.6613
# Epoch 83/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3583 - accuracy: 0.8585
# Epoch 00083: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 108s 763ms/step - loss: 0.3583 - accuracy: 0.8585 - val_loss: 1.9872 - val_accuracy: 0.6490
# Epoch 84/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3564 - accuracy: 0.8562
# Epoch 00084: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 97s 687ms/step - loss: 0.3564 - accuracy: 0.8562 - val_loss: 1.7199 - val_accuracy: 0.6475
# Epoch 85/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3549 - accuracy: 0.8594
# Epoch 00085: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 105s 745ms/step - loss: 0.3549 - accuracy: 0.8594 - val_loss: 1.4782 - val_accuracy: 0.6569
# Epoch 86/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.8576
# Epoch 00086: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 106s 751ms/step - loss: 0.3573 - accuracy: 0.8576 - val_loss: 1.7404 - val_accuracy: 0.6534
# Epoch 87/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3452 - accuracy: 0.8608
# Epoch 00087: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 105s 746ms/step - loss: 0.3452 - accuracy: 0.8608 - val_loss: 1.7967 - val_accuracy: 0.6515
# Epoch 88/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3521 - accuracy: 0.8617
# Epoch 00088: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 103s 732ms/step - loss: 0.3521 - accuracy: 0.8617 - val_loss: 1.8126 - val_accuracy: 0.6578
# Epoch 89/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3476 - accuracy: 0.8628
# Epoch 00089: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 108s 767ms/step - loss: 0.3476 - accuracy: 0.8628 - val_loss: 1.6794 - val_accuracy: 0.6534
# Epoch 90/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3540 - accuracy: 0.8570
# Epoch 00090: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 122s 863ms/step - loss: 0.3540 - accuracy: 0.8570 - val_loss: 2.0626 - val_accuracy: 0.6578
# Epoch 91/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3497 - accuracy: 0.8567
# Epoch 00091: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 107s 761ms/step - loss: 0.3497 - accuracy: 0.8567 - val_loss: 1.9714 - val_accuracy: 0.6539
# Epoch 92/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3382 - accuracy: 0.8667
# Epoch 00092: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 109s 770ms/step - loss: 0.3382 - accuracy: 0.8667 - val_loss: 2.0697 - val_accuracy: 0.6475
# Epoch 93/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3357 - accuracy: 0.8708
# Epoch 00093: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 98s 693ms/step - loss: 0.3357 - accuracy: 0.8708 - val_loss: 1.8113 - val_accuracy: 0.6471
# Epoch 94/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3361 - accuracy: 0.8666
# Epoch 00094: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 103s 730ms/step - loss: 0.3361 - accuracy: 0.8666 - val_loss: 1.8439 - val_accuracy: 0.6525
# Epoch 95/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3438 - accuracy: 0.8648
# Epoch 00095: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 97s 691ms/step - loss: 0.3438 - accuracy: 0.8648 - val_loss: 1.7335 - val_accuracy: 0.6672
# Epoch 96/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3337 - accuracy: 0.8682
# Epoch 00096: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 99s 699ms/step - loss: 0.3337 - accuracy: 0.8682 - val_loss: 1.9705 - val_accuracy: 0.6549
# Epoch 97/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3339 - accuracy: 0.8670
# Epoch 00097: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 99s 704ms/step - loss: 0.3339 - accuracy: 0.8670 - val_loss: 1.8474 - val_accuracy: 0.6549
# Epoch 98/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.8672
# Epoch 00098: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 105s 744ms/step - loss: 0.3324 - accuracy: 0.8672 - val_loss: 2.0973 - val_accuracy: 0.6520
# Epoch 99/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.8708
# Epoch 00099: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 105s 743ms/step - loss: 0.3274 - accuracy: 0.8708 - val_loss: 1.9335 - val_accuracy: 0.6642
# Epoch 100/100
# 141/141 [==============================] - ETA: 0s - loss: 0.3227 - accuracy: 0.8739
# Epoch 00100: val_accuracy did not improve from 0.67794
# 141/141 [==============================] - 98s 693ms/step - loss: 0.3227 - accuracy: 0.8739 - val_loss: 2.1585 - val_accuracy: 0.6515

# %%
print(model_info.history.keys())

import matplotlib.pyplot as plt
plt.plot(model_info.history['loss'])
plt.plot(model_info.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# model.load_weights('rong_test_2_5.h5')

# %%
# model_info = model.fit_generator(
#             train_generator,
#             steps_per_epoch=nb_train_samples // batch_size,
#             epochs=epochs,
#             callbacks = callbacks,
#             validation_data=validation_generator,
#             validation_steps=nb_validation_samples // batch_size)

# %%
# plt.plot(model_info.history['loss'])
# plt.plot(model_info.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'test'], loc='upper left')
# plt.show()

# %%
# model.load_weights('rong_test_2.h5')
# # history = model.fit_generator(
# #     train_generator,
# #     steps_per_epoch = nb_train_samples // batch_size,
# #     epochs = epochs,
# #     callbacks = callbacks,
# #     validation_data = validation_generator,
# #     validation_steps = nb_validation_samples // batch_size)

# %%
# import matplotlib.pyplot as plt
# import sklearn
# from sklearn.metrics import classification_report, confusion_matrix
# import numpy as np
# # Found 28709 images belonging to 7 classes.
# # Found 3589 images belonging to 7 classes.


# # nb_train_samples = 28273
# # nb_validation_samples = 3534
# nb_train_samples = 140
# nb_validation_samples = 70

# # We need to recreate our validation generator with shuffle = false
# validation_generator = val_datagen.flow_from_directory(
#         validation_data_dir,
#         color_mode = 'grayscale',
#         target_size=(img_rows, img_cols),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=False)

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# #Confution Matrix and Classification Report
# Y_pred = model.predict_generator(validation_generator, nb_validation_samples // batch_size+1)
# y_pred = np.argmax(Y_pred, axis=1)

# print('Confusion Matrix')
# print(confusion_matrix(validation_generator.classes, y_pred))
# print('Classification Report')
# target_names = list(class_labels.values())
# print(classification_report(validation_generator.classes, y_pred, target_names=target_names))

# plt.figure(figsize=(8,8))
# cnf_matrix = confusion_matrix(validation_generator.classes, y_pred)

# plt.imshow(cnf_matrix, interpolation='nearest')
# plt.colorbar()
# tick_marks = np.arange(len(classes))
# _ = plt.xticks(tick_marks, classes, rotation=90)
# _ = plt.yticks(tick_marks, classes)

# %%
# classifier = load_model('./emotion_detector_models/model_v3_71.hdf5')

# %%
# validation_generator = val_datagen.flow_from_directory(
#         validation_data_dir,
#         color_mode = 'grayscale',
#         target_size=(img_rows, img_cols),
#         batch_size=batch_size,
#         class_mode='categorical',
#         shuffle=False)

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())
# print(class_labels)

# %%
# from keras.models import load_model
# from keras.optimizers import RMSprop, SGD, Adam
# from keras.preprocessing import image
# import numpy as np
# import os
# import cv2
# import numpy as np
# from os import listdir
# from os.path import isfile, join
# import re

# def draw_test(name, pred, im, true_label):
#     BLACK = [0,0,0]
#     expanded_image = cv2.copyMakeBorder(im, 160, 0, 0, 300 ,cv2.BORDER_CONSTANT,value=BLACK)
#     cv2.putText(expanded_image, "predited - "+ pred, (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,0,255), 2)
#     cv2.putText(expanded_image, "true - "+ true_label, (20, 120) , cv2.FONT_HERSHEY_SIMPLEX,1, (0,255,0), 2)
#     cv2.imshow(name, expanded_image)


# def getRandomImage(path, img_width, img_height):
#     """function loads a random images from a random folder in our test path """
#     folders = path
#     random_directory = np.random.randint(0,len(folders))
#     path_class = folders[random_directory]
#     file_path = path
#     file_names = [f for f in listdir(file_path)]
#     random_file_index = np.random.randint(0,len(file_names))
#     image_name = file_names[random_file_index]
#     final_path = file_path + "/" + image_name
#     return image.load_img(final_path, target_size = (img_width, img_height),grayscale=True), final_path, path_class

# # dimensions of our images
# img_width, img_height = 48, 48

# # We use a very small learning rate 
# model.compile(loss = 'categorical_crossentropy',
#               optimizer = RMSprop(lr = 0.001),
#               metrics = ['accuracy'])

# files = []
# predictions = []
# true_labels = []

# # predicting images
# for i in range(0, 10):
#     path = '../non_load/fer2013/train' 
#     img, final_path, true_label = getRandomImage(path, img_width, img_height)
#     files.append(final_path)
#     true_labels.append(true_label)
#     x = image.img_to_array(img)
#     x = x * 1./255
#     x = np.expand_dims(x, axis=0)
#     images = np.vstack([x])
#     classes = model.predict_classes(images, batch_size = 10)
#     predictions.append(classes)
    
# for i in range(0, len(files)):
#     image = cv2.imread((files[i]))
#     image = cv2.resize(image, None, fx=3, fy=3, interpolation = cv2.INTER_CUBIC)
#     draw_test("Prediction", class_labels[predictions[i][0]], image, true_labels[i])
#     cv2.waitKey(0)

# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# from time import sleep
# from keras.preprocessing.image import img_to_array

# face_classifier = cv2.CascadeClassifier('../datasets/classifiers/haarcascade_frontalface_default.xml')
# classifier =load_model('rong_test_2_1.hdf5')

# class_labels = validation_generator.class_indices
# class_labels = {v: k for k, v in class_labels.items()}
# classes = list(class_labels.values())

# def face_detector(img):
#     # Convert image to grayscale
#     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#     faces = face_classifier.detectMultiScale(gray, 1.3, 5)
#     if faces is ():
#         return (0,0,0,0), np.zeros((48,48), np.uint8), img
    
#     for (x,y,w,h) in faces:
#         cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#         roi_gray = gray[y:y+h, x:x+w]

#     try:
#         roi_gray = cv2.resize(roi_gray, (48, 48), interpolation = cv2.INTER_AREA)
#     except:
#         return (x,w,y,h), np.zeros((48,48), np.uint8), img
#     return (x,w,y,h), roi_gray, img

# cap = cv2.VideoCapture(0)

# while True:

#     ret, frame = cap.read()
#     rect, face, image = face_detector(frame)
#     if np.sum([face]) != 0.0:
#         roi = face.astype("float") / 255.0
#         roi = img_to_array(roi)
#         roi = np.expand_dims(roi, axis=0)

#         # make a prediction on the ROI, then lookup the class
#         preds = classifier.predict(roi)[0]
#         label = class_labels[preds.argmax()]  
#         label_position = (rect[0] + int((rect[1]/2)), rect[2] + 25)
#         cv2.putText(image, label, label_position , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
#     else:
#         cv2.putText(image, "No Face Found", (20, 60) , cv2.FONT_HERSHEY_SIMPLEX,2, (0,255,0), 3)
        
#     cv2.imshow('All', image)
#     if cv2.waitKey(1) == 13: #13 is the Enter Key
#         break
        
# cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-28936e0903ba> in <module>
#      52
#      53 # cap.release()
# ---> 54 cv2.destroyAllWindows()
#
# NameError: name 'cv2' is not defined

# %%
# cap.release()
# cv2.destroyAllWindows()
