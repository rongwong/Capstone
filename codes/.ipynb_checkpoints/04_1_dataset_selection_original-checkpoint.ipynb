# %% [markdown]
# # 4.1 Original Dataset Modeling

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Results:</b> This dataset did not out-perform the AE dataset.
#
# Go straight to [Results](#Results) for Original Dataset
# </div>

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import classification_report, confusion_matrix


# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## Creating the Network of Best Model

# %%
#shaping X_train and X_test
train_data_dir = "../datasets/train_cropped_original/train"
validation_data_dir = "../datasets/train_cropped_original/val"
filepath = "../models/best_model_original_cp.hdf5"

img_rows, img_cols = 48, 48
num_classes = 4
epochs = 100
batch_size = 64

# %%
#callbacks

checkpoint = ModelCheckpoint(filepath,
                             monitor='val_categorical_accuracy',
                             mode='max',
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_categorical_accuracy',
                          min_delta=0,
                          mode='auto',
                          patience=15,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = ReduceLROnPlateau(monitor='val_categorical_accuracy',
                              factor=0.2,
                              mode='auto',
                              patience=5,
                              verbose=1,
                              min_delta=0.001)

# callbacks = [checkpoint]
callbacks = [earlystop,checkpoint,reduce_lr]

# %%
#data augmentation for train dataset, normalize all 

val_datagen = ImageDataGenerator(rescale=1./255)

train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')


train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 19601 images belonging to 4 classes.
# Found 4198 images belonging to 4 classes.

# %%
global train_samples, validation_samples
train_samples = 19601
validation_samples = 4198


print(validation_generator.class_indices)
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
#Model
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation="relu", input_shape= (48,48,1)))
model.add(Conv2D(16, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Flatten())
model.add(Dense(4, activation="softmax"))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 16)        2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 128)         73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 2052
# =================================================================
# Total params: 286,036
# Trainable params: 286,036
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile model
model.compile(optimizer= Adam(lr=0.001, decay=1e-6),
              loss="categorical_crossentropy",
              metrics=["categorical_accuracy"])

# %%
# %%time

#fit model
history = model.fit_generator(
            train_generator,
            steps_per_epoch=train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From <timed exec>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2607 - categorical_accuracy: 0.4102
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.43678, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 27s 88ms/step - loss: 1.2607 - categorical_accuracy: 0.4102 - val_loss: 1.2308 - val_categorical_accuracy: 0.4368 - lr: 0.0010
# Epoch 2/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1827 - categorical_accuracy: 0.4932
# Epoch 00002: val_categorical_accuracy improved from 0.43678 to 0.58774, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 35s 114ms/step - loss: 1.1827 - categorical_accuracy: 0.4932 - val_loss: 1.0355 - val_categorical_accuracy: 0.5877 - lr: 0.0010
# Epoch 3/100
# 306/306 [==============================] - ETA: 0s - loss: 1.0610 - categorical_accuracy: 0.5687
# Epoch 00003: val_categorical_accuracy improved from 0.58774 to 0.62091, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 50s 162ms/step - loss: 1.0610 - categorical_accuracy: 0.5687 - val_loss: 0.9517 - val_categorical_accuracy: 0.6209 - lr: 0.0010
# Epoch 4/100
# 306/306 [==============================] - ETA: 0s - loss: 0.9944 - categorical_accuracy: 0.5960
# Epoch 00004: val_categorical_accuracy improved from 0.62091 to 0.64952, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 52s 169ms/step - loss: 0.9944 - categorical_accuracy: 0.5960 - val_loss: 0.8581 - val_categorical_accuracy: 0.6495 - lr: 0.0010
# Epoch 5/100
# 306/306 [==============================] - ETA: 0s - loss: 0.9312 - categorical_accuracy: 0.6204
# Epoch 00005: val_categorical_accuracy improved from 0.64952 to 0.67043, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 52s 170ms/step - loss: 0.9312 - categorical_accuracy: 0.6204 - val_loss: 0.8283 - val_categorical_accuracy: 0.6704 - lr: 0.0010
# Epoch 6/100
# 306/306 [==============================] - ETA: 0s - loss: 0.9016 - categorical_accuracy: 0.6349
# Epoch 00006: val_categorical_accuracy did not improve from 0.67043
# 306/306 [==============================] - 52s 168ms/step - loss: 0.9016 - categorical_accuracy: 0.6349 - val_loss: 0.8520 - val_categorical_accuracy: 0.6599 - lr: 0.0010
# Epoch 7/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8602 - categorical_accuracy: 0.6528
# Epoch 00007: val_categorical_accuracy improved from 0.67043 to 0.69014, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 52s 169ms/step - loss: 0.8602 - categorical_accuracy: 0.6528 - val_loss: 0.7650 - val_categorical_accuracy: 0.6901 - lr: 0.0010
# Epoch 8/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8240 - categorical_accuracy: 0.6667
# Epoch 00008: val_categorical_accuracy improved from 0.69014 to 0.70000, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 51s 167ms/step - loss: 0.8240 - categorical_accuracy: 0.6667 - val_loss: 0.7413 - val_categorical_accuracy: 0.7000 - lr: 0.0010
# Epoch 9/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8079 - categorical_accuracy: 0.6787
# Epoch 00009: val_categorical_accuracy improved from 0.70000 to 0.71106, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 51s 165ms/step - loss: 0.8079 - categorical_accuracy: 0.6787 - val_loss: 0.7167 - val_categorical_accuracy: 0.7111 - lr: 0.0010
# Epoch 10/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7941 - categorical_accuracy: 0.6836
# Epoch 00010: val_categorical_accuracy improved from 0.71106 to 0.72861, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 50s 162ms/step - loss: 0.7941 - categorical_accuracy: 0.6836 - val_loss: 0.6883 - val_categorical_accuracy: 0.7286 - lr: 0.0010
# Epoch 11/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7623 - categorical_accuracy: 0.6949
# Epoch 00011: val_categorical_accuracy improved from 0.72861 to 0.73702, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 51s 166ms/step - loss: 0.7623 - categorical_accuracy: 0.6949 - val_loss: 0.6776 - val_categorical_accuracy: 0.7370 - lr: 0.0010
# Epoch 12/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7485 - categorical_accuracy: 0.7014
# Epoch 00012: val_categorical_accuracy did not improve from 0.73702
# 306/306 [==============================] - 51s 166ms/step - loss: 0.7485 - categorical_accuracy: 0.7014 - val_loss: 0.6727 - val_categorical_accuracy: 0.7341 - lr: 0.0010
# Epoch 13/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7400 - categorical_accuracy: 0.7079
# Epoch 00013: val_categorical_accuracy did not improve from 0.73702
# 306/306 [==============================] - 50s 165ms/step - loss: 0.7400 - categorical_accuracy: 0.7079 - val_loss: 0.6763 - val_categorical_accuracy: 0.7361 - lr: 0.0010
# Epoch 14/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7251 - categorical_accuracy: 0.7120
# Epoch 00014: val_categorical_accuracy improved from 0.73702 to 0.74904, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 52s 168ms/step - loss: 0.7251 - categorical_accuracy: 0.7120 - val_loss: 0.6497 - val_categorical_accuracy: 0.7490 - lr: 0.0010
# Epoch 15/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7160 - categorical_accuracy: 0.7186
# Epoch 00015: val_categorical_accuracy did not improve from 0.74904
# 306/306 [==============================] - 52s 168ms/step - loss: 0.7160 - categorical_accuracy: 0.7186 - val_loss: 0.6825 - val_categorical_accuracy: 0.7339 - lr: 0.0010
# Epoch 16/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7033 - categorical_accuracy: 0.7260
# Epoch 00016: val_categorical_accuracy did not improve from 0.74904
# 306/306 [==============================] - 51s 166ms/step - loss: 0.7033 - categorical_accuracy: 0.7260 - val_loss: 0.6422 - val_categorical_accuracy: 0.7462 - lr: 0.0010
# Epoch 17/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6933 - categorical_accuracy: 0.7301
# Epoch 00017: val_categorical_accuracy improved from 0.74904 to 0.75120, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 51s 167ms/step - loss: 0.6933 - categorical_accuracy: 0.7301 - val_loss: 0.6315 - val_categorical_accuracy: 0.7512 - lr: 0.0010
# Epoch 18/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6878 - categorical_accuracy: 0.7304
# Epoch 00018: val_categorical_accuracy improved from 0.75120 to 0.76298, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 53s 172ms/step - loss: 0.6878 - categorical_accuracy: 0.7304 - val_loss: 0.6198 - val_categorical_accuracy: 0.7630 - lr: 0.0010
# Epoch 19/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6831 - categorical_accuracy: 0.7316
# Epoch 00019: val_categorical_accuracy did not improve from 0.76298
# 306/306 [==============================] - 53s 172ms/step - loss: 0.6831 - categorical_accuracy: 0.7316 - val_loss: 0.6354 - val_categorical_accuracy: 0.7502 - lr: 0.0010
# Epoch 20/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6719 - categorical_accuracy: 0.7374
# Epoch 00020: val_categorical_accuracy did not improve from 0.76298
# 306/306 [==============================] - 51s 166ms/step - loss: 0.6719 - categorical_accuracy: 0.7374 - val_loss: 0.6037 - val_categorical_accuracy: 0.7618 - lr: 0.0010
# Epoch 21/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6592 - categorical_accuracy: 0.7426
# Epoch 00021: val_categorical_accuracy did not improve from 0.76298
# 306/306 [==============================] - 50s 165ms/step - loss: 0.6592 - categorical_accuracy: 0.7426 - val_loss: 0.6446 - val_categorical_accuracy: 0.7505 - lr: 0.0010
# Epoch 22/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6692 - categorical_accuracy: 0.7404
# Epoch 00022: val_categorical_accuracy did not improve from 0.76298
# 306/306 [==============================] - 50s 164ms/step - loss: 0.6692 - categorical_accuracy: 0.7404 - val_loss: 0.6186 - val_categorical_accuracy: 0.7575 - lr: 0.0010
# Epoch 23/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6526 - categorical_accuracy: 0.7432
# Epoch 00023: val_categorical_accuracy did not improve from 0.76298
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 306/306 [==============================] - 51s 168ms/step - loss: 0.6526 - categorical_accuracy: 0.7432 - val_loss: 0.6038 - val_categorical_accuracy: 0.7620 - lr: 0.0010
# Epoch 24/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6189 - categorical_accuracy: 0.7619
# Epoch 00024: val_categorical_accuracy improved from 0.76298 to 0.77428, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 51s 166ms/step - loss: 0.6189 - categorical_accuracy: 0.7619 - val_loss: 0.5830 - val_categorical_accuracy: 0.7743 - lr: 2.0000e-04
# Epoch 25/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6074 - categorical_accuracy: 0.7659
# Epoch 00025: val_categorical_accuracy did not improve from 0.77428
# 306/306 [==============================] - 49s 161ms/step - loss: 0.6074 - categorical_accuracy: 0.7659 - val_loss: 0.5853 - val_categorical_accuracy: 0.7740 - lr: 2.0000e-04
# Epoch 26/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6027 - categorical_accuracy: 0.7654
# Epoch 00026: val_categorical_accuracy did not improve from 0.77428
# 306/306 [==============================] - 49s 161ms/step - loss: 0.6027 - categorical_accuracy: 0.7654 - val_loss: 0.5772 - val_categorical_accuracy: 0.7721 - lr: 2.0000e-04
# Epoch 27/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5980 - categorical_accuracy: 0.7705
# Epoch 00027: val_categorical_accuracy improved from 0.77428 to 0.77524, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 49s 161ms/step - loss: 0.5980 - categorical_accuracy: 0.7705 - val_loss: 0.5903 - val_categorical_accuracy: 0.7752 - lr: 2.0000e-04
# Epoch 28/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5921 - categorical_accuracy: 0.7712
# Epoch 00028: val_categorical_accuracy improved from 0.77524 to 0.77957, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 52s 171ms/step - loss: 0.5921 - categorical_accuracy: 0.7712 - val_loss: 0.5686 - val_categorical_accuracy: 0.7796 - lr: 2.0000e-04
# Epoch 29/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5964 - categorical_accuracy: 0.7679
# Epoch 00029: val_categorical_accuracy did not improve from 0.77957
# 306/306 [==============================] - 49s 160ms/step - loss: 0.5964 - categorical_accuracy: 0.7679 - val_loss: 0.5773 - val_categorical_accuracy: 0.7752 - lr: 2.0000e-04
# Epoch 30/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5893 - categorical_accuracy: 0.7726
# Epoch 00030: val_categorical_accuracy did not improve from 0.77957
# 306/306 [==============================] - 50s 163ms/step - loss: 0.5893 - categorical_accuracy: 0.7726 - val_loss: 0.5825 - val_categorical_accuracy: 0.7743 - lr: 2.0000e-04
# Epoch 31/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5916 - categorical_accuracy: 0.7740
# Epoch 00031: val_categorical_accuracy did not improve from 0.77957
# 306/306 [==============================] - 48s 158ms/step - loss: 0.5916 - categorical_accuracy: 0.7740 - val_loss: 0.5944 - val_categorical_accuracy: 0.7702 - lr: 2.0000e-04
# Epoch 32/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5859 - categorical_accuracy: 0.7717
# Epoch 00032: val_categorical_accuracy did not improve from 0.77957
# 306/306 [==============================] - 49s 160ms/step - loss: 0.5859 - categorical_accuracy: 0.7717 - val_loss: 0.5891 - val_categorical_accuracy: 0.7721 - lr: 2.0000e-04
# Epoch 33/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5852 - categorical_accuracy: 0.7751
# Epoch 00033: val_categorical_accuracy did not improve from 0.77957
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 306/306 [==============================] - 49s 159ms/step - loss: 0.5852 - categorical_accuracy: 0.7751 - val_loss: 0.5910 - val_categorical_accuracy: 0.7666 - lr: 2.0000e-04
# Epoch 34/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5704 - categorical_accuracy: 0.7819
# Epoch 00034: val_categorical_accuracy did not improve from 0.77957
# 306/306 [==============================] - 49s 159ms/step - loss: 0.5704 - categorical_accuracy: 0.7819 - val_loss: 0.5700 - val_categorical_accuracy: 0.7760 - lr: 4.0000e-05
# Epoch 35/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5637 - categorical_accuracy: 0.7870
# Epoch 00035: val_categorical_accuracy did not improve from 0.77957
# 306/306 [==============================] - 49s 160ms/step - loss: 0.5637 - categorical_accuracy: 0.7870 - val_loss: 0.5655 - val_categorical_accuracy: 0.7781 - lr: 4.0000e-05
# Epoch 36/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5743 - categorical_accuracy: 0.7812
# Epoch 00036: val_categorical_accuracy did not improve from 0.77957
# 306/306 [==============================] - 49s 159ms/step - loss: 0.5743 - categorical_accuracy: 0.7812 - val_loss: 0.5658 - val_categorical_accuracy: 0.7779 - lr: 4.0000e-05
# Epoch 37/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5742 - categorical_accuracy: 0.7791
# Epoch 00037: val_categorical_accuracy did not improve from 0.77957
# 306/306 [==============================] - 48s 158ms/step - loss: 0.5742 - categorical_accuracy: 0.7791 - val_loss: 0.5719 - val_categorical_accuracy: 0.7767 - lr: 4.0000e-05
# Epoch 38/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5688 - categorical_accuracy: 0.7817
# Epoch 00038: val_categorical_accuracy did not improve from 0.77957
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 306/306 [==============================] - 49s 161ms/step - loss: 0.5688 - categorical_accuracy: 0.7817 - val_loss: 0.5655 - val_categorical_accuracy: 0.7793 - lr: 4.0000e-05
# Epoch 39/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5684 - categorical_accuracy: 0.7844
# Epoch 00039: val_categorical_accuracy improved from 0.77957 to 0.78149, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 52s 169ms/step - loss: 0.5684 - categorical_accuracy: 0.7844 - val_loss: 0.5660 - val_categorical_accuracy: 0.7815 - lr: 8.0000e-06
# Epoch 40/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5673 - categorical_accuracy: 0.7826
# Epoch 00040: val_categorical_accuracy did not improve from 0.78149
# 306/306 [==============================] - 51s 166ms/step - loss: 0.5673 - categorical_accuracy: 0.7826 - val_loss: 0.5660 - val_categorical_accuracy: 0.7815 - lr: 8.0000e-06
# Epoch 41/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5662 - categorical_accuracy: 0.7828
# Epoch 00041: val_categorical_accuracy did not improve from 0.78149
# 306/306 [==============================] - 50s 164ms/step - loss: 0.5662 - categorical_accuracy: 0.7828 - val_loss: 0.5647 - val_categorical_accuracy: 0.7805 - lr: 8.0000e-06
# Epoch 42/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5698 - categorical_accuracy: 0.7812
# Epoch 00042: val_categorical_accuracy improved from 0.78149 to 0.78173, saving model to ../models/best_model_original_cp.hdf5
# 306/306 [==============================] - 49s 162ms/step - loss: 0.5698 - categorical_accuracy: 0.7812 - val_loss: 0.5651 - val_categorical_accuracy: 0.7817 - lr: 8.0000e-06
# Epoch 43/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5663 - categorical_accuracy: 0.7818
# Epoch 00043: val_categorical_accuracy did not improve from 0.78173
# 306/306 [==============================] - 51s 168ms/step - loss: 0.5663 - categorical_accuracy: 0.7818 - val_loss: 0.5666 - val_categorical_accuracy: 0.7798 - lr: 8.0000e-06
# Epoch 44/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5691 - categorical_accuracy: 0.7818
# Epoch 00044: val_categorical_accuracy improved from 0.78173 to 0.78221, saving model to ../models/best_model_original_cp.hdf5
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 306/306 [==============================] - 49s 161ms/step - loss: 0.5691 - categorical_accuracy: 0.7818 - val_loss: 0.5656 - val_categorical_accuracy: 0.7822 - lr: 8.0000e-06
# Epoch 45/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5665 - categorical_accuracy: 0.7802
# Epoch 00045: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 49s 160ms/step - loss: 0.5665 - categorical_accuracy: 0.7802 - val_loss: 0.5677 - val_categorical_accuracy: 0.7808 - lr: 1.6000e-06
# Epoch 46/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5576 - categorical_accuracy: 0.7866
# Epoch 00046: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 49s 160ms/step - loss: 0.5576 - categorical_accuracy: 0.7866 - val_loss: 0.5677 - val_categorical_accuracy: 0.7798 - lr: 1.6000e-06
# Epoch 47/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5723 - categorical_accuracy: 0.7788
# Epoch 00047: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 49s 159ms/step - loss: 0.5723 - categorical_accuracy: 0.7788 - val_loss: 0.5653 - val_categorical_accuracy: 0.7803 - lr: 1.6000e-06
# Epoch 48/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5653 - categorical_accuracy: 0.7860
# Epoch 00048: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 49s 159ms/step - loss: 0.5653 - categorical_accuracy: 0.7860 - val_loss: 0.5671 - val_categorical_accuracy: 0.7805 - lr: 1.6000e-06
# Epoch 49/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5659 - categorical_accuracy: 0.7811
# Epoch 00049: val_categorical_accuracy did not improve from 0.78221
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 306/306 [==============================] - 49s 161ms/step - loss: 0.5659 - categorical_accuracy: 0.7811 - val_loss: 0.5673 - val_categorical_accuracy: 0.7796 - lr: 1.6000e-06
# Epoch 50/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5649 - categorical_accuracy: 0.7795
# Epoch 00050: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 49s 160ms/step - loss: 0.5649 - categorical_accuracy: 0.7795 - val_loss: 0.5671 - val_categorical_accuracy: 0.7805 - lr: 3.2000e-07
# Epoch 51/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5694 - categorical_accuracy: 0.7822
# Epoch 00051: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 51s 166ms/step - loss: 0.5694 - categorical_accuracy: 0.7822 - val_loss: 0.5687 - val_categorical_accuracy: 0.7788 - lr: 3.2000e-07
# Epoch 52/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5676 - categorical_accuracy: 0.7833
# Epoch 00052: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 50s 163ms/step - loss: 0.5676 - categorical_accuracy: 0.7833 - val_loss: 0.5660 - val_categorical_accuracy: 0.7800 - lr: 3.2000e-07
# Epoch 53/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5618 - categorical_accuracy: 0.7842
# Epoch 00053: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 50s 164ms/step - loss: 0.5618 - categorical_accuracy: 0.7842 - val_loss: 0.5681 - val_categorical_accuracy: 0.7793 - lr: 3.2000e-07
# Epoch 54/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5661 - categorical_accuracy: 0.7807
# Epoch 00054: val_categorical_accuracy did not improve from 0.78221
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 306/306 [==============================] - 51s 168ms/step - loss: 0.5661 - categorical_accuracy: 0.7807 - val_loss: 0.5673 - val_categorical_accuracy: 0.7791 - lr: 3.2000e-07
# Epoch 55/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5656 - categorical_accuracy: 0.7823
# Epoch 00055: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 51s 168ms/step - loss: 0.5656 - categorical_accuracy: 0.7823 - val_loss: 0.5663 - val_categorical_accuracy: 0.7798 - lr: 6.4000e-08
# Epoch 56/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5674 - categorical_accuracy: 0.7804
# Epoch 00056: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 50s 164ms/step - loss: 0.5674 - categorical_accuracy: 0.7804 - val_loss: 0.5672 - val_categorical_accuracy: 0.7803 - lr: 6.4000e-08
# Epoch 57/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5650 - categorical_accuracy: 0.7825
# Epoch 00057: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 50s 164ms/step - loss: 0.5650 - categorical_accuracy: 0.7825 - val_loss: 0.5679 - val_categorical_accuracy: 0.7796 - lr: 6.4000e-08
# Epoch 58/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5563 - categorical_accuracy: 0.7884
# Epoch 00058: val_categorical_accuracy did not improve from 0.78221
# 306/306 [==============================] - 50s 165ms/step - loss: 0.5563 - categorical_accuracy: 0.7884 - val_loss: 0.5666 - val_categorical_accuracy: 0.7800 - lr: 6.4000e-08
# Epoch 59/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5644 - categorical_accuracy: 0.7834Restoring model weights from the end of the best epoch.
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.78221
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 306/306 [==============================] - 50s 164ms/step - loss: 0.5644 - categorical_accuracy: 0.7834 - val_loss: 0.5654 - val_categorical_accuracy: 0.7808 - lr: 6.4000e-08
# Epoch 00059: early stopping
# CPU times: user 2h 33min 37s, sys: 23min 50s, total: 2h 57min 28s
# Wall time: 48min 57s

# %% [markdown]
# ## Results

# %%
#plotting Accuracy and Loss curves
plt.figure(figsize=(15,5))

plt.subplot(121)
plt.plot(history.history["categorical_accuracy"], label = 'Train Accuracy', color='gold')
plt.plot(history.history["val_categorical_accuracy"], label = 'Validation Accuracy', color='slategray')
plt.title("Training and Validation Accuracy by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend();

plt.subplot(122)
plt.plot(history.history["loss"], label = 'Train Loss', color='gold')
plt.plot(history.history["val_loss"], label = 'Validation Loss', color='slategray')
plt.title("Training and Validation Loss by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend();

# %%
#Code snippet credit: APEKSHA PRIYA, Priya Dwivedi
#confusion matrix and classification report

#validation generator with shuffle = false
validation_generator1 = val_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

class_labels = validation_generator1.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())

#Confusion Matrix and Classification Report
Y_pred = model.predict_generator(validation_generator1, validation_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
y_test = validation_generator1.classes

#Generate Confusion Matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
cnf_matrix.ravel

print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(y_test, y_pred, target_names=target_names))


#plot confusion matrix
plt.figure(figsize=(8,8))
ax= plt.subplot()
sns.heatmap(cnf_matrix, annot=True, ax = ax, cmap='bone_r', fmt='g', cbar=False)
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad'])
ax.yaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad']);
# Out:
# Found 4198 images belonging to 4 classes.
# WARNING:tensorflow:From <ipython-input-10-6561d12b4ec9>:18: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.68      0.71      0.69       544
#        happy       0.90      0.89      0.89      1665
#      neutral       0.74      0.81      0.78      1401
#          sad       0.62      0.48      0.54       588
#
#     accuracy                           0.78      4198
#    macro avg       0.73      0.72      0.73      4198
# weighted avg       0.78      0.78      0.78      4198
