# %% [markdown]
# # 4.4 E Dataset Modeling

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Results:</b> This dataset did not out-perform the AE dataset.
#
# Go straight to [Results](#Results) for E Dataset
# </div>

# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import classification_report, confusion_matrix


# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ## Creating the Network of Best Model

# %%
#shaping X_train and X_test
train_data_dir = "../datasets/train_cropped_e/train"
validation_data_dir = "../datasets/train_cropped_e/val"
filepath = "../models/best_model_e_cp.hdf5"

img_rows, img_cols = 48, 48
num_classes = 4
epochs = 100
batch_size = 64

# %%
#callbacks

checkpoint = ModelCheckpoint(filepath,
                             monitor='val_categorical_accuracy',
                             mode='max',
                             save_best_only=True,
                             verbose=1)

earlystop = EarlyStopping(monitor='val_categorical_accuracy',
                          min_delta=0,
                          mode='auto',
                          patience=15,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_lr = ReduceLROnPlateau(monitor='val_categorical_accuracy',
                              factor=0.2,
                              mode='auto',
                              patience=5,
                              verbose=1,
                              min_delta=0.001)

# callbacks = [checkpoint]
callbacks = [earlystop,checkpoint,reduce_lr]

# %%
#data augmentation for train dataset, normalize all 

val_datagen = ImageDataGenerator(rescale=1./255)

train_datagen = ImageDataGenerator(
        rescale=1./255,
      rotation_range=30,
      shear_range=0.3,
      zoom_range=0.3,
      horizontal_flip=True,
      fill_mode='nearest')


train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(48,48),
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical')
# Out:
# Found 19601 images belonging to 4 classes.
# Found 4198 images belonging to 4 classes.

# %%
global train_samples, validation_samples
train_samples = 19601
validation_samples = 4198


print(validation_generator.class_indices)
# Out:
# {'angry': 0, 'happy': 1, 'neutral': 2, 'sad': 3}

# %%
#Model
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation="relu", input_shape= (48,48,1)))
model.add(Conv2D(16, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))
model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))

model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))

model.add(Flatten())
model.add(Dense(4, activation="softmax"))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 16)        2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 128)         73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 2052
# =================================================================
# Total params: 286,036
# Trainable params: 286,036
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile model
model.compile(optimizer= Adam(lr=0.001, decay=1e-6),
              loss="categorical_crossentropy",
              metrics=["categorical_accuracy"])

# %%
# %%time

#fit model
history = model.fit_generator(
            train_generator,
            steps_per_epoch=train_samples // batch_size,
            epochs=epochs,
            callbacks = callbacks,
            validation_data=validation_generator,
            validation_steps=validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From <timed exec>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 306/306 [==============================] - ETA: 0s - loss: 1.2657 - categorical_accuracy: 0.4052
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.48005, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 49s 161ms/step - loss: 1.2657 - categorical_accuracy: 0.4052 - val_loss: 1.2064 - val_categorical_accuracy: 0.4800 - lr: 0.0010
# Epoch 2/100
# 306/306 [==============================] - ETA: 0s - loss: 1.1282 - categorical_accuracy: 0.5305
# Epoch 00002: val_categorical_accuracy improved from 0.48005 to 0.60889, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 51s 167ms/step - loss: 1.1282 - categorical_accuracy: 0.5305 - val_loss: 0.9614 - val_categorical_accuracy: 0.6089 - lr: 0.0010
# Epoch 3/100
# 306/306 [==============================] - ETA: 0s - loss: 1.0283 - categorical_accuracy: 0.5767
# Epoch 00003: val_categorical_accuracy improved from 0.60889 to 0.62019, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 52s 169ms/step - loss: 1.0283 - categorical_accuracy: 0.5767 - val_loss: 0.9833 - val_categorical_accuracy: 0.6202 - lr: 0.0010
# Epoch 4/100
# 306/306 [==============================] - ETA: 0s - loss: 0.9784 - categorical_accuracy: 0.5998
# Epoch 00004: val_categorical_accuracy improved from 0.62019 to 0.65865, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 52s 169ms/step - loss: 0.9784 - categorical_accuracy: 0.5998 - val_loss: 0.8456 - val_categorical_accuracy: 0.6587 - lr: 0.0010
# Epoch 5/100
# 306/306 [==============================] - ETA: 0s - loss: 0.9288 - categorical_accuracy: 0.6215
# Epoch 00005: val_categorical_accuracy improved from 0.65865 to 0.66971, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 51s 165ms/step - loss: 0.9288 - categorical_accuracy: 0.6215 - val_loss: 0.8113 - val_categorical_accuracy: 0.6697 - lr: 0.0010
# Epoch 6/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8824 - categorical_accuracy: 0.6409
# Epoch 00006: val_categorical_accuracy improved from 0.66971 to 0.68702, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 51s 168ms/step - loss: 0.8824 - categorical_accuracy: 0.6409 - val_loss: 0.7790 - val_categorical_accuracy: 0.6870 - lr: 0.0010
# Epoch 7/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8427 - categorical_accuracy: 0.6600
# Epoch 00007: val_categorical_accuracy improved from 0.68702 to 0.69447, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 51s 166ms/step - loss: 0.8427 - categorical_accuracy: 0.6600 - val_loss: 0.7724 - val_categorical_accuracy: 0.6945 - lr: 0.0010
# Epoch 8/100
# 306/306 [==============================] - ETA: 0s - loss: 0.8236 - categorical_accuracy: 0.6688
# Epoch 00008: val_categorical_accuracy did not improve from 0.69447
# 306/306 [==============================] - 48s 158ms/step - loss: 0.8236 - categorical_accuracy: 0.6688 - val_loss: 0.7610 - val_categorical_accuracy: 0.6889 - lr: 0.0010
# Epoch 9/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7951 - categorical_accuracy: 0.6801
# Epoch 00009: val_categorical_accuracy improved from 0.69447 to 0.70385, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 51s 168ms/step - loss: 0.7951 - categorical_accuracy: 0.6801 - val_loss: 0.7416 - val_categorical_accuracy: 0.7038 - lr: 0.0010
# Epoch 10/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7772 - categorical_accuracy: 0.6901
# Epoch 00010: val_categorical_accuracy improved from 0.70385 to 0.71995, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 51s 166ms/step - loss: 0.7772 - categorical_accuracy: 0.6901 - val_loss: 0.6874 - val_categorical_accuracy: 0.7200 - lr: 0.0010
# Epoch 11/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7640 - categorical_accuracy: 0.6941
# Epoch 00011: val_categorical_accuracy improved from 0.71995 to 0.72596, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 50s 164ms/step - loss: 0.7640 - categorical_accuracy: 0.6941 - val_loss: 0.6919 - val_categorical_accuracy: 0.7260 - lr: 0.0010
# Epoch 12/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7516 - categorical_accuracy: 0.7027
# Epoch 00012: val_categorical_accuracy improved from 0.72596 to 0.73462, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 52s 169ms/step - loss: 0.7516 - categorical_accuracy: 0.7027 - val_loss: 0.6678 - val_categorical_accuracy: 0.7346 - lr: 0.0010
# Epoch 13/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7354 - categorical_accuracy: 0.7095
# Epoch 00013: val_categorical_accuracy improved from 0.73462 to 0.73510, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 51s 168ms/step - loss: 0.7354 - categorical_accuracy: 0.7095 - val_loss: 0.6605 - val_categorical_accuracy: 0.7351 - lr: 0.0010
# Epoch 14/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7295 - categorical_accuracy: 0.7110
# Epoch 00014: val_categorical_accuracy did not improve from 0.73510
# 306/306 [==============================] - 51s 168ms/step - loss: 0.7295 - categorical_accuracy: 0.7110 - val_loss: 0.6782 - val_categorical_accuracy: 0.7296 - lr: 0.0010
# Epoch 15/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7131 - categorical_accuracy: 0.7203
# Epoch 00015: val_categorical_accuracy improved from 0.73510 to 0.74135, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 52s 169ms/step - loss: 0.7131 - categorical_accuracy: 0.7203 - val_loss: 0.6372 - val_categorical_accuracy: 0.7413 - lr: 0.0010
# Epoch 16/100
# 306/306 [==============================] - ETA: 0s - loss: 0.7059 - categorical_accuracy: 0.7211
# Epoch 00016: val_categorical_accuracy did not improve from 0.74135
# 306/306 [==============================] - 52s 168ms/step - loss: 0.7059 - categorical_accuracy: 0.7211 - val_loss: 0.6598 - val_categorical_accuracy: 0.7401 - lr: 0.0010
# Epoch 17/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6959 - categorical_accuracy: 0.7260
# Epoch 00017: val_categorical_accuracy improved from 0.74135 to 0.75048, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 53s 172ms/step - loss: 0.6959 - categorical_accuracy: 0.7260 - val_loss: 0.6398 - val_categorical_accuracy: 0.7505 - lr: 0.0010
# Epoch 18/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6968 - categorical_accuracy: 0.7217
# Epoch 00018: val_categorical_accuracy did not improve from 0.75048
# 306/306 [==============================] - 52s 169ms/step - loss: 0.6968 - categorical_accuracy: 0.7217 - val_loss: 0.6387 - val_categorical_accuracy: 0.7447 - lr: 0.0010
# Epoch 19/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6855 - categorical_accuracy: 0.7310
# Epoch 00019: val_categorical_accuracy improved from 0.75048 to 0.75625, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 50s 164ms/step - loss: 0.6855 - categorical_accuracy: 0.7310 - val_loss: 0.6184 - val_categorical_accuracy: 0.7563 - lr: 0.0010
# Epoch 20/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6841 - categorical_accuracy: 0.7310
# Epoch 00020: val_categorical_accuracy did not improve from 0.75625
# 306/306 [==============================] - 50s 162ms/step - loss: 0.6841 - categorical_accuracy: 0.7310 - val_loss: 0.6522 - val_categorical_accuracy: 0.7498 - lr: 0.0010
# Epoch 21/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6700 - categorical_accuracy: 0.7372
# Epoch 00021: val_categorical_accuracy improved from 0.75625 to 0.75986, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 52s 169ms/step - loss: 0.6700 - categorical_accuracy: 0.7372 - val_loss: 0.6136 - val_categorical_accuracy: 0.7599 - lr: 0.0010
# Epoch 22/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6702 - categorical_accuracy: 0.7376
# Epoch 00022: val_categorical_accuracy did not improve from 0.75986
# 306/306 [==============================] - 51s 167ms/step - loss: 0.6702 - categorical_accuracy: 0.7376 - val_loss: 0.6387 - val_categorical_accuracy: 0.7488 - lr: 0.0010
# Epoch 23/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6681 - categorical_accuracy: 0.7378
# Epoch 00023: val_categorical_accuracy did not improve from 0.75986
# 306/306 [==============================] - 50s 163ms/step - loss: 0.6681 - categorical_accuracy: 0.7378 - val_loss: 0.6284 - val_categorical_accuracy: 0.7519 - lr: 0.0010
# Epoch 24/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6598 - categorical_accuracy: 0.7438
# Epoch 00024: val_categorical_accuracy did not improve from 0.75986
# 306/306 [==============================] - 50s 163ms/step - loss: 0.6598 - categorical_accuracy: 0.7438 - val_loss: 0.6198 - val_categorical_accuracy: 0.7546 - lr: 0.0010
# Epoch 25/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6534 - categorical_accuracy: 0.7449
# Epoch 00025: val_categorical_accuracy improved from 0.75986 to 0.76178, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 49s 161ms/step - loss: 0.6534 - categorical_accuracy: 0.7449 - val_loss: 0.6147 - val_categorical_accuracy: 0.7618 - lr: 0.0010
# Epoch 26/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6441 - categorical_accuracy: 0.7516
# Epoch 00026: val_categorical_accuracy did not improve from 0.76178
# 306/306 [==============================] - 52s 169ms/step - loss: 0.6441 - categorical_accuracy: 0.7516 - val_loss: 0.6232 - val_categorical_accuracy: 0.7555 - lr: 0.0010
# Epoch 27/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6446 - categorical_accuracy: 0.7465
# Epoch 00027: val_categorical_accuracy improved from 0.76178 to 0.76466, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 50s 163ms/step - loss: 0.6446 - categorical_accuracy: 0.7465 - val_loss: 0.6068 - val_categorical_accuracy: 0.7647 - lr: 0.0010
# Epoch 28/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6371 - categorical_accuracy: 0.7515
# Epoch 00028: val_categorical_accuracy improved from 0.76466 to 0.76683, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 51s 166ms/step - loss: 0.6371 - categorical_accuracy: 0.7515 - val_loss: 0.5989 - val_categorical_accuracy: 0.7668 - lr: 0.0010
# Epoch 29/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6337 - categorical_accuracy: 0.7545
# Epoch 00029: val_categorical_accuracy did not improve from 0.76683
# 306/306 [==============================] - 49s 160ms/step - loss: 0.6337 - categorical_accuracy: 0.7545 - val_loss: 0.6068 - val_categorical_accuracy: 0.7627 - lr: 0.0010
# Epoch 30/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6365 - categorical_accuracy: 0.7510
# Epoch 00030: val_categorical_accuracy improved from 0.76683 to 0.76947, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 49s 160ms/step - loss: 0.6365 - categorical_accuracy: 0.7510 - val_loss: 0.5949 - val_categorical_accuracy: 0.7695 - lr: 0.0010
# Epoch 31/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6330 - categorical_accuracy: 0.7530
# Epoch 00031: val_categorical_accuracy did not improve from 0.76947
# 306/306 [==============================] - 49s 159ms/step - loss: 0.6330 - categorical_accuracy: 0.7530 - val_loss: 0.6023 - val_categorical_accuracy: 0.7656 - lr: 0.0010
# Epoch 32/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6255 - categorical_accuracy: 0.7566
# Epoch 00032: val_categorical_accuracy did not improve from 0.76947
# 306/306 [==============================] - 49s 161ms/step - loss: 0.6255 - categorical_accuracy: 0.7566 - val_loss: 0.5947 - val_categorical_accuracy: 0.7661 - lr: 0.0010
# Epoch 33/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6255 - categorical_accuracy: 0.7579
# Epoch 00033: val_categorical_accuracy did not improve from 0.76947
# 306/306 [==============================] - 49s 160ms/step - loss: 0.6255 - categorical_accuracy: 0.7579 - val_loss: 0.5918 - val_categorical_accuracy: 0.7654 - lr: 0.0010
# Epoch 34/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6220 - categorical_accuracy: 0.7587
# Epoch 00034: val_categorical_accuracy improved from 0.76947 to 0.77284, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 49s 160ms/step - loss: 0.6220 - categorical_accuracy: 0.7587 - val_loss: 0.5873 - val_categorical_accuracy: 0.7728 - lr: 0.0010
# Epoch 35/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6186 - categorical_accuracy: 0.7585
# Epoch 00035: val_categorical_accuracy did not improve from 0.77284
# 306/306 [==============================] - 49s 161ms/step - loss: 0.6186 - categorical_accuracy: 0.7585 - val_loss: 0.6034 - val_categorical_accuracy: 0.7642 - lr: 0.0010
# Epoch 36/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6172 - categorical_accuracy: 0.7617
# Epoch 00036: val_categorical_accuracy did not improve from 0.77284
# 306/306 [==============================] - 49s 161ms/step - loss: 0.6172 - categorical_accuracy: 0.7617 - val_loss: 0.5928 - val_categorical_accuracy: 0.7702 - lr: 0.0010
# Epoch 37/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6136 - categorical_accuracy: 0.7627
# Epoch 00037: val_categorical_accuracy did not improve from 0.77284
# 306/306 [==============================] - 51s 166ms/step - loss: 0.6136 - categorical_accuracy: 0.7627 - val_loss: 0.5852 - val_categorical_accuracy: 0.7673 - lr: 0.0010
# Epoch 38/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6134 - categorical_accuracy: 0.7615
# Epoch 00038: val_categorical_accuracy did not improve from 0.77284
# 306/306 [==============================] - 51s 166ms/step - loss: 0.6134 - categorical_accuracy: 0.7615 - val_loss: 0.6033 - val_categorical_accuracy: 0.7589 - lr: 0.0010
# Epoch 39/100
# 306/306 [==============================] - ETA: 0s - loss: 0.6073 - categorical_accuracy: 0.7630
# Epoch 00039: val_categorical_accuracy did not improve from 0.77284
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 306/306 [==============================] - 50s 165ms/step - loss: 0.6073 - categorical_accuracy: 0.7630 - val_loss: 0.5941 - val_categorical_accuracy: 0.7707 - lr: 0.0010
# Epoch 40/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5715 - categorical_accuracy: 0.7789
# Epoch 00040: val_categorical_accuracy improved from 0.77284 to 0.77885, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 50s 165ms/step - loss: 0.5715 - categorical_accuracy: 0.7789 - val_loss: 0.5606 - val_categorical_accuracy: 0.7788 - lr: 2.0000e-04
# Epoch 41/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5682 - categorical_accuracy: 0.7803
# Epoch 00041: val_categorical_accuracy did not improve from 0.77885
# 306/306 [==============================] - 51s 168ms/step - loss: 0.5682 - categorical_accuracy: 0.7803 - val_loss: 0.5650 - val_categorical_accuracy: 0.7776 - lr: 2.0000e-04
# Epoch 42/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5600 - categorical_accuracy: 0.7849
# Epoch 00042: val_categorical_accuracy did not improve from 0.77885
# 306/306 [==============================] - 49s 159ms/step - loss: 0.5600 - categorical_accuracy: 0.7849 - val_loss: 0.5646 - val_categorical_accuracy: 0.7757 - lr: 2.0000e-04
# Epoch 43/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5550 - categorical_accuracy: 0.7880
# Epoch 00043: val_categorical_accuracy improved from 0.77885 to 0.78101, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 49s 160ms/step - loss: 0.5550 - categorical_accuracy: 0.7880 - val_loss: 0.5629 - val_categorical_accuracy: 0.7810 - lr: 2.0000e-04
# Epoch 44/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5536 - categorical_accuracy: 0.7882
# Epoch 00044: val_categorical_accuracy did not improve from 0.78101
# 306/306 [==============================] - 49s 161ms/step - loss: 0.5536 - categorical_accuracy: 0.7882 - val_loss: 0.5566 - val_categorical_accuracy: 0.7810 - lr: 2.0000e-04
# Epoch 45/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5529 - categorical_accuracy: 0.7889
# Epoch 00045: val_categorical_accuracy improved from 0.78101 to 0.78245, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 49s 161ms/step - loss: 0.5529 - categorical_accuracy: 0.7889 - val_loss: 0.5717 - val_categorical_accuracy: 0.7825 - lr: 2.0000e-04
# Epoch 46/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5492 - categorical_accuracy: 0.7898
# Epoch 00046: val_categorical_accuracy did not improve from 0.78245
# 306/306 [==============================] - 49s 160ms/step - loss: 0.5492 - categorical_accuracy: 0.7898 - val_loss: 0.5650 - val_categorical_accuracy: 0.7786 - lr: 2.0000e-04
# Epoch 47/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5555 - categorical_accuracy: 0.7869
# Epoch 00047: val_categorical_accuracy did not improve from 0.78245
# 306/306 [==============================] - 49s 161ms/step - loss: 0.5555 - categorical_accuracy: 0.7869 - val_loss: 0.5688 - val_categorical_accuracy: 0.7788 - lr: 2.0000e-04
# Epoch 48/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5506 - categorical_accuracy: 0.7901
# Epoch 00048: val_categorical_accuracy did not improve from 0.78245
# 306/306 [==============================] - 49s 161ms/step - loss: 0.5506 - categorical_accuracy: 0.7901 - val_loss: 0.5651 - val_categorical_accuracy: 0.7743 - lr: 2.0000e-04
# Epoch 49/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5440 - categorical_accuracy: 0.7918
# Epoch 00049: val_categorical_accuracy did not improve from 0.78245
# 306/306 [==============================] - 50s 165ms/step - loss: 0.5440 - categorical_accuracy: 0.7918 - val_loss: 0.5604 - val_categorical_accuracy: 0.7781 - lr: 2.0000e-04
# Epoch 50/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5463 - categorical_accuracy: 0.7901
# Epoch 00050: val_categorical_accuracy did not improve from 0.78245
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 306/306 [==============================] - 50s 163ms/step - loss: 0.5463 - categorical_accuracy: 0.7901 - val_loss: 0.5611 - val_categorical_accuracy: 0.7822 - lr: 2.0000e-04
# Epoch 51/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5385 - categorical_accuracy: 0.7965
# Epoch 00051: val_categorical_accuracy improved from 0.78245 to 0.78293, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 50s 162ms/step - loss: 0.5385 - categorical_accuracy: 0.7965 - val_loss: 0.5567 - val_categorical_accuracy: 0.7829 - lr: 4.0000e-05
# Epoch 52/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5342 - categorical_accuracy: 0.7996
# Epoch 00052: val_categorical_accuracy did not improve from 0.78293
# 306/306 [==============================] - 51s 167ms/step - loss: 0.5342 - categorical_accuracy: 0.7996 - val_loss: 0.5575 - val_categorical_accuracy: 0.7817 - lr: 4.0000e-05
# Epoch 53/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5358 - categorical_accuracy: 0.7972
# Epoch 00053: val_categorical_accuracy did not improve from 0.78293
# 306/306 [==============================] - 50s 165ms/step - loss: 0.5358 - categorical_accuracy: 0.7972 - val_loss: 0.5541 - val_categorical_accuracy: 0.7829 - lr: 4.0000e-05
# Epoch 54/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5314 - categorical_accuracy: 0.7981
# Epoch 00054: val_categorical_accuracy did not improve from 0.78293
# 306/306 [==============================] - 50s 165ms/step - loss: 0.5314 - categorical_accuracy: 0.7981 - val_loss: 0.5560 - val_categorical_accuracy: 0.7791 - lr: 4.0000e-05
# Epoch 55/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5377 - categorical_accuracy: 0.7928
# Epoch 00055: val_categorical_accuracy improved from 0.78293 to 0.78389, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 50s 163ms/step - loss: 0.5377 - categorical_accuracy: 0.7928 - val_loss: 0.5521 - val_categorical_accuracy: 0.7839 - lr: 4.0000e-05
# Epoch 56/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5341 - categorical_accuracy: 0.7950
# Epoch 00056: val_categorical_accuracy did not improve from 0.78389
# 306/306 [==============================] - 51s 166ms/step - loss: 0.5341 - categorical_accuracy: 0.7950 - val_loss: 0.5521 - val_categorical_accuracy: 0.7829 - lr: 4.0000e-05
# Epoch 57/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5323 - categorical_accuracy: 0.8002
# Epoch 00057: val_categorical_accuracy did not improve from 0.78389
# 306/306 [==============================] - 50s 163ms/step - loss: 0.5323 - categorical_accuracy: 0.8002 - val_loss: 0.5547 - val_categorical_accuracy: 0.7820 - lr: 4.0000e-05
# Epoch 58/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5297 - categorical_accuracy: 0.7966
# Epoch 00058: val_categorical_accuracy did not improve from 0.78389
# 306/306 [==============================] - 34s 111ms/step - loss: 0.5297 - categorical_accuracy: 0.7966 - val_loss: 0.5547 - val_categorical_accuracy: 0.7834 - lr: 4.0000e-05
# Epoch 59/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5318 - categorical_accuracy: 0.7978
# Epoch 00059: val_categorical_accuracy improved from 0.78389 to 0.78534, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 28s 92ms/step - loss: 0.5318 - categorical_accuracy: 0.7978 - val_loss: 0.5527 - val_categorical_accuracy: 0.7853 - lr: 4.0000e-05
# Epoch 60/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5268 - categorical_accuracy: 0.8007
# Epoch 00060: val_categorical_accuracy did not improve from 0.78534
# 306/306 [==============================] - 29s 93ms/step - loss: 0.5268 - categorical_accuracy: 0.8007 - val_loss: 0.5523 - val_categorical_accuracy: 0.7851 - lr: 4.0000e-05
# Epoch 61/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5296 - categorical_accuracy: 0.7986
# Epoch 00061: val_categorical_accuracy did not improve from 0.78534
# 306/306 [==============================] - 28s 92ms/step - loss: 0.5296 - categorical_accuracy: 0.7986 - val_loss: 0.5519 - val_categorical_accuracy: 0.7832 - lr: 4.0000e-05
# Epoch 62/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5308 - categorical_accuracy: 0.7965
# Epoch 00062: val_categorical_accuracy did not improve from 0.78534
# 306/306 [==============================] - 29s 94ms/step - loss: 0.5308 - categorical_accuracy: 0.7965 - val_loss: 0.5536 - val_categorical_accuracy: 0.7837 - lr: 4.0000e-05
# Epoch 63/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5295 - categorical_accuracy: 0.7960
# Epoch 00063: val_categorical_accuracy did not improve from 0.78534
# 306/306 [==============================] - 28s 92ms/step - loss: 0.5295 - categorical_accuracy: 0.7960 - val_loss: 0.5490 - val_categorical_accuracy: 0.7851 - lr: 4.0000e-05
# Epoch 64/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5255 - categorical_accuracy: 0.7973
# Epoch 00064: val_categorical_accuracy improved from 0.78534 to 0.78558, saving model to ../models/best_model_e_cp.hdf5
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 306/306 [==============================] - 29s 95ms/step - loss: 0.5255 - categorical_accuracy: 0.7973 - val_loss: 0.5542 - val_categorical_accuracy: 0.7856 - lr: 4.0000e-05
# Epoch 65/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5294 - categorical_accuracy: 0.7981
# Epoch 00065: val_categorical_accuracy improved from 0.78558 to 0.78582, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 29s 95ms/step - loss: 0.5294 - categorical_accuracy: 0.7981 - val_loss: 0.5514 - val_categorical_accuracy: 0.7858 - lr: 8.0000e-06
# Epoch 66/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5336 - categorical_accuracy: 0.7945
# Epoch 00066: val_categorical_accuracy did not improve from 0.78582
# 306/306 [==============================] - 28s 92ms/step - loss: 0.5336 - categorical_accuracy: 0.7945 - val_loss: 0.5537 - val_categorical_accuracy: 0.7849 - lr: 8.0000e-06
# Epoch 67/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5262 - categorical_accuracy: 0.8006
# Epoch 00067: val_categorical_accuracy did not improve from 0.78582
# 306/306 [==============================] - 28s 91ms/step - loss: 0.5262 - categorical_accuracy: 0.8006 - val_loss: 0.5515 - val_categorical_accuracy: 0.7846 - lr: 8.0000e-06
# Epoch 68/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5276 - categorical_accuracy: 0.8008
# Epoch 00068: val_categorical_accuracy improved from 0.78582 to 0.78606, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 28s 91ms/step - loss: 0.5276 - categorical_accuracy: 0.8008 - val_loss: 0.5522 - val_categorical_accuracy: 0.7861 - lr: 8.0000e-06
# Epoch 69/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5295 - categorical_accuracy: 0.7969
# Epoch 00069: val_categorical_accuracy did not improve from 0.78606
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 306/306 [==============================] - 28s 92ms/step - loss: 0.5295 - categorical_accuracy: 0.7969 - val_loss: 0.5527 - val_categorical_accuracy: 0.7853 - lr: 8.0000e-06
# Epoch 70/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5333 - categorical_accuracy: 0.7986
# Epoch 00070: val_categorical_accuracy improved from 0.78606 to 0.78630, saving model to ../models/best_model_e_cp.hdf5
# 306/306 [==============================] - 28s 91ms/step - loss: 0.5333 - categorical_accuracy: 0.7986 - val_loss: 0.5525 - val_categorical_accuracy: 0.7863 - lr: 1.6000e-06
# Epoch 71/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5248 - categorical_accuracy: 0.7995
# Epoch 00071: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 28s 91ms/step - loss: 0.5248 - categorical_accuracy: 0.7995 - val_loss: 0.5531 - val_categorical_accuracy: 0.7851 - lr: 1.6000e-06
# Epoch 72/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5267 - categorical_accuracy: 0.8003
# Epoch 00072: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 28s 92ms/step - loss: 0.5267 - categorical_accuracy: 0.8003 - val_loss: 0.5517 - val_categorical_accuracy: 0.7858 - lr: 1.6000e-06
# Epoch 73/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5310 - categorical_accuracy: 0.7980
# Epoch 00073: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 28s 91ms/step - loss: 0.5310 - categorical_accuracy: 0.7980 - val_loss: 0.5510 - val_categorical_accuracy: 0.7856 - lr: 1.6000e-06
# Epoch 74/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5299 - categorical_accuracy: 0.7957
# Epoch 00074: val_categorical_accuracy did not improve from 0.78630
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 306/306 [==============================] - 29s 94ms/step - loss: 0.5299 - categorical_accuracy: 0.7957 - val_loss: 0.5484 - val_categorical_accuracy: 0.7861 - lr: 1.6000e-06
# Epoch 75/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5324 - categorical_accuracy: 0.7972
# Epoch 00075: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 29s 95ms/step - loss: 0.5324 - categorical_accuracy: 0.7972 - val_loss: 0.5519 - val_categorical_accuracy: 0.7844 - lr: 3.2000e-07
# Epoch 76/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5263 - categorical_accuracy: 0.7989
# Epoch 00076: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 29s 96ms/step - loss: 0.5263 - categorical_accuracy: 0.7989 - val_loss: 0.5519 - val_categorical_accuracy: 0.7837 - lr: 3.2000e-07
# Epoch 77/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5281 - categorical_accuracy: 0.7983
# Epoch 00077: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 30s 98ms/step - loss: 0.5281 - categorical_accuracy: 0.7983 - val_loss: 0.5514 - val_categorical_accuracy: 0.7851 - lr: 3.2000e-07
# Epoch 78/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5271 - categorical_accuracy: 0.7977
# Epoch 00078: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 29s 96ms/step - loss: 0.5271 - categorical_accuracy: 0.7977 - val_loss: 0.5503 - val_categorical_accuracy: 0.7839 - lr: 3.2000e-07
# Epoch 79/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5277 - categorical_accuracy: 0.7957
# Epoch 00079: val_categorical_accuracy did not improve from 0.78630
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 306/306 [==============================] - 29s 94ms/step - loss: 0.5277 - categorical_accuracy: 0.7957 - val_loss: 0.5518 - val_categorical_accuracy: 0.7834 - lr: 3.2000e-07
# Epoch 80/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5330 - categorical_accuracy: 0.7970
# Epoch 00080: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 29s 93ms/step - loss: 0.5330 - categorical_accuracy: 0.7970 - val_loss: 0.5531 - val_categorical_accuracy: 0.7841 - lr: 6.4000e-08
# Epoch 81/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5297 - categorical_accuracy: 0.7996
# Epoch 00081: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 29s 93ms/step - loss: 0.5297 - categorical_accuracy: 0.7996 - val_loss: 0.5528 - val_categorical_accuracy: 0.7837 - lr: 6.4000e-08
# Epoch 82/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5295 - categorical_accuracy: 0.7979
# Epoch 00082: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 28s 93ms/step - loss: 0.5295 - categorical_accuracy: 0.7979 - val_loss: 0.5525 - val_categorical_accuracy: 0.7841 - lr: 6.4000e-08
# Epoch 83/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5296 - categorical_accuracy: 0.7973
# Epoch 00083: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 29s 94ms/step - loss: 0.5296 - categorical_accuracy: 0.7973 - val_loss: 0.5524 - val_categorical_accuracy: 0.7834 - lr: 6.4000e-08
# Epoch 84/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5320 - categorical_accuracy: 0.7964
# Epoch 00084: val_categorical_accuracy did not improve from 0.78630
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 306/306 [==============================] - 29s 94ms/step - loss: 0.5320 - categorical_accuracy: 0.7964 - val_loss: 0.5529 - val_categorical_accuracy: 0.7839 - lr: 6.4000e-08
# Epoch 85/100
# 306/306 [==============================] - ETA: 0s - loss: 0.5289 - categorical_accuracy: 0.7997Restoring model weights from the end of the best epoch.
#
# Epoch 00085: val_categorical_accuracy did not improve from 0.78630
# 306/306 [==============================] - 29s 96ms/step - loss: 0.5289 - categorical_accuracy: 0.7997 - val_loss: 0.5519 - val_categorical_accuracy: 0.7844 - lr: 1.2800e-08
# Epoch 00085: early stopping
# CPU times: user 3h 41min 10s, sys: 33min 39s, total: 4h 14min 50s
# Wall time: 1h 1min 26s

# %% [markdown]
# ## Results

# %%
#plotting Accuracy and Loss curves
plt.figure(figsize=(15,5))

plt.subplot(121)
plt.plot(history.history["categorical_accuracy"], label = 'Train Accuracy', color='gold')
plt.plot(history.history["val_categorical_accuracy"], label = 'Validation Accuracy', color='slategray')
plt.title("Training and Validation Accuracy by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend();

plt.subplot(122)
plt.plot(history.history["loss"], label = 'Train Loss', color='gold')
plt.plot(history.history["val_loss"], label = 'Validation Loss', color='slategray')
plt.title("Training and Validation Loss by Epoch")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend();

# %%
#Code snippet credit: APEKSHA PRIYA, Priya Dwivedi
#confusion matrix and classification report

#validation generator with shuffle = false
validation_generator1 = val_datagen.flow_from_directory(
        validation_data_dir,
        color_mode = 'grayscale',
        target_size=(img_rows, img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

class_labels = validation_generator1.class_indices
class_labels = {v: k for k, v in class_labels.items()}
classes = list(class_labels.values())

#Confusion Matrix and Classification Report
Y_pred = model.predict_generator(validation_generator1, validation_samples // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)
y_test = validation_generator1.classes

#Generate Confusion Matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
cnf_matrix.ravel

print('Classification Report')
target_names = list(class_labels.values())
print(classification_report(y_test, y_pred, target_names=target_names))


#plot confusion matrix
plt.figure(figsize=(8,8))
ax= plt.subplot()
sns.heatmap(cnf_matrix, annot=True, ax = ax, cmap='bone_r', fmt='g', cbar=False)
# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels') 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad'])
ax.yaxis.set_ticklabels(['angry', 'happy', 'neutral', 'sad']);
# Out:
# Found 4198 images belonging to 4 classes.
# WARNING:tensorflow:From <ipython-input-10-6561d12b4ec9>:18: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# Classification Report
#               precision    recall  f1-score   support
#
#        angry       0.71      0.69      0.70       544
#        happy       0.89      0.89      0.89      1665
#      neutral       0.75      0.82      0.78      1401
#          sad       0.64      0.49      0.56       588
#
#     accuracy                           0.79      4198
#    macro avg       0.74      0.72      0.73      4198
# weighted avg       0.78      0.79      0.78      4198
